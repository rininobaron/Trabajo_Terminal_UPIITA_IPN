# %% [markdown]
# Anexo O

# %% [markdown]
# # Red Neuronal Convolucional ResNet50
#
# #### Elaborado por: Ricardo Niño de Rivera Barrón
#
# #### Ingeniería Biónica
#
# #### Trabajo Terminal II

# %% [markdown]
# En esta libreta interactiva se describe el proceso para la implementación de un modelo preentrenado de Red Neuronal Convolucional llamado ResNet50.
#
# Esta libreta se desarrolló en la plaforma Kaggle con el objetivo de mejorar la velocidad de implementación.

# %%
# Importando bibliotecas necesarias
import os
import numpy as np
import pandas as pd
from tqdm import tqdm
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import preprocessing
import matplotlib.image as mpimg
import sklearn
import tensorflow as tf

# %% [markdown]
# Ahora instalamos una nueva biblioteca para poder descargar archivos de MEGA.

# %%
# Instalanado mega.py
# !pip install mega.py
# Out:
# Collecting mega.py
#   Downloading mega.py-1.0.8-py2.py3-none-any.whl (19 kB)
# Collecting pathlib==1.0.1
#   Downloading pathlib-1.0.1.tar.gz (49 kB)
#      |████████████████████████████████| 49 kB 478 kB/s
# Collecting pycryptodome<4.0.0,>=3.9.6
#   Downloading pycryptodome-3.9.9-cp37-cp37m-manylinux1_x86_64.whl (13.7 MB)
#      |████████████████████████████████| 13.7 MB 11.7 MB/s
# Collecting tenacity<6.0.0,>=5.1.5
#   Downloading tenacity-5.1.5-py2.py3-none-any.whl (34 kB)
# Requirement already satisfied: requests>=0.10 in /opt/conda/lib/python3.7/site-packages (from mega.py) (2.23.0)
# Requirement already satisfied: six>=1.9.0 in /opt/conda/lib/python3.7/site-packages (from tenacity<6.0.0,>=5.1.5->mega.py) (1.14.0)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests>=0.10->mega.py) (2.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests>=0.10->mega.py) (1.25.9)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests>=0.10->mega.py) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests>=0.10->mega.py) (3.0.4)
# Building wheels for collected packages: pathlib
# done
#   Created wheel for pathlib: filename=pathlib-1.0.1-py3-none-any.whl size=14346 sha256=57aad52f059a9b948d5bd956911fad8bc24bf016957b9a1d58350c399b081212
#   Stored in directory: /root/.cache/pip/wheels/6e/96/b8/10037fe231e23970bac58361d7c93571ab983a7bbc55e68550
# Successfully built pathlib
# Installing collected packages: pathlib, pycryptodome, tenacity, mega.py
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 6.1.0
#     Uninstalling tenacity-6.1.0:
#       Successfully uninstalled tenacity-6.1.0
# Successfully installed mega.py-1.0.8 pathlib-1.0.1 pycryptodome-3.9.9 tenacity-5.1.5

# %%
# De la biblioteca mega importamos el método Mega
from mega import Mega

# %%
# Instanciando Mega en el objeto mega
mega = Mega()

# %% [markdown]
# Inicamos sesión en MEGA con cuenta temporal y anónima

# %%
# Log in en la cuenta de MEGA con cuenta temporal anónima
m = mega.login()

# %% [markdown]
# Descargando Base de Datos.

# %%
# Descargando Base de Datos
m.download_url('https://mega.nz/file/dBARgAIQ#uiQq4P-zC1fm6tV1I_udl2dtCiqzwyDadLyVlZ_dzAY')
# Out:
# PosixPath('BaseDeDatosFrontales_FINAL_256_bits.zip')

# %% [markdown]
# Como Kaggle es un entorno de desarrollo que trabaja en Linux utilizaremos algunos comandos nativos de este sistema operativo.
#
# Para descomprimir el archivo utilizarmos el comando nativo de Linux <em>unzip</em>.

# %%
# !unzip -q BaseDeDatosFrontales_FINAL_256_bits.zip

# %% [markdown]
# Descargamos los archivos necesarios.

# %%
# Descargando pos_train
m.download_url('https://mega.nz/file/Fcp12QzD#MLUFNaNeKJ8YFPo2bO1uNt7hnKCbDAy8S10s1-vKJ5Q')
# Out:
# PosixPath('pos_train.npy')

# %%
# Descargando pos_test
m.download_url('https://mega.nz/file/sQoFDaRB#Uh70-XjrqlGKaE9eBoc4puXnNxNFcQ0D23h_79rDnC4')
# Out:
# PosixPath('pos_test.npy')

# %%
# Descargando Y_train2.npy
m.download_url('https://mega.nz/file/tdohXarb#SRrt31GIT7H6gioCVm2KYF-sH6a8PHK8Z7Tr76oZb4I')
# Out:
# PosixPath('Y_train2.npy')

# %%
# Descargando Y_test2.npy
m.download_url('https://mega.nz/file/Vc5TBSbY#D8pbUvpA3l2V0PJxCu7Meg8WJ3wPpT6X2jEoDsleCWw')
# Out:
# PosixPath('Y_test2.npy')

# %% [markdown]
# Ahora se leen los archivos con numpy

# %%
pos_train = np.load('pos_train.npy')
pos_train.shape
# Out:
# (3337,)

# %%
pos_test = np.load('pos_test.npy')
pos_test.shape
# Out:
# (832,)

# %%
Y_train = np.load('Y_train2.npy')
Y_train.shape
# Out:
# (3337,)

# %%
# Agregando un dimensión para evitar errores con tensorflow
#Y_train = np.expand_dims(Y_train, axis=1)
#Y_train.shape

# %%
Y_test = np.load('Y_test2.npy')
Y_test.shape
# Out:
# (832,)

# %%
# Agregando un dimensión para evitar errores con tensorflow
#Y_test = np.expand_dims(Y_test, axis=1)
#Y_test.shape

# %% [markdown]
# Leemos los archivos en los directorios de interés.

# %%
# Leyendo archivos de entrenamiento
files=os.listdir("./BaseDeDatosFrontales_FINAL_256_bits/train")

# %%
# Leyendo archivos de validación
files2=os.listdir("./BaseDeDatosFrontales_FINAL_256_bits/test")

# %%
# Ordenando alfabeticamente el contenido de las listas
files.sort()
files2.sort()

# %% [markdown]
# ### Construyendo X_train y X_test

# %% [markdown]
# Vamos a definir un nuevo tamaño de las imágenes para evitar problemas de memoria y acelerar el entrenamiento.

# %%
size_img = 128

# %%
# Definiendo función get_img para leer los archivos numpy y ajustarlos a nuevo tamaño.
# La imagen que retorna la función también es normalizada sobre los valor máximo del pixel (255)
def get_img(path, size, display_image = False):
  img = np.load(path)
  img = np.expand_dims(img, axis=2)
  if display_image == True:
    print(img.shape)
    plt.imshow(img[:,:,0], cmap='hot')

  return tf.image.resize(img, [size,size], antialias=True)/255

# %%
# Directorio raíz
path = "./BaseDeDatosFrontales_FINAL_256_bits/"

# %% [markdown]
# Realizamos una prueba de funcionamiento de la función

# %%
# Imagen original
hola=get_img(path+'train/'+files[1], size_img, display_image = True)
# Out:
# (480, 640, 1)

# %%
np.max(hola)
# Out:
# 0.78683746

# %%
np.min(hola)
# Out:
# 0.15518688

# %%
# Imagen resultante
plt.imshow(hola[:,:,0], cmap='hot')

# %% [markdown]
# Se leen los archivos y se ordenan en un nuevo arreglo.

# %%
# Entrenamiento X_train

# Creamos el arreglo para almacenar las imégenes
# Tendrá tres canales para  aprovechar los pesos preentrenados
# con imágenes de ImageNet
X_train = np.zeros((len(files), size_img, size_img,3))

for i in tqdm(range(len(files))):

  # Leemos y procesamos la imagen con respecto a pos_train
  temp_img = get_img(path+"train/"+files[pos_train[i]], size_img)

  # Almacenamos la imagen obtenida en cada canal
  X_train[i,:,:,0] = temp_img[:,:,0]
  X_train[i,:,:,1] = temp_img[:,:,0]
  X_train[i,:,:,2] = temp_img[:,:,0]
# Out:
# 100%|██████████| 3337/3337 [00:15<00:00, 218.14it/s]

# %%
X_train.shape
# Out:
# (3337, 128, 128, 3)

# %%
# Validación X_test

# Creamos el arreglo para almacenar las imégenes
# Tendrá tres canales para  aprovechar los pesos preentrenados
# con imágenes de ImageNet
X_test = np.zeros((len(files2), size_img, size_img,3))

for i in tqdm(range(len(files2))):

  # Leemos y procesamos la imagen con respecto a pos_train
  temp_img = get_img(path+"test/"+files2[pos_test[i]], size_img)

  # Almacenamos la imagen obtenida en cada canal
  X_test[i,:,:,0] = temp_img[:,:,0]
  X_test[i,:,:,1] = temp_img[:,:,0]
  X_test[i,:,:,2] = temp_img[:,:,0]
# Out:
# 100%|██████████| 832/832 [00:04<00:00, 166.59it/s]

# %%
X_test.shape
# Out:
# (832, 128, 128, 3)

# %% [markdown]
# ### ResNet50
#
# En esta sección se implementa la arquitectura ResNet50
#
# Esta arquitectura fue propuesta en 2016. La idea principal de esta arquitectura es la modificación de la función de activación de las bloques convolucionales considerando segmentos de bloques en lugar de uno a uno, de ahí el nombre, "Res"-residual, osea considera las salidas anteriores o "residuos". Esto mejora empíricamenete ha mejorado el rendimiento en diferentes problemas de reconocimiento de imágenes donde ha sido evaluado con arquitecturas "clásicas". ref: http://multigrid.org/wiki/wp-content/uploads/2019/09/He_Deep_Residual_Learning_CVPR_2016_paper.pdf

# %%
# importando bibliotecas auxiliares
from tensorflow.keras.applications import *
from tensorflow.keras.layers import *
import tensorflow_addons as tfa
from tensorflow.keras import Model, Input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# Out:
# /opt/conda/lib/python3.7/site-packages/tensorflow_addons/utils/ensure_tf_install.py:68: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.2.0 and strictly below 2.3.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.3.1 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   UserWarning,

# %%
# Importando métricas de scikit learn}
from sklearn.metrics import f1_score, precision_score, recall_score, confusion_matrix, roc_curve, auc, accuracy_score

# %%
# Arreglando el problema de clases desbalanceadas estableciendo un peso por clase en el función de costo
w_p=np.sum(Y_train==0)/Y_train.shape[0]
w_n=np.sum(Y_train==1)/Y_train.shape[0]

# %%
# Creando diccionario para establecer el peso de cada clase de salida
class_weights = { 0 : w_n , 1 : w_p }

# %%
# definimos dropout
# Esta factor que está definido entre 0 y 1
# es un factor que determina la tasa de unidades que se "apagarán"
# durante el entrenamiento; esto evita el sobreajuste
dropout = 0.2

# %%
# Definimos un modelo de incialización
# Esta inicialización ha demostrado ser bastante útil
# para ayudar al modelo a converger más rápido.
# Incialización por he es una técnica que utiliza la destribución probabílistica
# propuesta por He para incializar los pesos de la red neuronal
# Para más información refierase a la coumentación
# de la biblioteca
kernel_init = 'he_normal'

# %%
# Creando el modelo ResNet50 con pesos preentrenados en ImageNet
rnet = ResNet50(weights='imagenet', include_top=False, input_shape=[X_train.shape[1],X_train.shape[2],X_train.shape[3]])
rnet = tf.keras.Sequential(rnet)
rnet.add(Dropout(dropout))
rnet.add(Flatten())
rnet.add(Dense(4096, activation='relu', kernel_initializer=kernel_init))
rnet.add(Dropout(dropout))
rnet.add(Dense(4096, activation='relu', kernel_initializer=kernel_init))
rnet.add(Dropout(dropout))
rnet.add(Dense(1, activation='sigmoid', kernel_initializer=kernel_init))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 5s 0us/step

# %%
# Visualizando el modelo
rnet.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Functional)        (None, 4, 4, 2048)        23587712
# _________________________________________________________________
# dropout (Dropout)            (None, 4, 4, 2048)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 32768)             0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              134221824
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 4097
# =================================================================
# Total params: 174,594,945
# Trainable params: 174,541,825
# Non-trainable params: 53,120
# _________________________________________________________________

# %%
rnet.output.shape
# Out:
# TensorShape([None, 1])

# %%
# Añadiendo un término de regularización para evitar sobreajuste

#L1 = 0.1

#regularizer = tf.keras.regularizers.L1(l1=L1)

#rnet.trainable = True

#for layer in rnet.layers:
#    for attr in ['kernel_regularizer']:
#        if hasattr(layer, attr):
#          setattr(layer, attr, regularizer)

# %%
# Se fuerza a la tasa de aprendiza a decaer de forma polinomial para evitar problemas con el entrenamiento
starter_learning_rate = 0.1
end_learning_rate = 0.01
decay_steps = 5
learning_rate_fn = tf.keras.optimizers.schedules.PolynomialDecay(
    starter_learning_rate,
    decay_steps,
    end_learning_rate,
    power=0.5)

# %%
# Definimos el optimizador utilizando el método de Adam
# Este método es una modificación del algoritmo de
# gradiente descendiente
opt=tfa.optimizers.RectifiedAdam(learning_rate=0.01) #,clipvalue=5)
#opt=tf.keras.optimizers.Nadam(learning_rate=0.01 ,clipvalue=5)
#opt=tf.keras.optimizers.Adam(learning_rate=learning_rate_fn) #,clipvalue=5)

# %%
# Definiendo las métricas necesarias para dar seguimiento al modelo
METRICS = [
  tf.keras.metrics.BinaryAccuracy(name='accuracy'),
  tf.keras.metrics.Precision(name='precision'),
  tf.keras.metrics.Recall(name='recall'),
  tfa.metrics.F1Score(num_classes=2, average="micro", threshold=0.5),
  tf.keras.metrics.AUC(name='AUC')
]

# %%
# Compilando el modelo
rnet.compile(
    optimizer=opt,
    loss = 'binary_crossentropy',
    metrics=METRICS
)

# %% [markdown]
# La métrica de oro será el AUC.

# %%
# Con este objeto se guardará el mejor modelo con base a la métrica f1_score
sv = tf.keras.callbacks.ModelCheckpoint(filepath='ResNet50_weights.h5',monitor='val_AUC', verbose=0, save_best_only=True,
        save_weights_only=False, mode='max', save_freq='epoch')

# %%
# Tamaño del batch (se recomienda un batch potencia de 2)
BS = 128

# %%
# Entrenando el modelo y almacenando los valores en history_1
history_1 = rnet.fit(X_train, Y_train, batch_size=BS,
                          steps_per_epoch=len(X_train) // BS, validation_data=(X_test, Y_test),
                          epochs=200, verbose=2, class_weight=class_weights, callbacks=[sv])
# Out:
# Epoch 1/200
# 26/26 - 18s - loss: 0.4798 - accuracy: 0.8218 - precision: 0.5046 - recall: 0.8223 - f1_score: 0.6254 - AUC: 0.8828 - val_loss: 817.1833 - val_accuracy: 0.7224 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00 - val_AUC: 0.5000
# Epoch 2/200
# 26/26 - 9s - loss: 0.0550 - accuracy: 0.9592 - precision: 0.8341 - recall: 0.9674 - f1_score: 0.8958 - AUC: 0.9855 - val_loss: 4.8616 - val_accuracy: 0.2776 - val_precision: 0.2776 - val_recall: 1.0000 - val_f1_score: 0.4346 - val_AUC: 0.5000
# Epoch 3/200
# 26/26 - 8s - loss: 0.0033 - accuracy: 0.9966 - precision: 0.9811 - recall: 1.0000 - f1_score: 0.9905 - AUC: 0.9995 - val_loss: 8.1682 - val_accuracy: 0.2776 - val_precision: 0.2776 - val_recall: 1.0000 - val_f1_score: 0.4346 - val_AUC: 0.5000
# Epoch 4/200
# 26/26 - 8s - loss: 0.0882 - accuracy: 0.9311 - precision: 0.7507 - recall: 0.9336 - f1_score: 0.8322 - AUC: 0.9776 - val_loss: 66668584.0000 - val_accuracy: 0.7224 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00 - val_AUC: 0.5000
# Epoch 5/200
# 26/26 - 8s - loss: 0.0534 - accuracy: 0.9205 - precision: 0.6988 - recall: 0.9809 - f1_score: 0.8162 - AUC: 0.9819 - val_loss: 1708333.8750 - val_accuracy: 0.7224 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00 - val_AUC: 0.5000
# Epoch 6/200
# 26/26 - 8s - loss: 5.5183 - accuracy: 0.6644 - precision: 0.3040 - recall: 0.6794 - f1_score: 0.4200 - AUC: 0.7556 - val_loss: 152184213641034203136.0000 - val_accuracy: 0.7224 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00 - val_AUC: 0.5000
# Epoch 7/200
# 26/26 - 8s - loss: 2.9275 - accuracy: 0.5665 - precision: 0.2693 - recall: 0.8357 - f1_score: 0.4073 - AUC: 0.7228 - val_loss: 270220937658368.0000 - val_accuracy: 0.7224 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00 - val_AUC: 0.5000
# Epoch 8/200
# 26/26 - 8s - loss: 0.8869 - accuracy: 0.6248 - precision: 0.2706 - recall: 0.6714 - f1_score: 0.3857 - AUC: 0.7065 - val_loss: 1871903360.0000 - val_accuracy: 0.7224 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00 - val_AUC: 0.5000
# Epoch 9/200
# 26/26 - 8s - loss: 0.1881 - accuracy: 0.4581 - precision: 0.2455 - recall: 0.9390 - f1_score: 0.3892 - AUC: 0.6748 - val_loss: 0.6951 - val_accuracy: 0.2776 - val_precision: 0.2776 - val_recall: 1.0000 - val_f1_score: 0.4346 - val_AUC: 0.5000
# Epoch 10/200
# 26/26 - 8s - loss: 0.1802 - accuracy: 0.5058 - precision: 0.2589 - recall: 0.9261 - f1_score: 0.4047 - AUC: 0.6763 - val_loss: 0.7933 - val_accuracy: 0.2776 - val_precision: 0.2776 - val_recall: 1.0000 - val_f1_score: 0.4346 - val_AUC: 0.5000
# Epoch 11/200
# 26/26 - 8s - loss: 0.1650 - accuracy: 0.4780 - precision: 0.2600 - recall: 0.9882 - f1_score: 0.4117 - AUC: 0.7040 - val_loss: 0.8239 - val_accuracy: 0.2776 - val_precision: 0.2776 - val_recall: 1.0000 - val_f1_score: 0.4346 - val_AUC: 0.5000
# Epoch 12/200
# 26/26 - 8s - loss: 0.1861 - accuracy: 0.6276 - precision: 0.2975 - recall: 0.8274 - f1_score: 0.4376 - AUC: 0.7803 - val_loss: 0.8414 - val_accuracy: 0.2776 - val_precision: 0.2776 - val_recall: 1.0000 - val_f1_score: 0.4346 - val_AUC: 0.5000
# Epoch 13/200
# 26/26 - 8s - loss: 0.1278 - accuracy: 0.7585 - precision: 0.4150 - recall: 0.8438 - f1_score: 0.5564 - AUC: 0.8735 - val_loss: 1.1018 - val_accuracy: 0.2776 - val_precision: 0.2776 - val_recall: 1.0000 - val_f1_score: 0.4346 - val_AUC: 0.5000
# Epoch 14/200
# 26/26 - 17s - loss: 0.1283 - accuracy: 0.7691 - precision: 0.4384 - recall: 0.8512 - f1_score: 0.5787 - AUC: 0.8831 - val_loss: 0.9205 - val_accuracy: 0.2776 - val_precision: 0.2776 - val_recall: 1.0000 - val_f1_score: 0.4346 - val_AUC: 0.5393
# Epoch 15/200
# 26/26 - 32s - loss: 0.1099 - accuracy: 0.8118 - precision: 0.4861 - recall: 0.8524 - f1_score: 0.6192 - AUC: 0.9125 - val_loss: 0.6655 - val_accuracy: 0.6298 - val_precision: 0.4045 - val_recall: 0.7056 - val_f1_score: 0.5142 - val_AUC: 0.6474
# Epoch 16/200
# 26/26 - 8s - loss: 0.1636 - accuracy: 0.6600 - precision: 0.3391 - recall: 0.9046 - f1_score: 0.4933 - AUC: 0.8277 - val_loss: 0.7353 - val_accuracy: 0.2776 - val_precision: 0.2776 - val_recall: 1.0000 - val_f1_score: 0.4346 - val_AUC: 0.5000
# Epoch 17/200
# 26/26 - 8s - loss: 0.1686 - accuracy: 0.4600 - precision: 0.2440 - recall: 0.9771 - f1_score: 0.3904 - AUC: 0.6758 - val_loss: 0.8454 - val_accuracy: 0.2776 - val_precision: 0.2776 - val_recall: 1.0000 - val_f1_score: 0.4346 - val_AUC: 0.5000
# Epoch 18/200
# 26/26 - 8s - loss: 0.1650 - accuracy: 0.4790 - precision: 0.2544 - recall: 0.9878 - f1_score: 0.4046 - AUC: 0.6950 - val_loss: 0.7750 - val_accuracy: 0.2776 - val_precision: 0.2776 - val_recall: 1.0000 - val_f1_score: 0.4346 - val_AUC: 0.5000
# Epoch 19/200
# 26/26 - 8s - loss: 0.1664 - accuracy: 0.4849 - precision: 0.2648 - recall: 0.9801 - f1_score: 0.4169 - AUC: 0.7095 - val_loss: 0.8136 - val_accuracy: 0.2776 - val_precision: 0.2776 - val_recall: 1.0000 - val_f1_score: 0.4346 - val_AUC: 0.5000
# Epoch 20/200
# 26/26 - 8s - loss: 0.1575 - accuracy: 0.4868 - precision: 0.2498 - recall: 0.9820 - f1_score: 0.3982 - AUC: 0.7072 - val_loss: 0.8306 - val_accuracy: 0.2776 - val_precision: 0.2776 - val_recall: 1.0000 - val_f1_score: 0.4346 - val_AUC: 0.5000
# Epoch 21/200
# 26/26 - 8s - loss: 0.1647 - accuracy: 0.4917 - precision: 0.2633 - recall: 0.9864 - f1_score: 0.4156 - AUC: 0.6949 - val_loss: 0.8180 - val_accuracy: 0.2776 - val_precision: 0.2776 - val_recall: 1.0000 - val_f1_score: 0.4346 - val_AUC: 0.5000
# Epoch 22/200
# 26/26 - 8s - loss: 0.1560 - accuracy: 0.4921 - precision: 0.2629 - recall: 0.9983 - f1_score: 0.4162 - AUC: 0.7152 - val_loss: 0.7920 - val_accuracy: 0.2776 - val_precision: 0.2776 - val_recall: 1.0000 - val_f1_score: 0.4346 - val_AUC: 0.5000
# Epoch 23/200
# 26/26 - 8s - loss: 0.1620 - accuracy: 0.5076 - precision: 0.2624 - recall: 0.9894 - f1_score: 0.4148 - AUC: 0.7112 - val_loss: 0.8429 - val_accuracy: 0.2776 - val_precision: 0.2776 - val_recall: 1.0000 - val_f1_score: 0.4346 - val_AUC: 0.5000
# Epoch 24/200
# 26/26 - 8s - loss: 0.1591 - accuracy: 0.4983 - precision: 0.2668 - recall: 0.9865 - f1_score: 0.4200 - AUC: 0.7222 - val_loss: 0.7956 - val_accuracy: 0.2776 - val_precision: 0.2776 - val_recall: 1.0000 - val_f1_score: 0.4346 - val_AUC: 0.5000
# Epoch 25/200
# 26/26 - 8s - loss: 0.1536 - accuracy: 0.5095 - precision: 0.2666 - recall: 0.9948 - f1_score: 0.4205 - AUC: 0.7301 - val_loss: 0.8164 - val_accuracy: 0.2776 - val_precision: 0.2776 - val_recall: 1.0000 - val_f1_score: 0.4346 - val_AUC: 0.5000
# Epoch 26/200
# 26/26 - 8s - loss: 0.1521 - accuracy: 0.5095 - precision: 0.2663 - recall: 0.9896 - f1_score: 0.4196 - AUC: 0.7335 - val_loss: 0.8488 - val_accuracy: 0.2776 - val_precision: 0.2776 - val_recall: 1.0000 - val_f1_score: 0.4346 - val_AUC: 0.5000
# Epoch 27/200
# 26/26 - 8s - loss: 0.1580 - accuracy: 0.5033 - precision: 0.2666 - recall: 0.9931 - f1_score: 0.4204 - AUC: 0.7226 - val_loss: 0.7852 - val_accuracy: 0.2776 - val_precision: 0.2776 - val_recall: 1.0000 - val_f1_score: 0.4346 - val_AUC: 0.5000
# Epoch 28/200
# 26/26 - 8s - loss: 0.1546 - accuracy: 0.5084 - precision: 0.2659 - recall: 0.9833 - f1_score: 0.4186 - AUC: 0.7184 - val_loss: 0.7838 - val_accuracy: 0.2776 - val_precision: 0.2776 - val_recall: 1.0000 - val_f1_score: 0.4346 - val_AUC: 0.5000
# Epoch 29/200
# 26/26 - 8s - loss: 0.1536 - accuracy: 0.5114 - precision: 0.2671 - recall: 0.9878 - f1_score: 0.4205 - AUC: 0.7243 - val_loss: 0.8019 - val_accuracy: 0.2776 - val_precision: 0.2776 - val_recall: 1.0000 - val_f1_score: 0.4346 - val_AUC: 0.5000
# Epoch 30/200
# 26/26 - 8s - loss: 0.1539 - accuracy: 0.5126 - precision: 0.2701 - recall: 0.9914 - f1_score: 0.4246 - AUC: 0.7223 - val_loss: 0.8104 - val_accuracy: 0.2776 - val_precision: 0.2776 - val_recall: 1.0000 - val_f1_score: 0.4346 - val_AUC: 0.5000
# Epoch 31/200
# 26/26 - 8s - loss: 0.1490 - accuracy: 0.5235 - precision: 0.2762 - recall: 0.9983 - f1_score: 0.4327 - AUC: 0.7358 - val_loss: 0.7924 - val_accuracy: 0.2776 - val_precision: 0.2776 - val_recall: 1.0000 - val_f1_score: 0.4346 - val_AUC: 0.5000
# Epoch 32/200
# 26/26 - 8s - loss: 0.1621 - accuracy: 0.5051 - precision: 0.2624 - recall: 0.9860 - f1_score: 0.4145 - AUC: 0.7214 - val_loss: 0.7851 - val_accuracy: 0.2776 - val_precision: 0.2776 - val_recall: 1.0000 - val_f1_score: 0.4346 - val_AUC: 0.5000
# Epoch 33/200
# 26/26 - 8s - loss: 0.1595 - accuracy: 0.4896 - precision: 0.2583 - recall: 0.9878 - f1_score: 0.4095 - AUC: 0.7127 - val_loss: 0.7327 - val_accuracy: 0.2776 - val_precision: 0.2776 - val_recall: 1.0000 - val_f1_score: 0.4346 - val_AUC: 0.5000
# Epoch 34/200
# 26/26 - 8s - loss: 0.1938 - accuracy: 0.4506 - precision: 0.2438 - recall: 0.9809 - f1_score: 0.3906 - AUC: 0.6636 - val_loss: 0.7725 - val_accuracy: 0.2776 - val_precision: 0.2776 - val_recall: 1.0000 - val_f1_score: 0.4346 - val_AUC: 0.5000
# Epoch 35/200
# 26/26 - 8s - loss: 0.1781 - accuracy: 0.4375 - precision: 0.2486 - recall: 0.9834 - f1_score: 0.3969 - AUC: 0.6639 - val_loss: 0.7027 - val_accuracy: 0.2776 - val_precision: 0.2776 - val_recall: 1.0000 - val_f1_score: 0.4346 - val_AUC: 0.5000
# Epoch 36/200
# 26/26 - 8s - loss: 0.1612 - accuracy: 0.5092 - precision: 0.2535 - recall: 0.9373 - f1_score: 0.3991 - AUC: 0.7054 - val_loss: 0.8374 - val_accuracy: 0.2776 - val_precision: 0.2776 - val_recall: 1.0000 - val_f1_score: 0.4346 - val_AUC: 0.5000
# Epoch 37/200
# 26/26 - 8s - loss: 17.9564 - accuracy: 0.5002 - precision: 0.2375 - recall: 0.7836 - f1_score: 0.3645 - AUC: 0.6243 - val_loss: 54823080689664.0000 - val_accuracy: 0.7224 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00 - val_AUC: 0.5000
# Epoch 38/200
# 26/26 - 8s - loss: 0.2763 - accuracy: 0.4600 - precision: 0.2312 - recall: 0.8552 - f1_score: 0.3640 - AUC: 0.6322 - val_loss: 21834911744.0000 - val_accuracy: 0.7224 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00 - val_AUC: 0.5000
# Epoch 39/200
# 26/26 - 8s - loss: 0.2167 - accuracy: 0.4721 - precision: 0.1995 - recall: 0.6544 - f1_score: 0.3057 - AUC: 0.5742 - val_loss: 154769312.0000 - val_accuracy: 0.7224 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00 - val_AUC: 0.5000
# Epoch 40/200
# 26/26 - 8s - loss: 0.1903 - accuracy: 0.4254 - precision: 0.2102 - recall: 0.7725 - f1_score: 0.3304 - AUC: 0.5812 - val_loss: 4820019.0000 - val_accuracy: 0.7163 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00 - val_AUC: 0.4925
# Epoch 41/200
# 26/26 - 8s - loss: 0.1854 - accuracy: 0.4889 - precision: 0.2067 - recall: 0.6816 - f1_score: 0.3172 - AUC: 0.6046 - val_loss: 169930.4062 - val_accuracy: 0.6130 - val_precision: 0.3064 - val_recall: 0.3117 - val_f1_score: 0.3090 - val_AUC: 0.5220
# Epoch 42/200
# 26/26 - 17s - loss: 0.1817 - accuracy: 0.3805 - precision: 0.2197 - recall: 0.9534 - f1_score: 0.3571 - AUC: 0.6171 - val_loss: 13036.7969 - val_accuracy: 0.6274 - val_precision: 0.4168 - val_recall: 0.8571 - val_f1_score: 0.5609 - val_AUC: 0.6999
# Epoch 43/200
# 26/26 - 8s - loss: 0.1871 - accuracy: 0.3677 - precision: 0.2346 - recall: 0.9952 - f1_score: 0.3797 - AUC: 0.5947 - val_loss: 1665.0580 - val_accuracy: 0.5769 - val_precision: 0.3894 - val_recall: 0.9221 - val_f1_score: 0.5476 - val_AUC: 0.6830
# Epoch 44/200
# 26/26 - 8s - loss: 0.1845 - accuracy: 0.3749 - precision: 0.2153 - recall: 0.9910 - f1_score: 0.3537 - AUC: 0.6111 - val_loss: 178.8170 - val_accuracy: 0.5132 - val_precision: 0.3597 - val_recall: 0.9654 - val_f1_score: 0.5241 - val_AUC: 0.6562
# Epoch 45/200
# 26/26 - 8s - loss: 0.1799 - accuracy: 0.3649 - precision: 0.2204 - recall: 1.0000 - f1_score: 0.3611 - AUC: 0.6050 - val_loss: 14.3530 - val_accuracy: 0.4688 - val_precision: 0.3409 - val_recall: 0.9784 - val_f1_score: 0.5056 - val_AUC: 0.6264
# Epoch 46/200
# 26/26 - 8s - loss: 0.1775 - accuracy: 0.3786 - precision: 0.2232 - recall: 1.0000 - f1_score: 0.3650 - AUC: 0.6126 - val_loss: 1.0140 - val_accuracy: 0.4507 - val_precision: 0.3348 - val_recall: 0.9913 - val_f1_score: 0.5005 - val_AUC: 0.6171
# Epoch 47/200
# 26/26 - 8s - loss: 0.1713 - accuracy: 0.4272 - precision: 0.2396 - recall: 1.0000 - f1_score: 0.3865 - AUC: 0.6430 - val_loss: 0.9884 - val_accuracy: 0.4651 - val_precision: 0.3393 - val_recall: 0.9784 - val_f1_score: 0.5039 - val_AUC: 0.6264
# Epoch 48/200
# 26/26 - 8s - loss: 0.1694 - accuracy: 0.4802 - precision: 0.2570 - recall: 0.9562 - f1_score: 0.4051 - AUC: 0.6676 - val_loss: 0.6450 - val_accuracy: 0.4002 - val_precision: 0.3164 - val_recall: 1.0000 - val_f1_score: 0.4807 - val_AUC: 0.5857
# Epoch 49/200
# 26/26 - 8s - loss: 0.1682 - accuracy: 0.4378 - precision: 0.2389 - recall: 0.9982 - f1_score: 0.3856 - AUC: 0.6558 - val_loss: 0.6762 - val_accuracy: 0.4159 - val_precision: 0.3222 - val_recall: 1.0000 - val_f1_score: 0.4873 - val_AUC: 0.5982
# Epoch 50/200
# 26/26 - 8s - loss: 0.1653 - accuracy: 0.4581 - precision: 0.2485 - recall: 1.0000 - f1_score: 0.3981 - AUC: 0.6699 - val_loss: 0.7258 - val_accuracy: 0.4339 - val_precision: 0.3281 - val_recall: 0.9913 - val_f1_score: 0.4930 - val_AUC: 0.6067
# Epoch 51/200
# 26/26 - 8s - loss: 0.1736 - accuracy: 0.4609 - precision: 0.2515 - recall: 0.9983 - f1_score: 0.4018 - AUC: 0.6742 - val_loss: 204.5279 - val_accuracy: 0.5721 - val_precision: 0.3878 - val_recall: 0.9351 - val_f1_score: 0.5482 - val_AUC: 0.6863
# Epoch 52/200
# 26/26 - 8s - loss: 0.1706 - accuracy: 0.4487 - precision: 0.2474 - recall: 0.9966 - f1_score: 0.3965 - AUC: 0.6703 - val_loss: 106.8136 - val_accuracy: 0.5373 - val_precision: 0.3695 - val_recall: 0.9437 - val_f1_score: 0.5311 - val_AUC: 0.6633
# Epoch 53/200
# 26/26 - 8s - loss: 0.1677 - accuracy: 0.4515 - precision: 0.2466 - recall: 0.9948 - f1_score: 0.3952 - AUC: 0.6644 - val_loss: 32.0106 - val_accuracy: 0.5072 - val_precision: 0.3549 - val_recall: 0.9481 - val_f1_score: 0.5165 - val_AUC: 0.6455
# Epoch 54/200
# 26/26 - 8s - loss: 0.1693 - accuracy: 0.4519 - precision: 0.2461 - recall: 0.9879 - f1_score: 0.3941 - AUC: 0.6630 - val_loss: 6.7524 - val_accuracy: 0.4784 - val_precision: 0.3421 - val_recall: 0.9524 - val_f1_score: 0.5034 - val_AUC: 0.6306
# Epoch 55/200
# 26/26 - 8s - loss: 0.1671 - accuracy: 0.4513 - precision: 0.2467 - recall: 1.0000 - f1_score: 0.3958 - AUC: 0.6559 - val_loss: 2.9060 - val_accuracy: 0.4724 - val_precision: 0.3405 - val_recall: 0.9610 - val_f1_score: 0.5028 - val_AUC: 0.6261
# Epoch 56/200
# 26/26 - 8s - loss: 0.1663 - accuracy: 0.4612 - precision: 0.2523 - recall: 0.9983 - f1_score: 0.4028 - AUC: 0.6689 - val_loss: 1.7253 - val_accuracy: 0.4447 - val_precision: 0.3294 - val_recall: 0.9654 - val_f1_score: 0.4912 - val_AUC: 0.6063
# Epoch 57/200
# 26/26 - 8s - loss: 0.1674 - accuracy: 0.4497 - precision: 0.2479 - recall: 1.0000 - f1_score: 0.3973 - AUC: 0.6558 - val_loss: 1.6375 - val_accuracy: 0.4447 - val_precision: 0.3294 - val_recall: 0.9654 - val_f1_score: 0.4912 - val_AUC: 0.6047
# Epoch 58/200
# 26/26 - 8s - loss: 0.1684 - accuracy: 0.4475 - precision: 0.2401 - recall: 0.9982 - f1_score: 0.3871 - AUC: 0.6505 - val_loss: 0.9002 - val_accuracy: 0.4183 - val_precision: 0.3206 - val_recall: 0.9784 - val_f1_score: 0.4829 - val_AUC: 0.5922
# Epoch 59/200
# 26/26 - 8s - loss: 0.1666 - accuracy: 0.4631 - precision: 0.2551 - recall: 1.0000 - f1_score: 0.4065 - AUC: 0.6533 - val_loss: 0.7286 - val_accuracy: 0.3594 - val_precision: 0.3024 - val_recall: 1.0000 - val_f1_score: 0.4643 - val_AUC: 0.5566
# Epoch 60/200
# 26/26 - 8s - loss: 0.1671 - accuracy: 0.4637 - precision: 0.2515 - recall: 0.9983 - f1_score: 0.4018 - AUC: 0.6614 - val_loss: 0.7105 - val_accuracy: 0.4002 - val_precision: 0.3164 - val_recall: 1.0000 - val_f1_score: 0.4807 - val_AUC: 0.5832
# Epoch 61/200
# 26/26 - 8s - loss: 0.1734 - accuracy: 0.4232 - precision: 0.2381 - recall: 0.9983 - f1_score: 0.3844 - AUC: 0.6450 - val_loss: 0.6780 - val_accuracy: 0.4483 - val_precision: 0.3338 - val_recall: 0.9913 - val_f1_score: 0.4995 - val_AUC: 0.6163
# Epoch 62/200
# 26/26 - 8s - loss: 0.1687 - accuracy: 0.4325 - precision: 0.2387 - recall: 1.0000 - f1_score: 0.3854 - AUC: 0.6506 - val_loss: 0.9064 - val_accuracy: 0.4567 - val_precision: 0.3358 - val_recall: 0.9784 - val_f1_score: 0.5000 - val_AUC: 0.6185
# Epoch 63/200
# 26/26 - 8s - loss: 6.3597 - accuracy: 0.4422 - precision: 0.2245 - recall: 0.8768 - f1_score: 0.3575 - AUC: 0.6163 - val_loss: 127469862912.0000 - val_accuracy: 0.7224 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00 - val_AUC: 0.5000
# Epoch 64/200
# 26/26 - 8s - loss: 17.2381 - accuracy: 0.4494 - precision: 0.2161 - recall: 0.7496 - f1_score: 0.3355 - AUC: 0.5737 - val_loss: 233807806464.0000 - val_accuracy: 0.7224 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00 - val_AUC: 0.5000
# Epoch 65/200
# 26/26 - 8s - loss: 41.7546 - accuracy: 0.5061 - precision: 0.2076 - recall: 0.5973 - f1_score: 0.3082 - AUC: 0.5658 - val_loss: 12010793.0000 - val_accuracy: 0.2873 - val_precision: 0.2709 - val_recall: 0.9264 - val_f1_score: 0.4192 - val_AUC: 0.4826
# Epoch 66/200
# 26/26 - 8s - loss: 1.4728 - accuracy: 0.5145 - precision: 0.2164 - recall: 0.6522 - f1_score: 0.3250 - AUC: 0.5914 - val_loss: 1416271616.0000 - val_accuracy: 0.7224 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00 - val_AUC: 0.5000
# Epoch 67/200
# 26/26 - 8s - loss: 0.2239 - accuracy: 0.5167 - precision: 0.2145 - recall: 0.6394 - f1_score: 0.3212 - AUC: 0.5900 - val_loss: 137908000.0000 - val_accuracy: 0.7224 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00 - val_AUC: 0.5000
# Epoch 68/200
# 26/26 - 8s - loss: 0.1895 - accuracy: 0.4117 - precision: 0.2023 - recall: 0.7860 - f1_score: 0.3218 - AUC: 0.5685 - val_loss: 14733977.0000 - val_accuracy: 0.7224 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00 - val_AUC: 0.5000
# Epoch 69/200
# 26/26 - 8s - loss: 0.1890 - accuracy: 0.3306 - precision: 0.2024 - recall: 0.9174 - f1_score: 0.3317 - AUC: 0.5748 - val_loss: 1900910.0000 - val_accuracy: 0.7055 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00 - val_AUC: 0.4867
# Epoch 70/200
# 26/26 - 8s - loss: 0.1901 - accuracy: 0.3160 - precision: 0.2138 - recall: 1.0000 - f1_score: 0.3523 - AUC: 0.5661 - val_loss: 132693.0938 - val_accuracy: 0.6995 - val_precision: 0.3933 - val_recall: 0.1515 - val_f1_score: 0.2188 - val_AUC: 0.5376
# Epoch 71/200
# 26/26 - 8s - loss: 55.4796 - accuracy: 0.4141 - precision: 0.1947 - recall: 0.7576 - f1_score: 0.3098 - AUC: 0.5592 - val_loss: 85001101312.0000 - val_accuracy: 0.7224 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00 - val_AUC: 0.5000
# Epoch 72/200
# 26/26 - 8s - loss: 48.1631 - accuracy: 0.4201 - precision: 0.1945 - recall: 0.6562 - f1_score: 0.3001 - AUC: 0.5116 - val_loss: 770990720.0000 - val_accuracy: 0.7224 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00 - val_AUC: 0.5000
# Epoch 73/200
# 26/26 - 8s - loss: 25.0104 - accuracy: 0.4840 - precision: 0.1827 - recall: 0.5501 - f1_score: 0.2743 - AUC: 0.5088 - val_loss: 7713121280.0000 - val_accuracy: 0.7224 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00 - val_AUC: 0.5000
# Epoch 74/200
# 26/26 - 8s - loss: 15.4022 - accuracy: 0.4765 - precision: 0.1807 - recall: 0.5509 - f1_score: 0.2721 - AUC: 0.5280 - val_loss: 160746608.0000 - val_accuracy: 0.2776 - val_precision: 0.2776 - val_recall: 1.0000 - val_f1_score: 0.4346 - val_AUC: 0.5000
# Epoch 75/200
# 26/26 - 8s - loss: 4.1729 - accuracy: 0.4852 - precision: 0.1798 - recall: 0.5389 - f1_score: 0.2697 - AUC: 0.5187 - val_loss: 10732448.0000 - val_accuracy: 0.7224 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00 - val_AUC: 0.5000
# Epoch 76/200
# 26/26 - 8s - loss: 0.5284 - accuracy: 0.4275 - precision: 0.2002 - recall: 0.6883 - f1_score: 0.3102 - AUC: 0.5247 - val_loss: 639899.5625 - val_accuracy: 0.7224 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00 - val_AUC: 0.5000
# Epoch 77/200
# 26/26 - 8s - loss: 6.2453 - accuracy: 0.4400 - precision: 0.1887 - recall: 0.6424 - f1_score: 0.2917 - AUC: 0.5338 - val_loss: 190058.2344 - val_accuracy: 0.7224 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00 - val_AUC: 0.5000
# Epoch 78/200
# 26/26 - 8s - loss: 3.0612 - accuracy: 0.4755 - precision: 0.1812 - recall: 0.5581 - f1_score: 0.2736 - AUC: 0.5127 - val_loss: 89165.0703 - val_accuracy: 0.6887 - val_precision: 0.0333 - val_recall: 0.0043 - val_f1_score: 0.0077 - val_AUC: 0.4581
# Epoch 79/200
# 26/26 - 8s - loss: 0.2693 - accuracy: 0.4269 - precision: 0.1891 - recall: 0.6452 - f1_score: 0.2924 - AUC: 0.5262 - val_loss: 36418.2461 - val_accuracy: 0.7188 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00 - val_AUC: 0.4364
# Epoch 80/200
# 26/26 - 8s - loss: 0.2010 - accuracy: 0.4765 - precision: 0.1716 - recall: 0.5035 - f1_score: 0.2560 - AUC: 0.5050 - val_loss: 18305.0371 - val_accuracy: 0.3389 - val_precision: 0.2464 - val_recall: 0.6710 - val_f1_score: 0.3605 - val_AUC: 0.4427
# Epoch 81/200
# 26/26 - 8s - loss: 0.2182 - accuracy: 0.3646 - precision: 0.1881 - recall: 0.7586 - f1_score: 0.3015 - AUC: 0.5229 - val_loss: 10205.5840 - val_accuracy: 0.2788 - val_precision: 0.2420 - val_recall: 0.7489 - val_f1_score: 0.3658 - val_AUC: 0.4259
# Epoch 82/200
# 26/26 - 9s - loss: 0.2076 - accuracy: 0.4666 - precision: 0.1903 - recall: 0.6017 - f1_score: 0.2891 - AUC: 0.5257 - val_loss: 5984.0161 - val_accuracy: 0.2885 - val_precision: 0.2571 - val_recall: 0.8268 - val_f1_score: 0.3922 - val_AUC: 0.4538
# Epoch 83/200
# 26/26 - 8s - loss: 0.1999 - accuracy: 0.3668 - precision: 0.1908 - recall: 0.7611 - f1_score: 0.3051 - AUC: 0.5328 - val_loss: 4142.5576 - val_accuracy: 0.2825 - val_precision: 0.2560 - val_recall: 0.8312 - val_f1_score: 0.3914 - val_AUC: 0.4511
# Epoch 84/200
# 26/26 - 8s - loss: 0.1986 - accuracy: 0.4503 - precision: 0.1836 - recall: 0.6000 - f1_score: 0.2812 - AUC: 0.5249 - val_loss: 3079.0278 - val_accuracy: 0.2800 - val_precision: 0.2566 - val_recall: 0.8398 - val_f1_score: 0.3931 - val_AUC: 0.4520
# Epoch 85/200
# 26/26 - 8s - loss: 0.1979 - accuracy: 0.4808 - precision: 0.1817 - recall: 0.5445 - f1_score: 0.2725 - AUC: 0.5162 - val_loss: 2494.4871 - val_accuracy: 0.2752 - val_precision: 0.2553 - val_recall: 0.8398 - val_f1_score: 0.3915 - val_AUC: 0.4488
# Epoch 86/200
# 26/26 - 8s - loss: 0.1980 - accuracy: 0.4883 - precision: 0.1970 - recall: 0.6035 - f1_score: 0.2971 - AUC: 0.5381 - val_loss: 2018.8136 - val_accuracy: 0.2740 - val_precision: 0.2575 - val_recall: 0.8571 - val_f1_score: 0.3960 - val_AUC: 0.4535
# Epoch 87/200
# 26/26 - 8s - loss: 0.2000 - accuracy: 0.2593 - precision: 0.1950 - recall: 0.9596 - f1_score: 0.3241 - AUC: 0.5228 - val_loss: 1547.3735 - val_accuracy: 0.2728 - val_precision: 0.2590 - val_recall: 0.8701 - val_f1_score: 0.3992 - val_AUC: 0.4564
# Epoch 88/200
# 26/26 - 8s - loss: 0.1982 - accuracy: 0.3163 - precision: 0.1879 - recall: 0.8455 - f1_score: 0.3074 - AUC: 0.5467 - val_loss: 1374.7313 - val_accuracy: 0.2704 - val_precision: 0.2590 - val_recall: 0.8745 - val_f1_score: 0.3996 - val_AUC: 0.4540
# Epoch 89/200
# 26/26 - 8s - loss: 0.2003 - accuracy: 0.2518 - precision: 0.1907 - recall: 0.9656 - f1_score: 0.3185 - AUC: 0.5050 - val_loss: 1143.9465 - val_accuracy: 0.2668 - val_precision: 0.2580 - val_recall: 0.8745 - val_f1_score: 0.3984 - val_AUC: 0.4539
# Epoch 90/200
# 26/26 - 8s - loss: 0.1981 - accuracy: 0.5145 - precision: 0.1854 - recall: 0.5052 - f1_score: 0.2713 - AUC: 0.5209 - val_loss: 1084.4745 - val_accuracy: 0.2668 - val_precision: 0.2580 - val_recall: 0.8745 - val_f1_score: 0.3984 - val_AUC: 0.4537
# Epoch 91/200
# 26/26 - 8s - loss: 0.1990 - accuracy: 0.3911 - precision: 0.1905 - recall: 0.7184 - f1_score: 0.3011 - AUC: 0.5300 - val_loss: 987.8404 - val_accuracy: 0.2644 - val_precision: 0.2573 - val_recall: 0.8745 - val_f1_score: 0.3976 - val_AUC: 0.4523
# Epoch 92/200
# 26/26 - 8s - loss: 0.2014 - accuracy: 0.3736 - precision: 0.1955 - recall: 0.7508 - f1_score: 0.3102 - AUC: 0.5100 - val_loss: 852.9001 - val_accuracy: 0.2656 - val_precision: 0.2583 - val_recall: 0.8788 - val_f1_score: 0.3992 - val_AUC: 0.4541
# Epoch 93/200
# 26/26 - 8s - loss: 0.1942 - accuracy: 0.2502 - precision: 0.1782 - recall: 0.9520 - f1_score: 0.3002 - AUC: 0.5210 - val_loss: 799.7504 - val_accuracy: 0.2644 - val_precision: 0.2586 - val_recall: 0.8831 - val_f1_score: 0.4000 - val_AUC: 0.4553
# Epoch 94/200
# 26/26 - 8s - loss: 0.1990 - accuracy: 0.2954 - precision: 0.1921 - recall: 0.9083 - f1_score: 0.3171 - AUC: 0.5320 - val_loss: 813.4576 - val_accuracy: 0.2644 - val_precision: 0.2586 - val_recall: 0.8831 - val_f1_score: 0.4000 - val_AUC: 0.4553
# Epoch 95/200
# 26/26 - 8s - loss: 0.1998 - accuracy: 0.2437 - precision: 0.1943 - recall: 0.9848 - f1_score: 0.3245 - AUC: 0.5229 - val_loss: 853.1774 - val_accuracy: 0.2656 - val_precision: 0.2589 - val_recall: 0.8831 - val_f1_score: 0.4004 - val_AUC: 0.4540
# Epoch 96/200
# 26/26 - 8s - loss: 0.1961 - accuracy: 0.3057 - precision: 0.1873 - recall: 0.8814 - f1_score: 0.3089 - AUC: 0.5364 - val_loss: 798.9242 - val_accuracy: 0.2656 - val_precision: 0.2589 - val_recall: 0.8831 - val_f1_score: 0.4004 - val_AUC: 0.4553
# Epoch 97/200
# 26/26 - 8s - loss: 0.1995 - accuracy: 0.3646 - precision: 0.1930 - recall: 0.7755 - f1_score: 0.3090 - AUC: 0.5269 - val_loss: 770.1801 - val_accuracy: 0.2644 - val_precision: 0.2586 - val_recall: 0.8831 - val_f1_score: 0.4000 - val_AUC: 0.4546
# Epoch 98/200
# 26/26 - 8s - loss: 0.1998 - accuracy: 0.3496 - precision: 0.1907 - recall: 0.7857 - f1_score: 0.3069 - AUC: 0.5260 - val_loss: 889.4278 - val_accuracy: 0.2632 - val_precision: 0.2570 - val_recall: 0.8745 - val_f1_score: 0.3972 - val_AUC: 0.4520
# Epoch 99/200
# 26/26 - 8s - loss: 0.1986 - accuracy: 0.3253 - precision: 0.1953 - recall: 0.8635 - f1_score: 0.3185 - AUC: 0.5485 - val_loss: 933.0917 - val_accuracy: 0.2644 - val_precision: 0.2573 - val_recall: 0.8745 - val_f1_score: 0.3976 - val_AUC: 0.4522
# Epoch 100/200
# 26/26 - 8s - loss: 0.1958 - accuracy: 0.3203 - precision: 0.1741 - recall: 0.7880 - f1_score: 0.2852 - AUC: 0.5068 - val_loss: 882.2656 - val_accuracy: 0.2644 - val_precision: 0.2573 - val_recall: 0.8745 - val_f1_score: 0.3976 - val_AUC: 0.4521
# Epoch 101/200
# 26/26 - 8s - loss: 0.1999 - accuracy: 0.3260 - precision: 0.1973 - recall: 0.8469 - f1_score: 0.3200 - AUC: 0.5247 - val_loss: 982.0424 - val_accuracy: 0.2644 - val_precision: 0.2573 - val_recall: 0.8745 - val_f1_score: 0.3976 - val_AUC: 0.4522
# Epoch 102/200
# 26/26 - 8s - loss: 0.3001 - accuracy: 0.2555 - precision: 0.1888 - recall: 0.9770 - f1_score: 0.3165 - AUC: 0.5564 - val_loss: 797.1650 - val_accuracy: 0.3005 - val_precision: 0.2735 - val_recall: 0.9177 - val_f1_score: 0.4215 - val_AUC: 0.4522
# Epoch 103/200
# 26/26 - 8s - loss: 1.6740 - accuracy: 0.4098 - precision: 0.1826 - recall: 0.6580 - f1_score: 0.2858 - AUC: 0.5237 - val_loss: 0.7614 - val_accuracy: 0.7224 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00 - val_AUC: 0.5190
# Epoch 104/200
# 26/26 - 8s - loss: 21.2176 - accuracy: 0.4466 - precision: 0.1861 - recall: 0.6034 - f1_score: 0.2844 - AUC: 0.5165 - val_loss: 0.6722 - val_accuracy: 0.7224 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00 - val_AUC: 0.5000
# Epoch 105/200
# 26/26 - 8s - loss: 16.3101 - accuracy: 0.5238 - precision: 0.1818 - recall: 0.4773 - f1_score: 0.2633 - AUC: 0.5234 - val_loss: 0.7735 - val_accuracy: 0.2776 - val_precision: 0.2776 - val_recall: 1.0000 - val_f1_score: 0.4346 - val_AUC: 0.5000
# Epoch 106/200
# 26/26 - 8s - loss: 13.4660 - accuracy: 0.4877 - precision: 0.1828 - recall: 0.5302 - f1_score: 0.2719 - AUC: 0.5011 - val_loss: 39066.8047 - val_accuracy: 0.7236 - val_precision: 0.6667 - val_recall: 0.0087 - val_f1_score: 0.0171 - val_AUC: 0.5057
# Epoch 107/200
# 26/26 - 8s - loss: 7.9663 - accuracy: 0.4519 - precision: 0.1947 - recall: 0.6432 - f1_score: 0.2989 - AUC: 0.5380 - val_loss: 201860.6094 - val_accuracy: 0.7296 - val_precision: 0.5263 - val_recall: 0.2597 - val_f1_score: 0.3478 - val_AUC: 0.5869
# Epoch 108/200
# 26/26 - 8s - loss: 0.2056 - accuracy: 0.2537 - precision: 0.1929 - recall: 0.9896 - f1_score: 0.3229 - AUC: 0.5287 - val_loss: 18811.9336 - val_accuracy: 0.5913 - val_precision: 0.3482 - val_recall: 0.5411 - val_f1_score: 0.4237 - val_AUC: 0.5761
# Epoch 109/200
# 26/26 - 8s - loss: 0.2077 - accuracy: 0.4489 - precision: 0.2011 - recall: 0.6917 - f1_score: 0.3116 - AUC: 0.5530 - val_loss: 852.8809 - val_accuracy: 0.4591 - val_precision: 0.3259 - val_recall: 0.8874 - val_f1_score: 0.4767 - val_AUC: 0.5913
# Epoch 110/200
# 26/26 - 8s - loss: 0.2070 - accuracy: 0.2720 - precision: 0.1941 - recall: 0.9603 - f1_score: 0.3229 - AUC: 0.5452 - val_loss: 26.8858 - val_accuracy: 0.3149 - val_precision: 0.2857 - val_recall: 0.9784 - val_f1_score: 0.4423 - val_AUC: 0.5183
# Epoch 111/200
# 26/26 - 8s - loss: 0.2057 - accuracy: 0.2456 - precision: 0.1912 - recall: 0.9965 - f1_score: 0.3209 - AUC: 0.5238 - val_loss: 3.0974 - val_accuracy: 0.2897 - val_precision: 0.2805 - val_recall: 0.9957 - val_f1_score: 0.4377 - val_AUC: 0.5062
# Epoch 112/200
# 26/26 - 8s - loss: 0.1982 - accuracy: 0.3017 - precision: 0.1930 - recall: 0.8937 - f1_score: 0.3174 - AUC: 0.5151 - val_loss: 1.6578 - val_accuracy: 0.2885 - val_precision: 0.2801 - val_recall: 0.9957 - val_f1_score: 0.4373 - val_AUC: 0.5062
# Epoch 113/200
# 26/26 - 8s - loss: 0.2094 - accuracy: 0.2415 - precision: 0.1920 - recall: 0.9983 - f1_score: 0.3220 - AUC: 0.5375 - val_loss: 0.7143 - val_accuracy: 0.2885 - val_precision: 0.2801 - val_recall: 0.9957 - val_f1_score: 0.4373 - val_AUC: 0.5062
# Epoch 114/200
# 26/26 - 8s - loss: 0.1997 - accuracy: 0.3422 - precision: 0.1880 - recall: 0.8066 - f1_score: 0.3049 - AUC: 0.5466 - val_loss: 0.6929 - val_accuracy: 0.2885 - val_precision: 0.2801 - val_recall: 0.9957 - val_f1_score: 0.4373 - val_AUC: 0.5062
# Epoch 115/200
# 26/26 - 8s - loss: 0.1963 - accuracy: 0.2568 - precision: 0.1842 - recall: 0.9483 - f1_score: 0.3085 - AUC: 0.5193 - val_loss: 0.6972 - val_accuracy: 0.2897 - val_precision: 0.2810 - val_recall: 1.0000 - val_f1_score: 0.4387 - val_AUC: 0.5083
# Epoch 116/200
# 26/26 - 8s - loss: 0.3748 - accuracy: 0.2907 - precision: 0.2066 - recall: 0.9966 - f1_score: 0.3422 - AUC: 0.5600 - val_loss: 0.7126 - val_accuracy: 0.2776 - val_precision: 0.2776 - val_recall: 1.0000 - val_f1_score: 0.4346 - val_AUC: 0.5000
# Epoch 117/200
# 26/26 - 8s - loss: 0.2850 - accuracy: 0.3537 - precision: 0.2033 - recall: 0.8765 - f1_score: 0.3301 - AUC: 0.5596 - val_loss: 0.7080 - val_accuracy: 0.2776 - val_precision: 0.2776 - val_recall: 1.0000 - val_f1_score: 0.4346 - val_AUC: 0.5000
# Epoch 118/200
# 26/26 - 8s - loss: 0.2041 - accuracy: 0.4085 - precision: 0.2028 - recall: 0.7715 - f1_score: 0.3212 - AUC: 0.5693 - val_loss: 0.7290 - val_accuracy: 0.2776 - val_precision: 0.2776 - val_recall: 1.0000 - val_f1_score: 0.4346 - val_AUC: 0.5000
# Epoch 119/200
# 26/26 - 8s - loss: 0.1892 - accuracy: 0.2914 - precision: 0.1982 - recall: 0.9929 - f1_score: 0.3304 - AUC: 0.5704 - val_loss: 0.7027 - val_accuracy: 0.2825 - val_precision: 0.2790 - val_recall: 1.0000 - val_f1_score: 0.4363 - val_AUC: 0.5033
# Epoch 120/200
# 26/26 - 8s - loss: 0.1888 - accuracy: 0.3440 - precision: 0.2064 - recall: 0.9177 - f1_score: 0.3370 - AUC: 0.5708 - val_loss: 0.6028 - val_accuracy: 0.7224 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00 - val_AUC: 0.5042
# Epoch 121/200
# 26/26 - 8s - loss: 0.2009 - accuracy: 0.3266 - precision: 0.2122 - recall: 0.9747 - f1_score: 0.3485 - AUC: 0.5685 - val_loss: 0.7513 - val_accuracy: 0.3077 - val_precision: 0.2857 - val_recall: 0.9957 - val_f1_score: 0.4440 - val_AUC: 0.5379
# Epoch 122/200
# 26/26 - 8s - loss: 0.1915 - accuracy: 0.3372 - precision: 0.1964 - recall: 0.8730 - f1_score: 0.3207 - AUC: 0.5608 - val_loss: 0.7140 - val_accuracy: 0.3017 - val_precision: 0.2845 - val_recall: 1.0000 - val_f1_score: 0.4430 - val_AUC: 0.5166
# Epoch 123/200
# 26/26 - 8s - loss: 0.1902 - accuracy: 0.2988 - precision: 0.2052 - recall: 1.0000 - f1_score: 0.3406 - AUC: 0.5732 - val_loss: 0.6994 - val_accuracy: 0.3029 - val_precision: 0.2848 - val_recall: 1.0000 - val_f1_score: 0.4434 - val_AUC: 0.5175
# Epoch 124/200
# 26/26 - 8s - loss: 0.1880 - accuracy: 0.3228 - precision: 0.2124 - recall: 1.0000 - f1_score: 0.3504 - AUC: 0.5873 - val_loss: 0.7196 - val_accuracy: 0.3149 - val_precision: 0.2884 - val_recall: 1.0000 - val_f1_score: 0.4477 - val_AUC: 0.5258
# Epoch 125/200
# 26/26 - 8s - loss: 0.1897 - accuracy: 0.3443 - precision: 0.1945 - recall: 0.8752 - f1_score: 0.3182 - AUC: 0.5717 - val_loss: 0.6732 - val_accuracy: 0.7224 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00 - val_AUC: 0.5200
# Epoch 126/200
# 26/26 - 8s - loss: 0.1930 - accuracy: 0.3288 - precision: 0.2081 - recall: 0.9360 - f1_score: 0.3405 - AUC: 0.5657 - val_loss: 0.7507 - val_accuracy: 0.3065 - val_precision: 0.2859 - val_recall: 1.0000 - val_f1_score: 0.4447 - val_AUC: 0.5200
# Epoch 127/200
# 26/26 - 8s - loss: 0.1919 - accuracy: 0.3144 - precision: 0.2032 - recall: 0.9469 - f1_score: 0.3345 - AUC: 0.5725 - val_loss: 0.7261 - val_accuracy: 0.3065 - val_precision: 0.2859 - val_recall: 1.0000 - val_f1_score: 0.4447 - val_AUC: 0.5200
# Epoch 128/200
# 26/26 - 8s - loss: 0.1887 - accuracy: 0.3415 - precision: 0.1954 - recall: 0.8828 - f1_score: 0.3199 - AUC: 0.5683 - val_loss: 0.6959 - val_accuracy: 0.3065 - val_precision: 0.2859 - val_recall: 1.0000 - val_f1_score: 0.4447 - val_AUC: 0.5200
# Epoch 129/200
# 26/26 - 8s - loss: 0.1899 - accuracy: 0.3316 - precision: 0.2064 - recall: 0.9417 - f1_score: 0.3386 - AUC: 0.5819 - val_loss: 0.7106 - val_accuracy: 0.3149 - val_precision: 0.2884 - val_recall: 1.0000 - val_f1_score: 0.4477 - val_AUC: 0.5266
# Epoch 130/200
# 26/26 - 8s - loss: 0.1928 - accuracy: 0.2973 - precision: 0.2038 - recall: 0.9983 - f1_score: 0.3385 - AUC: 0.5520 - val_loss: 0.7034 - val_accuracy: 0.3137 - val_precision: 0.2880 - val_recall: 1.0000 - val_f1_score: 0.4472 - val_AUC: 0.5258
# Epoch 131/200
# 26/26 - 8s - loss: 0.1862 - accuracy: 0.3188 - precision: 0.2020 - recall: 0.9769 - f1_score: 0.3348 - AUC: 0.5755 - val_loss: 0.6585 - val_accuracy: 0.7224 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00 - val_AUC: 0.5300
# Epoch 132/200
# 26/26 - 8s - loss: 0.2068 - accuracy: 0.3331 - precision: 0.2049 - recall: 0.9247 - f1_score: 0.3354 - AUC: 0.5672 - val_loss: 0.7098 - val_accuracy: 0.3017 - val_precision: 0.2845 - val_recall: 1.0000 - val_f1_score: 0.4430 - val_AUC: 0.5175
# Epoch 133/200
# 26/26 - 8s - loss: 0.1935 - accuracy: 0.3241 - precision: 0.2054 - recall: 0.9355 - f1_score: 0.3369 - AUC: 0.5485 - val_loss: 0.7239 - val_accuracy: 0.3017 - val_precision: 0.2845 - val_recall: 1.0000 - val_f1_score: 0.4430 - val_AUC: 0.5166
# Epoch 134/200
# 26/26 - 8s - loss: 0.1913 - accuracy: 0.2858 - precision: 0.2008 - recall: 1.0000 - f1_score: 0.3345 - AUC: 0.5488 - val_loss: 0.7002 - val_accuracy: 0.3041 - val_precision: 0.2852 - val_recall: 1.0000 - val_f1_score: 0.4438 - val_AUC: 0.5183
# Epoch 135/200
# 26/26 - 8s - loss: 0.1896 - accuracy: 0.3275 - precision: 0.2096 - recall: 0.9726 - f1_score: 0.3449 - AUC: 0.5619 - val_loss: 0.7262 - val_accuracy: 0.3053 - val_precision: 0.2855 - val_recall: 1.0000 - val_f1_score: 0.4442 - val_AUC: 0.5200
# Epoch 136/200
# 26/26 - 8s - loss: 0.2278 - accuracy: 0.3131 - precision: 0.2082 - recall: 0.9983 - f1_score: 0.3446 - AUC: 0.5646 - val_loss: 0.7178 - val_accuracy: 0.2981 - val_precision: 0.2834 - val_recall: 1.0000 - val_f1_score: 0.4417 - val_AUC: 0.5141
# Epoch 137/200
# 26/26 - 8s - loss: 0.1934 - accuracy: 0.2839 - precision: 0.1997 - recall: 0.9845 - f1_score: 0.3320 - AUC: 0.5472 - val_loss: 0.7056 - val_accuracy: 0.2981 - val_precision: 0.2834 - val_recall: 1.0000 - val_f1_score: 0.4417 - val_AUC: 0.5141
# Epoch 138/200
# 26/26 - 8s - loss: 0.1902 - accuracy: 0.2839 - precision: 0.1964 - recall: 0.9947 - f1_score: 0.3281 - AUC: 0.5574 - val_loss: 0.7150 - val_accuracy: 0.2981 - val_precision: 0.2834 - val_recall: 1.0000 - val_f1_score: 0.4417 - val_AUC: 0.5150
# Epoch 139/200
# 26/26 - 8s - loss: 4.1910 - accuracy: 0.4098 - precision: 0.1999 - recall: 0.7398 - f1_score: 0.3148 - AUC: 0.5399 - val_loss: 2.7886 - val_accuracy: 0.4471 - val_precision: 0.2777 - val_recall: 0.6190 - val_f1_score: 0.3834 - val_AUC: 0.5118
# Epoch 140/200
# 26/26 - 8s - loss: 0.1931 - accuracy: 0.2917 - precision: 0.2007 - recall: 0.9742 - f1_score: 0.3328 - AUC: 0.5376 - val_loss: 0.7428 - val_accuracy: 0.4363 - val_precision: 0.3265 - val_recall: 0.9697 - val_f1_score: 0.4885 - val_AUC: 0.6011
# Epoch 141/200
# 26/26 - 8s - loss: 0.1919 - accuracy: 0.2861 - precision: 0.2013 - recall: 0.9983 - f1_score: 0.3350 - AUC: 0.5542 - val_loss: 0.6645 - val_accuracy: 0.3690 - val_precision: 0.3056 - val_recall: 1.0000 - val_f1_score: 0.4681 - val_AUC: 0.5715
# Epoch 142/200
# 26/26 - 8s - loss: 0.1944 - accuracy: 0.2861 - precision: 0.2070 - recall: 1.0000 - f1_score: 0.3430 - AUC: 0.5570 - val_loss: 0.6976 - val_accuracy: 0.3365 - val_precision: 0.2950 - val_recall: 1.0000 - val_f1_score: 0.4556 - val_AUC: 0.5424
# Epoch 143/200
# 26/26 - 8s - loss: 25.5189 - accuracy: 0.3048 - precision: 0.1846 - recall: 0.8668 - f1_score: 0.3043 - AUC: 0.5160 - val_loss: 0.7372 - val_accuracy: 0.2776 - val_precision: 0.2776 - val_recall: 1.0000 - val_f1_score: 0.4346 - val_AUC: 0.5027
# Epoch 144/200
# 26/26 - 8s - loss: 6.5533 - accuracy: 0.4419 - precision: 0.1797 - recall: 0.5815 - f1_score: 0.2746 - AUC: 0.5025 - val_loss: 25.2006 - val_accuracy: 0.6611 - val_precision: 0.1852 - val_recall: 0.0649 - val_f1_score: 0.0962 - val_AUC: 0.4953
# Epoch 145/200
# 26/26 - 8s - loss: 1.9673 - accuracy: 0.4434 - precision: 0.1853 - recall: 0.6394 - f1_score: 0.2873 - AUC: 0.5310 - val_loss: 272.4811 - val_accuracy: 0.6034 - val_precision: 0.3408 - val_recall: 0.4589 - val_f1_score: 0.3911 - val_AUC: 0.5632
# Epoch 146/200
# 26/26 - 8s - loss: 0.3768 - accuracy: 0.3696 - precision: 0.2039 - recall: 0.8462 - f1_score: 0.3286 - AUC: 0.5591 - val_loss: 547.1365 - val_accuracy: 0.6406 - val_precision: 0.2703 - val_recall: 0.1732 - val_f1_score: 0.2111 - val_AUC: 0.4951
# Epoch 147/200
# 26/26 - 8s - loss: 0.2036 - accuracy: 0.4017 - precision: 0.1960 - recall: 0.7448 - f1_score: 0.3103 - AUC: 0.5415 - val_loss: 109.8077 - val_accuracy: 0.6106 - val_precision: 0.3218 - val_recall: 0.3636 - val_f1_score: 0.3415 - val_AUC: 0.5161
# Epoch 148/200
# 26/26 - 8s - loss: 0.1957 - accuracy: 0.3110 - precision: 0.1987 - recall: 0.9292 - f1_score: 0.3274 - AUC: 0.5423 - val_loss: 19.8674 - val_accuracy: 0.5565 - val_precision: 0.3029 - val_recall: 0.4589 - val_f1_score: 0.3649 - val_AUC: 0.5383
# Epoch 149/200
# 26/26 - 8s - loss: 0.1994 - accuracy: 0.3792 - precision: 0.1978 - recall: 0.8024 - f1_score: 0.3173 - AUC: 0.5583 - val_loss: 9.5543 - val_accuracy: 0.4760 - val_precision: 0.3048 - val_recall: 0.6926 - val_f1_score: 0.4233 - val_AUC: 0.5419
# Epoch 150/200
# 26/26 - 8s - loss: 0.1986 - accuracy: 0.2836 - precision: 0.2005 - recall: 0.9965 - f1_score: 0.3338 - AUC: 0.5559 - val_loss: 0.7520 - val_accuracy: 0.3978 - val_precision: 0.3093 - val_recall: 0.9481 - val_f1_score: 0.4665 - val_AUC: 0.5760
# Epoch 151/200
# 26/26 - 8s - loss: 0.1921 - accuracy: 0.3325 - precision: 0.2011 - recall: 0.9100 - f1_score: 0.3294 - AUC: 0.5568 - val_loss: 0.6425 - val_accuracy: 0.3834 - val_precision: 0.3095 - val_recall: 0.9913 - val_f1_score: 0.4717 - val_AUC: 0.5687
# Epoch 152/200
# 26/26 - 8s - loss: 0.1961 - accuracy: 0.2982 - precision: 0.2087 - recall: 0.9933 - f1_score: 0.3450 - AUC: 0.5636 - val_loss: 0.6766 - val_accuracy: 0.3762 - val_precision: 0.3080 - val_recall: 1.0000 - val_f1_score: 0.4709 - val_AUC: 0.5657
# Epoch 153/200
# 26/26 - 8s - loss: 0.1897 - accuracy: 0.3375 - precision: 0.1956 - recall: 0.8836 - f1_score: 0.3203 - AUC: 0.5580 - val_loss: 0.6684 - val_accuracy: 0.3714 - val_precision: 0.3064 - val_recall: 1.0000 - val_f1_score: 0.4690 - val_AUC: 0.5666
# Epoch 154/200
# 26/26 - 8s - loss: 0.1900 - accuracy: 0.3060 - precision: 0.2089 - recall: 1.0000 - f1_score: 0.3456 - AUC: 0.5832 - val_loss: 0.6559 - val_accuracy: 0.3666 - val_precision: 0.3047 - val_recall: 1.0000 - val_f1_score: 0.4671 - val_AUC: 0.5632
# Epoch 155/200
# 26/26 - 8s - loss: 0.1942 - accuracy: 0.2998 - precision: 0.2073 - recall: 0.9966 - f1_score: 0.3432 - AUC: 0.5772 - val_loss: 0.6850 - val_accuracy: 0.3558 - val_precision: 0.3012 - val_recall: 1.0000 - val_f1_score: 0.4629 - val_AUC: 0.5574
# Epoch 156/200
# 26/26 - 8s - loss: 0.1896 - accuracy: 0.3858 - precision: 0.1959 - recall: 0.8154 - f1_score: 0.3159 - AUC: 0.5589 - val_loss: 0.6663 - val_accuracy: 0.3630 - val_precision: 0.3035 - val_recall: 1.0000 - val_f1_score: 0.4657 - val_AUC: 0.5591
# Epoch 157/200
# 26/26 - 8s - loss: 0.1900 - accuracy: 0.3334 - precision: 0.1981 - recall: 0.8986 - f1_score: 0.3246 - AUC: 0.5622 - val_loss: 0.6310 - val_accuracy: 0.7224 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00 - val_AUC: 0.5591
# Epoch 158/200
# 26/26 - 8s - loss: 0.2018 - accuracy: 0.3182 - precision: 0.2023 - recall: 0.9464 - f1_score: 0.3333 - AUC: 0.5604 - val_loss: 0.6830 - val_accuracy: 0.3389 - val_precision: 0.2958 - val_recall: 1.0000 - val_f1_score: 0.4565 - val_AUC: 0.5433
# Epoch 159/200
# 26/26 - 8s - loss: 0.1944 - accuracy: 0.3069 - precision: 0.2121 - recall: 0.9950 - f1_score: 0.3497 - AUC: 0.5662 - val_loss: 0.6928 - val_accuracy: 0.3401 - val_precision: 0.2962 - val_recall: 1.0000 - val_f1_score: 0.4570 - val_AUC: 0.5499
# Epoch 160/200
# 26/26 - 8s - loss: 0.1875 - accuracy: 0.2979 - precision: 0.1988 - recall: 1.0000 - f1_score: 0.3317 - AUC: 0.5710 - val_loss: 0.6709 - val_accuracy: 0.3498 - val_precision: 0.2992 - val_recall: 1.0000 - val_f1_score: 0.4606 - val_AUC: 0.5507
# Epoch 161/200
# 26/26 - 8s - loss: 0.2038 - accuracy: 0.2904 - precision: 0.2025 - recall: 0.9931 - f1_score: 0.3363 - AUC: 0.5719 - val_loss: 0.6578 - val_accuracy: 0.3810 - val_precision: 0.3097 - val_recall: 1.0000 - val_f1_score: 0.4729 - val_AUC: 0.5732
# Epoch 162/200
# 26/26 - 8s - loss: 0.1953 - accuracy: 0.2798 - precision: 0.2015 - recall: 0.9983 - f1_score: 0.3353 - AUC: 0.5492 - val_loss: 0.6580 - val_accuracy: 0.3726 - val_precision: 0.3068 - val_recall: 1.0000 - val_f1_score: 0.4695 - val_AUC: 0.5666
# Epoch 163/200
# 26/26 - 9s - loss: 0.1944 - accuracy: 0.2984 - precision: 0.1989 - recall: 0.9550 - f1_score: 0.3292 - AUC: 0.5555 - val_loss: 0.6269 - val_accuracy: 0.7224 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00 - val_AUC: 0.5624
# Epoch 164/200
# 26/26 - 8s - loss: 0.1948 - accuracy: 0.3605 - precision: 0.1972 - recall: 0.8244 - f1_score: 0.3183 - AUC: 0.5618 - val_loss: 0.6647 - val_accuracy: 0.3642 - val_precision: 0.3039 - val_recall: 1.0000 - val_f1_score: 0.4662 - val_AUC: 0.5607
# Epoch 165/200
# 26/26 - 8s - loss: 0.1930 - accuracy: 0.2973 - precision: 0.1989 - recall: 0.9601 - f1_score: 0.3295 - AUC: 0.5507 - val_loss: 0.6808 - val_accuracy: 0.3558 - val_precision: 0.3012 - val_recall: 1.0000 - val_f1_score: 0.4629 - val_AUC: 0.5549
# Epoch 166/200
# 26/26 - 8s - loss: 0.1930 - accuracy: 0.3615 - precision: 0.1953 - recall: 0.8194 - f1_score: 0.3154 - AUC: 0.5547 - val_loss: 0.6565 - val_accuracy: 0.3570 - val_precision: 0.3016 - val_recall: 1.0000 - val_f1_score: 0.4634 - val_AUC: 0.5549
# Epoch 167/200
# 26/26 - 8s - loss: 0.1967 - accuracy: 0.2914 - precision: 0.2016 - recall: 0.9578 - f1_score: 0.3331 - AUC: 0.5691 - val_loss: 0.6780 - val_accuracy: 0.3438 - val_precision: 0.2973 - val_recall: 1.0000 - val_f1_score: 0.4583 - val_AUC: 0.5557
# Epoch 168/200
# 26/26 - 8s - loss: 0.2164 - accuracy: 0.4880 - precision: 0.2031 - recall: 0.6439 - f1_score: 0.3088 - AUC: 0.5665 - val_loss: 0.7029 - val_accuracy: 0.3546 - val_precision: 0.3008 - val_recall: 1.0000 - val_f1_score: 0.4625 - val_AUC: 0.5607
# Epoch 169/200
# 26/26 - 9s - loss: 0.1912 - accuracy: 0.3842 - precision: 0.2056 - recall: 0.8322 - f1_score: 0.3297 - AUC: 0.5753 - val_loss: 0.6882 - val_accuracy: 0.3666 - val_precision: 0.3047 - val_recall: 1.0000 - val_f1_score: 0.4671 - val_AUC: 0.5624
# Epoch 170/200
# 26/26 - 8s - loss: 0.4337 - accuracy: 0.3110 - precision: 0.1930 - recall: 0.9268 - f1_score: 0.3195 - AUC: 0.5463 - val_loss: 2.7762 - val_accuracy: 0.3990 - val_precision: 0.3124 - val_recall: 0.9697 - val_f1_score: 0.4726 - val_AUC: 0.5823
# Epoch 171/200
# 26/26 - 8s - loss: 0.1995 - accuracy: 0.3422 - precision: 0.2070 - recall: 0.8915 - f1_score: 0.3360 - AUC: 0.5484 - val_loss: 1.4121 - val_accuracy: 0.3582 - val_precision: 0.3014 - val_recall: 0.9957 - val_f1_score: 0.4628 - val_AUC: 0.5544
# Epoch 172/200
# 26/26 - 8s - loss: 0.1936 - accuracy: 0.3777 - precision: 0.1991 - recall: 0.8160 - f1_score: 0.3201 - AUC: 0.5579 - val_loss: 1.1542 - val_accuracy: 0.3425 - val_precision: 0.2964 - val_recall: 0.9957 - val_f1_score: 0.4568 - val_AUC: 0.5435
# Epoch 173/200
# 26/26 - 8s - loss: 0.1897 - accuracy: 0.3188 - precision: 0.2062 - recall: 0.9623 - f1_score: 0.3396 - AUC: 0.5920 - val_loss: 1.1155 - val_accuracy: 0.3425 - val_precision: 0.2964 - val_recall: 0.9957 - val_f1_score: 0.4568 - val_AUC: 0.5444
# Epoch 174/200
# 26/26 - 8s - loss: 0.1862 - accuracy: 0.3210 - precision: 0.1957 - recall: 0.9405 - f1_score: 0.3239 - AUC: 0.5580 - val_loss: 1.0467 - val_accuracy: 0.3425 - val_precision: 0.2964 - val_recall: 0.9957 - val_f1_score: 0.4568 - val_AUC: 0.5436
# Epoch 175/200
# 26/26 - 8s - loss: 0.1932 - accuracy: 0.3094 - precision: 0.2117 - recall: 0.9867 - f1_score: 0.3486 - AUC: 0.5673 - val_loss: 1.0413 - val_accuracy: 0.3474 - val_precision: 0.2979 - val_recall: 0.9957 - val_f1_score: 0.4586 - val_AUC: 0.5477
# Epoch 176/200
# 26/26 - 8s - loss: 0.1868 - accuracy: 0.3063 - precision: 0.2000 - recall: 0.9893 - f1_score: 0.3327 - AUC: 0.5607 - val_loss: 1.0913 - val_accuracy: 0.3510 - val_precision: 0.2991 - val_recall: 0.9957 - val_f1_score: 0.4600 - val_AUC: 0.5494
# Epoch 177/200
# 26/26 - 8s - loss: 0.2062 - accuracy: 0.3129 - precision: 0.2137 - recall: 0.9983 - f1_score: 0.3520 - AUC: 0.5579 - val_loss: 1.4523 - val_accuracy: 0.3389 - val_precision: 0.2953 - val_recall: 0.9957 - val_f1_score: 0.4554 - val_AUC: 0.5386
# Epoch 178/200
# 26/26 - 8s - loss: 0.2534 - accuracy: 0.2904 - precision: 0.2023 - recall: 0.9965 - f1_score: 0.3363 - AUC: 0.5642 - val_loss: 0.9796 - val_accuracy: 0.3185 - val_precision: 0.2889 - val_recall: 0.9957 - val_f1_score: 0.4479 - val_AUC: 0.5278
# Epoch 179/200
# 26/26 - 8s - loss: 0.1884 - accuracy: 0.3334 - precision: 0.1906 - recall: 0.8793 - f1_score: 0.3133 - AUC: 0.5673 - val_loss: 1.0115 - val_accuracy: 0.3341 - val_precision: 0.2937 - val_recall: 0.9957 - val_f1_score: 0.4536 - val_AUC: 0.5402
# Epoch 180/200
# 26/26 - 8s - loss: 0.1936 - accuracy: 0.2942 - precision: 0.2091 - recall: 1.0000 - f1_score: 0.3459 - AUC: 0.5498 - val_loss: 1.0453 - val_accuracy: 0.3438 - val_precision: 0.2968 - val_recall: 0.9957 - val_f1_score: 0.4573 - val_AUC: 0.5444
# Epoch 181/200
# 26/26 - 8s - loss: 0.3088 - accuracy: 0.3082 - precision: 0.2036 - recall: 0.9690 - f1_score: 0.3365 - AUC: 0.5702 - val_loss: 1.1362 - val_accuracy: 0.3606 - val_precision: 0.3022 - val_recall: 0.9957 - val_f1_score: 0.4637 - val_AUC: 0.5585
# Epoch 182/200
# 26/26 - 8s - loss: 0.1875 - accuracy: 0.3151 - precision: 0.2088 - recall: 1.0000 - f1_score: 0.3454 - AUC: 0.5846 - val_loss: 1.7545 - val_accuracy: 0.3894 - val_precision: 0.3121 - val_recall: 0.9957 - val_f1_score: 0.4752 - val_AUC: 0.5785
# Epoch 183/200
# 26/26 - 8s - loss: 0.1890 - accuracy: 0.3431 - precision: 0.2137 - recall: 0.9948 - f1_score: 0.3518 - AUC: 0.5881 - val_loss: 1.7347 - val_accuracy: 0.4050 - val_precision: 0.3177 - val_recall: 0.9957 - val_f1_score: 0.4817 - val_AUC: 0.5893
# Epoch 184/200
# 26/26 - 8s - loss: 0.1964 - accuracy: 0.3160 - precision: 0.2056 - recall: 0.9982 - f1_score: 0.3410 - AUC: 0.5787 - val_loss: 1.4949 - val_accuracy: 0.3606 - val_precision: 0.3022 - val_recall: 0.9957 - val_f1_score: 0.4637 - val_AUC: 0.5552
# Epoch 185/200
# 26/26 - 8s - loss: 0.1863 - accuracy: 0.4011 - precision: 0.2147 - recall: 0.8707 - f1_score: 0.3445 - AUC: 0.5791 - val_loss: 1.6317 - val_accuracy: 0.3690 - val_precision: 0.3050 - val_recall: 0.9957 - val_f1_score: 0.4670 - val_AUC: 0.5619
# Epoch 186/200
# 26/26 - 8s - loss: 0.1868 - accuracy: 0.3515 - precision: 0.2194 - recall: 0.9831 - f1_score: 0.3587 - AUC: 0.5805 - val_loss: 1.5834 - val_accuracy: 0.3702 - val_precision: 0.3054 - val_recall: 0.9957 - val_f1_score: 0.4675 - val_AUC: 0.5635
# Epoch 187/200
# 26/26 - 17s - loss: 3.0527 - accuracy: 0.3568 - precision: 0.2129 - recall: 0.9600 - f1_score: 0.3485 - AUC: 0.5966 - val_loss: 18.5071 - val_accuracy: 0.6767 - val_precision: 0.4568 - val_recall: 0.8701 - val_f1_score: 0.5991 - val_AUC: 0.7345
# Epoch 188/200
# 26/26 - 8s - loss: 0.8264 - accuracy: 0.3372 - precision: 0.2063 - recall: 0.9478 - f1_score: 0.3388 - AUC: 0.5452 - val_loss: 37.6867 - val_accuracy: 0.7224 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00 - val_AUC: 0.4834
# Epoch 189/200
# 26/26 - 8s - loss: 0.3828 - accuracy: 0.4048 - precision: 0.2069 - recall: 0.8191 - f1_score: 0.3303 - AUC: 0.5758 - val_loss: 2.5656 - val_accuracy: 0.6695 - val_precision: 0.2755 - val_recall: 0.1169 - val_f1_score: 0.1641 - val_AUC: 0.5704
# Epoch 190/200
# 26/26 - 9s - loss: 0.2562 - accuracy: 0.3786 - precision: 0.2226 - recall: 0.9866 - f1_score: 0.3633 - AUC: 0.6267 - val_loss: 0.6892 - val_accuracy: 0.5757 - val_precision: 0.3853 - val_recall: 0.8874 - val_f1_score: 0.5374 - val_AUC: 0.6803
# Epoch 191/200
# 26/26 - 8s - loss: 0.2028 - accuracy: 0.2964 - precision: 0.2025 - recall: 0.9913 - f1_score: 0.3363 - AUC: 0.5596 - val_loss: 0.6351 - val_accuracy: 0.3894 - val_precision: 0.3121 - val_recall: 0.9957 - val_f1_score: 0.4752 - val_AUC: 0.5772
# Epoch 192/200
# 26/26 - 8s - loss: 0.1935 - accuracy: 0.3553 - precision: 0.2041 - recall: 0.8941 - f1_score: 0.3324 - AUC: 0.5623 - val_loss: 0.6592 - val_accuracy: 0.3714 - val_precision: 0.3064 - val_recall: 1.0000 - val_f1_score: 0.4690 - val_AUC: 0.5657
# Epoch 193/200
# 26/26 - 8s - loss: 0.1994 - accuracy: 0.4064 - precision: 0.2089 - recall: 0.8235 - f1_score: 0.3332 - AUC: 0.5911 - val_loss: 0.7009 - val_accuracy: 0.3582 - val_precision: 0.3020 - val_recall: 1.0000 - val_f1_score: 0.4639 - val_AUC: 0.5566
# Epoch 194/200
# 26/26 - 8s - loss: 0.1853 - accuracy: 0.4194 - precision: 0.2193 - recall: 0.8638 - f1_score: 0.3497 - AUC: 0.6014 - val_loss: 0.7036 - val_accuracy: 0.3606 - val_precision: 0.3028 - val_recall: 1.0000 - val_f1_score: 0.4648 - val_AUC: 0.5574
# Epoch 195/200
# 26/26 - 8s - loss: 0.2044 - accuracy: 0.3450 - precision: 0.2174 - recall: 0.9949 - f1_score: 0.3568 - AUC: 0.5913 - val_loss: 0.6856 - val_accuracy: 0.3558 - val_precision: 0.3012 - val_recall: 1.0000 - val_f1_score: 0.4629 - val_AUC: 0.5549
# Epoch 196/200
# 26/26 - 8s - loss: 0.1903 - accuracy: 0.3543 - precision: 0.2162 - recall: 0.9913 - f1_score: 0.3549 - AUC: 0.5805 - val_loss: 0.7102 - val_accuracy: 0.3534 - val_precision: 0.3004 - val_recall: 1.0000 - val_f1_score: 0.4620 - val_AUC: 0.5549
# Epoch 197/200
# 26/26 - 8s - loss: 0.1973 - accuracy: 0.3867 - precision: 0.2220 - recall: 0.9964 - f1_score: 0.3631 - AUC: 0.6270 - val_loss: 0.7083 - val_accuracy: 0.3630 - val_precision: 0.3035 - val_recall: 1.0000 - val_f1_score: 0.4657 - val_AUC: 0.5591
# Epoch 198/200
# 26/26 - 8s - loss: 0.2055 - accuracy: 0.3926 - precision: 0.2306 - recall: 0.9881 - f1_score: 0.3739 - AUC: 0.6157 - val_loss: 0.6883 - val_accuracy: 0.3654 - val_precision: 0.3043 - val_recall: 1.0000 - val_f1_score: 0.4667 - val_AUC: 0.5624
# Epoch 199/200
# 26/26 - 8s - loss: 0.1769 - accuracy: 0.3979 - precision: 0.2342 - recall: 1.0000 - f1_score: 0.3796 - AUC: 0.6357 - val_loss: 0.6821 - val_accuracy: 0.3738 - val_precision: 0.3072 - val_recall: 1.0000 - val_f1_score: 0.4700 - val_AUC: 0.5655
# Epoch 200/200
# 26/26 - 8s - loss: 0.2755 - accuracy: 0.4110 - precision: 0.2343 - recall: 0.9983 - f1_score: 0.3795 - AUC: 0.6320 - val_loss: 0.7129 - val_accuracy: 0.3558 - val_precision: 0.3012 - val_recall: 1.0000 - val_f1_score: 0.4629 - val_AUC: 0.5541

# %%
# Primera iteración con el AUC de validación más alto
best_iter=np.where(np.max(history_1.history['val_AUC'])==history_1.history['val_AUC'])[0][0]
print(best_iter)
# Out:
# 186

# %%
# AUC más alto
history_1.history['val_AUC'][best_iter]
# Out:
# 0.7344685792922974

# %%
# Definiendo la función para desplegar la curva ROC
def plot_roc(name, labels, predictions, name_fig):
    fp, tp, _ = roc_curve(labels, predictions)
    auc1 = auc(fp, tp)
    lw=2

    plt.plot(100*fp, 100*tp, linewidth=2, lw=lw, color='darkorange', label='ROC curve (area = %0.2f)' % auc1)
    plt.plot([0, 100], [0, 100], color='navy', lw=lw, linestyle='--',label='Random')
    plt.xlabel('Falsos positivos [%]')
    plt.ylabel('Verdaderos positivos [%]')
    plt.xlim([-5,105])
    plt.ylim([-5,105])
    plt.grid(True)
    ax = plt.gca()
    ax.set_aspect('equal')
    plt.title(name)
    plt.legend(loc="lower right")
    plt.savefig('ROC_'+name_fig+'.png')

# %%
# Definiendo función para visualizar curvas de entrenamiento
def display_training_curves(training, validation, title, subplot):   ####2
    if subplot%10==1: # set up the subplots on the first call
        plt.subplots(figsize=(10,10), facecolor='#F0F0F0')
        plt.tight_layout()
    ax = plt.subplot(subplot)
    ax.set_facecolor('#F8F8F8')
    ax.plot(training)
    ax.plot(validation)
    ax.set_title('model '+ title)
    ax.set_ylabel(title)
    #ax.set_ylim(0.28,1.05)
    ax.set_xlabel('Iteración')
    ax.legend(['Entrenamiento', 'Validación.'])
    ax.scatter(best_iter, validation[best_iter], c='#ff7f0e', s=500)
    bbox = dict(boxstyle="round", fc="0.9")
    ax.annotate("Iteración con AUC más alto", (best_iter, validation[best_iter]), bbox=bbox)
    plt.savefig(str(title)+'.png')

# %%
# Desplegando curvas (loss & accuracy)
display_training_curves(history_1.history['loss'], history_1.history['val_loss'], 'Loss', 211)
display_training_curves(history_1.history['accuracy'], history_1.history['val_accuracy'], 'Accuracy', 212)

# %%
# Desplegando curvas (precision & recall)
display_training_curves(history_1.history['precision'], history_1.history['val_precision'], 'Precision', 211)
display_training_curves(history_1.history['recall'], history_1.history['val_recall'], 'Recall', 212)

# %%
# Desplegando curvas (f1_score & AUC)
display_training_curves(history_1.history['f1_score'], history_1.history['val_f1_score'], 'F1-Score', 211)
display_training_curves(history_1.history['AUC'], history_1.history['val_AUC'], 'AUC', 212)

# %%
# Cargamos el modelo con la mejor métrica de AUC en validación
rnet.load_weights("ResNet50_weights.h5")

# %%
# Calculando las predicciones para Red Neuronal
Y_train_pred = (rnet.predict(X_train) > 0.5).astype("int32")
Y_train_proba = rnet.predict(X_train) # Arreglo de probabilidades
Y_test_pred = (rnet.predict(X_test) > 0.5).astype("int32")
Y_test_proba = rnet.predict(X_test) # Arreglo de probabilidades

# %% [markdown]
# Lamentablemente Tensorflow subestima la métrica F1-Score y Sobrestima la métrica AUC. Para este trabajo se reportarán los resultados con base en la biblioteca de Scikit-Learn y se utilizará las métricas de TensorFlow sólo como auxiliar para hallar el valor más alto ponderado durante las iteracion o entrenamiento.
#
# Por tanto es posible que algunas gráficas del entrenamiento difieran con los resultados finales de estas dos métricas.
#
# A continuación de realiza una demostración de lo anteriromente descrito.

# %%
# Desplegando métrica del rendimiento
print("ResNet50 TensorFlow Metrics")
print()
print("MÉTRICAS EN ENTRENAMIENTO")
metric = tf.keras.metrics.BinaryAccuracy()
metric.update_state(Y_train, Y_train_pred)
print("Accuracy: %0.2f%%"%(100*metric.result().numpy()))
metric = tf.keras.metrics.Precision()
metric.update_state(Y_train, Y_train_pred)
print("Precision: %0.2f%%"%(100*metric.result().numpy()))
metric = tf.keras.metrics.Recall()
metric.update_state(Y_train, Y_train_pred)
print("Recall: %0.2f%%"%(100*metric.result().numpy()))
metric = tfa.metrics.F1Score(num_classes=2, average="micro", threshold=0.5)
metric.update_state(Y_train, Y_train_pred)
print("F1-Score: %0.2f%%"%(100*metric.result().numpy()))
metric = tf.keras.metrics.AUC()
metric.update_state(Y_train, Y_train_proba)
print("AUC: %0.2f%%"%(100*metric.result().numpy()))
print()
print("MÉTRICAS EN VALIDACIÓN")
metric = tf.keras.metrics.BinaryAccuracy()
metric.update_state(Y_test, Y_test_pred)
print("Accuracy: %0.2f%%"%(100*metric.result().numpy()))
metric = tf.keras.metrics.Precision()
metric.update_state(Y_test, Y_test_pred)
print("Precision: %0.2f%%"%(100*metric.result().numpy()))
metric = tf.keras.metrics.Recall()
metric.update_state(Y_test, Y_test_pred)
print("Recall: %0.2f%%"%(100*metric.result().numpy()))
metric = tfa.metrics.F1Score(num_classes=2, average="micro", threshold=0.5)
metric.update_state(Y_test, Y_test_pred)
print("F1-Score: %0.2f%%"%(100*metric.result().numpy()))
metric = tf.keras.metrics.AUC()
metric.update_state(Y_test, Y_test_proba)
print("AUC: %0.2f%%"%(100*metric.result().numpy()))
print()
print()
print("ResNet50 SciKit-Learn Metrics")
print()
print("MÉTRICAS EN ENTRENAMIENTO")
print("Accuracy: %0.2f%%"%(100*accuracy_score(Y_train, Y_train_pred)))
print("Precision: %0.2f%%"%(100*precision_score(Y_train, Y_train_pred)))
print("Recall: %0.2f%%"%(100*recall_score(Y_train, Y_train_pred)))
print("F1-Score: %0.2f%%"%(100*f1_score(Y_train, Y_train_pred)))
fp, tp, _ = roc_curve(Y_train, Y_train_proba)
print("AUC: %0.2f%%"%(100*auc(fp, tp)))
print()
print("MÉTRICAS EN VALIDACIÓN")
print("Accuracy: %0.2f%%"%(100*accuracy_score(Y_test, Y_test_pred)))
print("Precision: %0.2f%%"%(100*precision_score(Y_test, Y_test_pred)))
print("Recall: %0.2f%%"%(100*recall_score(Y_test, Y_test_pred)))
print("F1-Score: %0.2f%%"%(100*f1_score(Y_test, Y_test_pred)))
fp, tp, _ = roc_curve(Y_test, Y_test_proba)
print("AUC: %0.2f%%"%(100*auc(fp, tp)))
print()
# Out:
# ResNet50 TensorFlow Metrics
#
# MÉTRICAS EN ENTRENAMIENTO
# Accuracy: 76.39%
# Precision: 42.88%
# Recall: 93.02%
# F1-Score: 24.70%
# AUC: 82.83%
#
# MÉTRICAS EN VALIDACIÓN
# Accuracy: 67.67%
# Precision: 45.68%
# Recall: 87.01%
# F1-Score: 36.41%
# AUC: 73.45%
#
#
# ResNet50 SciKit-Learn Metrics
#
# MÉTRICAS EN ENTRENAMIENTO
# Accuracy: 76.39%
# Precision: 42.88%
# Recall: 93.02%
# F1-Score: 58.70%
# AUC: 83.33%
#
# MÉTRICAS EN VALIDACIÓN
# Accuracy: 67.67%
# Precision: 45.68%
# Recall: 87.01%
# F1-Score: 59.91%
# AUC: 73.49%

# %%
# Curva ROC de entrenamiento
plot_roc('ROC Red Neuronal Entrenamiento', Y_train, Y_train_proba, name_fig='RNET')
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:7: MatplotlibDeprecationWarning: Saw kwargs ['lw', 'linewidth'] which are all aliases for 'linewidth'.  Kept value from 'linewidth'.  Passing multiple aliases for the same property will raise a TypeError in 3.3.
#   import sys

# %%
# Curva de Roc de Validación
plot_roc('ROC Red Neuronal Validacion', Y_test, Y_test_proba, name_fig='RNET2')
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:7: MatplotlibDeprecationWarning: Saw kwargs ['lw', 'linewidth'] which are all aliases for 'linewidth'.  Kept value from 'linewidth'.  Passing multiple aliases for the same property will raise a TypeError in 3.3.
#   import sys

# %% [markdown]
# Finalmente se guarda el modelo completo.

# %%
rnet.save('ResNet50_FULL.h5')

# %% [markdown]
# Eliminando archivos innecesarios para guardar la libreta en Kaggle

# %%
import shutil

dir_path = './BaseDeDatosFrontales_FINAL_256_bits'

try:
    shutil.rmtree(dir_path)
except OSError as e:
    print("Error: %s : %s" % (dir_path, e.strerror))

# %%
os.remove("./BaseDeDatosFrontales_FINAL_256_bits.zip")
