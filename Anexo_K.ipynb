# %% [markdown]
# Anexo K

# %% [markdown]
# # Reconocedor con base en caracterización por asimetría de descriptores estadísticos con auxilio de PCA
#
# #### Elaborado por: Ricardo Niño de Rivera Barrón
#
# #### Ingeniería Biónica
#
# #### Trabajo Terminal II

# %% [markdown]
# En esta libreta interactiva se evalúa el funcionamiento de dos reconocedores artificiales que utilizan como entrada los descriptores estadísticos previamente procesados por una técnica de PCA.
#
# Esta libreta se desarrolló en la plaforma Google Colab con el objetiivo de mejorar la velocidad de implementación.

# %%
# Importando bibliotecas necesarias
import os
import numpy as np
import pandas as pd
from tqdm import tqdm
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import preprocessing
import matplotlib.image as mpimg
import sklearn

# %% [markdown]
# Ahora instalamos una nueva biblioteca para poder descargar archivos de MEGA.

# %%
# Instalanado mega.py
# !pip install mega.py
# Out:
# Collecting mega.py
#   Downloading mega.py-1.0.8-py2.py3-none-any.whl (19 kB)
# Requirement already satisfied: requests>=0.10 in /opt/conda/lib/python3.7/site-packages (from mega.py) (2.23.0)
# Collecting tenacity<6.0.0,>=5.1.5
#   Downloading tenacity-5.1.5-py2.py3-none-any.whl (34 kB)
# Collecting pathlib==1.0.1
#   Downloading pathlib-1.0.1.tar.gz (49 kB)
#      |████████████████████████████████| 49 kB 2.0 MB/s
# Collecting pycryptodome<4.0.0,>=3.9.6
#   Downloading pycryptodome-3.9.9-cp37-cp37m-manylinux1_x86_64.whl (13.7 MB)
#      |████████████████████████████████| 13.7 MB 16.9 MB/s
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests>=0.10->mega.py) (2020.11.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests>=0.10->mega.py) (1.25.9)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests>=0.10->mega.py) (2.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests>=0.10->mega.py) (3.0.4)
# Requirement already satisfied: six>=1.9.0 in /opt/conda/lib/python3.7/site-packages (from tenacity<6.0.0,>=5.1.5->mega.py) (1.14.0)
# Building wheels for collected packages: pathlib
# done
#   Created wheel for pathlib: filename=pathlib-1.0.1-py3-none-any.whl size=14346 sha256=24b8b8dba35adf53636aab4e6a9fc6e9ba66a495d6556f5bb6b32c591ee37749
#   Stored in directory: /root/.cache/pip/wheels/6e/96/b8/10037fe231e23970bac58361d7c93571ab983a7bbc55e68550
# Successfully built pathlib
# Installing collected packages: tenacity, pathlib, pycryptodome, mega.py
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 6.1.0
#     Uninstalling tenacity-6.1.0:
#       Successfully uninstalled tenacity-6.1.0
# Successfully installed mega.py-1.0.8 pathlib-1.0.1 pycryptodome-3.9.9 tenacity-5.1.5
# WARNING: You are using pip version 20.2.4; however, version 20.3 is available.
# You should consider upgrading via the '/opt/conda/bin/python3.7 -m pip install --upgrade pip' command.

# %%
# De la biblioteca mega importamos el método Mega
from mega import Mega

# %%
# Instanciando Mega en el objeto mega
mega = Mega()

# %% [markdown]
# Inicamos sesión con una cuenta temporal y anónima.

# %%
# Log in en la cuenta de MEGA con los datos de acceso
m = mega.login()

# %% [markdown]
# Descargamos los archivos necesarios

# %%
# Descargando X_train.npy
m.download_url('https://mega.nz/file/oAZT1IYJ#HpIvnnR50IH6N2F9wfdPgNTgLPpAwhEBpTl3_yAxLFc')
# Out:
# PosixPath('X_train.npy')

# %%
# Descargando X_test.npy
m.download_url('https://mega.nz/file/tMIzDQbK#MLFeDRu5D4dq2lRqvPcxIZkuTtVKH2azBRrhSzndqME')
# Out:
# PosixPath('X_test.npy')

# %%
# Descargando Y_train2.npy
m.download_url('https://mega.nz/file/tdohXarb#SRrt31GIT7H6gioCVm2KYF-sH6a8PHK8Z7Tr76oZb4I')
# Out:
# PosixPath('Y_train2.npy')

# %%
# Descargando Y_test2.npy
m.download_url('https://mega.nz/file/Vc5TBSbY#D8pbUvpA3l2V0PJxCu7Meg8WJ3wPpT6X2jEoDsleCWw')
# Out:
# PosixPath('Y_test2.npy')

# %% [markdown]
# Ahora se leen los archivos con numpy

# %%
X_train = np.load('X_train.npy')
X_train.shape
# Out:
# (3337, 17)

# %%
X_test = np.load('X_test.npy')
X_test.shape
# Out:
# (832, 17)

# %%
Y_train = np.load('Y_train2.npy')
Y_train.shape
# Out:
# (3337,)

# %%
Y_test = np.load('Y_test2.npy')
Y_test.shape
# Out:
# (832,)

# %% [markdown]
# ### Análisis de Componentes Principales PCA
#
# PCA es una técnica que reduce las dimensiones de un arreglo matricial utilizando las propiedades lineales de sus columnas.

# %%
sklearn.__version__
# Out:
# '0.23.2'

# %%
# Importando el método PCA
from sklearn.decomposition import PCA

# %%
# Instanciando PCa en un objeto que transforme los datos a 3 dimensiones
pca = PCA(n_components=3)

# %%
# Para X_train
X_train_pca = pca.fit(X_train).transform(X_train)

# %%
# Para X_test
# Nótese que se utiliza X_train para ajustar el pca
X_test_pca = pca.fit(X_train).transform(X_test)

# %%
# Comprobación con un ejemplo cualesquiera

#Leyendo ejemplo
ejemplo_test = X_test[5,:]

#Expandiendo una dimension
ejemplo_test = np.expand_dims(ejemplo_test,axis=0)

#Transformando el ejemplo
prueba1 = pca.fit(X_train).transform(ejemplo_test)
print(prueba1)
print(X_test_pca[5,:])
# Out:
# [[-18.52513566  21.87689658  -5.58046172]]
# [-18.52513566  21.87689658  -5.58046172]

# %% [markdown]
# La implementación es correcta.

# %% [markdown]
# Graficando X_train_pca

# %%
pos_train = np.where(Y_train==1)

# %%
neg_train = np.where(Y_train==0)

# %%
fig = plt.figure()
plt.title('Gráfica de dispersión\n PCA Datos Clínicos Entrenamiento')
ax = fig.add_subplot(1,3,1, projection='3d', title='Postivos')
ax.scatter(X_train_pca[pos_train,0], X_train_pca[pos_train,1], X_train_pca[pos_train,2], color='red')
ax = fig.add_subplot(1,3,2, projection='3d', title='Negativos')
ax.scatter(X_train_pca[neg_train,0], X_train_pca[neg_train,1], X_train_pca[neg_train,2], color='blue')
ax = fig.add_subplot(1,3,3, projection='3d', title='Ambas clases')
ax.scatter(X_train_pca[pos_train,0], X_train_pca[pos_train,1], X_train_pca[pos_train,2], color='red')
ax.scatter(X_train_pca[neg_train,0], X_train_pca[neg_train,1], X_train_pca[neg_train,2], color='blue')#
#plt.axis('off')
plt.axis(axis='off')
plt.savefig('PCA_train_Statistics_Descriptors.png')
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:11: MatplotlibDeprecationWarning: Passing unsupported keyword arguments to axis() will raise a TypeError in 3.3.
#   # This is added back by InteractiveShellApp.init_path()

# %% [markdown]
# Graficando X_test_pca

# %%
pos_test = np.where(Y_test==1)
neg_test = np.where(Y_test==0)

# %%
fig = plt.figure()
plt.title('Gráfica de dispersión\n PCA Datos Clínicos Validación')
ax = fig.add_subplot(1,3,1, projection='3d', title='Postivos')
ax.scatter(X_test_pca[pos_test,0], X_test_pca[pos_test,1], X_test_pca[pos_test,2], color='red')
ax = fig.add_subplot(1,3,2, projection='3d', title='Negativos')
ax.scatter(X_test_pca[neg_test,0], X_test_pca[neg_test,1], X_test_pca[neg_test,2], color='blue')
ax = fig.add_subplot(1,3,3, projection='3d', title='Ambas clases')
ax.scatter(X_test_pca[pos_test,0], X_test_pca[pos_test,1], X_test_pca[pos_test,2], color='red')
ax.scatter(X_test_pca[neg_test,0], X_test_pca[neg_test,1], X_test_pca[neg_test,2], color='blue')#
#plt.axis('off')
plt.axis(axis='off')
plt.savefig('PCA_test_Statistics_Descriptors.png')
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:11: MatplotlibDeprecationWarning: Passing unsupported keyword arguments to axis() will raise a TypeError in 3.3.
#   # This is added back by InteractiveShellApp.init_path()

# %% [markdown]
# ### Definiendo métricas

# %%
# Importando métricas de scikit learn}
from sklearn.metrics import f1_score, precision_score, recall_score, confusion_matrix, roc_curve, auc, accuracy_score

# %%
# Definiendo la función para desplegar la curva ROC
def plot_roc(name, labels, predictions, name_fig):
    fp, tp, _ = roc_curve(labels, predictions)
    auc1 = auc(fp, tp)
    lw=2

    plt.plot(100*fp, 100*tp, linewidth=2, lw=lw, color='darkorange', label='ROC curve (area = %0.2f)' % auc1)
    plt.plot([0, 100], [0, 100], color='navy', lw=lw, linestyle='--',label='Random')
    plt.xlabel('Falsos positivos [%]')
    plt.ylabel('Verdaderos positivos [%]')
    plt.xlim([-5,105])
    plt.ylim([-5,105])
    plt.grid(True)
    ax = plt.gca()
    ax.set_aspect('equal')
    plt.title(name)
    plt.legend(loc="lower right")
    plt.savefig('ROC_'+name_fig+'.png')

# %% [markdown]
# ### Regresión Logística
#
# El primer experimento es utilizando el modelo Regresión Logística o Unidad Neuronal.

# %%
# Importando el método auxiliar
from sklearn.linear_model import LogisticRegression

# %%
LR = LogisticRegression(C=0.01, solver='liblinear').fit(X_train_pca, Y_train)

# %%
# Calculando las predicciones para LR
Y_train_pred = LR.predict(X_train_pca)
Y_train_proba = LR.predict_proba(X_train_pca)[:,1] # Arreglo de probabilidades
Y_test_pred = LR.predict(X_test_pca)
Y_test_proba = LR.predict_proba(X_test_pca)[:,1] # Arreglo de probabilidades

# %%
# Desplegando métrica del rendimiento
print("REGRESIÓN LOGÍSTICA")
print()
print("MÉTRICAS EN ENTRENAMIENTO")
print("Accuracy: %0.2f%%"%(100*accuracy_score(Y_train, Y_train_pred)))
print("Precision: %0.2f%%"%(100*precision_score(Y_train, Y_train_pred)))
print("Recall: %0.2f%%"%(100*recall_score(Y_train, Y_train_pred)))
print("F1-Score: %0.2f%%"%(100*f1_score(Y_train, Y_train_pred)))
fp, tp, _ = roc_curve(Y_train, Y_train_proba)
print("AUC: %0.2f%%"%(100*auc(fp, tp)))
print()
print("MÉTRICAS EN VALIDACIÓN")
print("Accuracy: %0.2f%%"%(100*accuracy_score(Y_test, Y_test_pred)))
print("Precision: %0.2f%%"%(100*precision_score(Y_test, Y_test_pred)))
print("Recall: %0.2f%%"%(100*recall_score(Y_test, Y_test_pred)))
print("F1-Score: %0.2f%%"%(100*f1_score(Y_test, Y_test_pred)))
fp, tp, _ = roc_curve(Y_test, Y_test_proba)
print("AUC: %0.2f%%"%(100*auc(fp, tp)))
print()
# Out:
# REGRESIÓN LOGÍSTICA
#
# MÉTRICAS EN ENTRENAMIENTO
# Accuracy: 81.87%
# Precision: 48.45%
# Recall: 7.81%
# F1-Score: 13.45%
# AUC: 64.97%
#
# MÉTRICAS EN VALIDACIÓN
# Accuracy: 68.27%
# Precision: 2.86%
# Recall: 0.43%
# F1-Score: 0.75%
# AUC: 34.40%

# %%
# Curva ROC de entrenamiento
plot_roc('ROC Regresión Logística Entrenamiento', Y_train, Y_train_proba, name_fig='RegLog')
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:7: MatplotlibDeprecationWarning: Saw kwargs ['lw', 'linewidth'] which are all aliases for 'linewidth'.  Kept value from 'linewidth'.  Passing multiple aliases for the same property will raise a TypeError in 3.3.
#   import sys

# %%
# Curva de Roc de Validación
plot_roc('ROC Regresión Logística Validacion', Y_test, Y_test_proba, name_fig='RegLog')
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:7: MatplotlibDeprecationWarning: Saw kwargs ['lw', 'linewidth'] which are all aliases for 'linewidth'.  Kept value from 'linewidth'.  Passing multiple aliases for the same property will raise a TypeError in 3.3.
#   import sys

# %% [markdown]
# ### Red Neuronal Artificial
#
# Se propone una red neuronal artificial con tres capas ocultas.

# %%
# importando bibliotecas auxiliares
import tensorflow as tf
from tensorflow.keras.applications import *
from tensorflow.keras.layers import Dense, Dropout
import tensorflow_addons as tfa
from tensorflow.keras import Model, Input

# %%
# Arreglando el problema de clases desbalanceadas estableciendo un peso por clase en el función de costo
w_p=np.sum(Y_train==0)/Y_train.shape[0]
w_n=np.sum(Y_train==1)/Y_train.shape[0]

# %%
# Creando diccionario para establecer el peso de cada clase de salida
class_weights = { 0 : w_n , 1 : w_p }

# %%
# definimos dropout
# Esta factor que está definido entre 0 y 1
# es un factor que determina la tasa de unidades que se "apagarán"
# durante el entrenamiento; esto evita el sobreajuste
dropout = 0.2

# %%
# Definimos un modelo de incialización
# Esta inicialización ha demostrado ser bastante útil
# para ayudar al modelo a converger más rápido.
# Incialización por he es una técnica que utiliza la destribución probabílistica
# propuesta por He para incializar los pesos de la red neuronal
# Para más información refierase a la coumentación
# de la biblioteca
kernel_init = 'he_normal'

# %%
# Creando el modelo de la red neuronal de tres capasocultas con 10,000 unidades por capa
rnet = tf.keras.Sequential()
rnet.add(Dense(300, activation="relu", kernel_initializer=kernel_init, input_shape=(X_train_pca.shape[1],)))
rnet.add(Dropout(dropout))
rnet.add(Dense(300, activation="relu", kernel_initializer=kernel_init))
rnet.add(Dropout(dropout))
rnet.add(Dense(300, activation="relu", kernel_initializer=kernel_init))
rnet.add(Dropout(dropout))
rnet.add(Dense(1, activation='sigmoid', kernel_initializer=kernel_init))

# %%
# Visualizando el modelo
rnet.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 300)               1200
# _________________________________________________________________
# dropout (Dropout)            (None, 300)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 300)               90300
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 300)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 300)               90300
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 300)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 301
# =================================================================
# Total params: 182,101
# Trainable params: 182,101
# Non-trainable params: 0
# _________________________________________________________________

# %%
rnet.input.shape
# Out:
# TensorShape([None, 3])

# %%
# Añadiendo un término de regularización para evitar sobreajuste

L1 = 0.1

regularizer = tf.keras.regularizers.L1(l1=L1)

rnet.trainable = True

for layer in rnet.layers:
    for attr in ['kernel_regularizer']:
        if hasattr(layer, attr):
          setattr(layer, attr, regularizer)

# %%
# Se fuerza a la tasa de aprendiza a decaer de forma polinomial para evitar problemas con el entrenamiento
starter_learning_rate = 0.1
end_learning_rate = 0.01
decay_steps = 5
learning_rate_fn = tf.keras.optimizers.schedules.PolynomialDecay(
    starter_learning_rate,
    decay_steps,
    end_learning_rate,
    power=0.5)

# %%
import tensorflow_addons as tfa

# %%
# Definimos el optimizador utilizando el método de Adam
# Este método es una modificación del algoritmo de
# gradiente descendiente
#opt=tf.keras.optimizers.Adam(learning_rate=0.001) #,clipvalue=5)
#opt=tf.keras.optimizers.RMSprop(learning_rate=0.001) #,clipvalue=5)
#opt=tf.keras.optimizers.Adam(learning_rate=learning_rate_fn) #,clipvalue=5)
opt=tfa.optimizers.RectifiedAdam(learning_rate=0.001)

# %%
# Definiendo las métricas necesarias para dar seguimiento al modelo
METRICS = [
  tf.keras.metrics.BinaryAccuracy(name='accuracy'),
  tf.keras.metrics.Precision(name='precision'),
  tf.keras.metrics.Recall(name='recall'),
  tfa.metrics.F1Score(num_classes=2, average="micro", threshold=0.5),
  tf.keras.metrics.AUC(name='AUC')
]

# %%
# Compilando el modelo
rnet.compile(
    optimizer=opt,
    loss = 'binary_crossentropy',
    metrics=METRICS
)

# %% [markdown]
# Se guardará el modelo con el mejor rendimiento de AUC ya que se observó en distintos experimentos que se puede alcanzar un modelo que dé resultados mejores al azar.

# %%
# Con este objeto se guardará el mejor modelo con base a la métrica f1_score
sv = tf.keras.callbacks.ModelCheckpoint(filepath='rnet_weights.h5',monitor='val_AUC', verbose=0, save_best_only=True,
        save_weights_only=False, mode='max', save_freq='epoch')

# %%
# Tamaño del batch
BS = 128

# %%
# Entrenando el modelo y almacenando los valores en history_1
history_1 = rnet.fit(X_train_pca, Y_train, batch_size=BS,
                          steps_per_epoch=len(X_train_pca) // BS, validation_data=(X_test_pca, Y_test),
                          epochs=500, verbose=2, class_weight=class_weights, callbacks=[sv])
# Out:
# Epoch 1/500
# 26/26 - 1s - loss: 2.7858 - accuracy: 0.5496 - precision: 0.2116 - recall: 0.5465 - f1_score: 0.3051 - AUC: 0.5605 - val_loss: 11.5173 - val_accuracy: 0.4904 - val_precision: 0.1245 - val_recall: 0.1385 - val_f1_score: 0.1311 - val_AUC: 0.3687
# Epoch 2/500
# 26/26 - 0s - loss: 2.5384 - accuracy: 0.5572 - precision: 0.2186 - recall: 0.5601 - f1_score: 0.3145 - AUC: 0.5679 - val_loss: 6.2827 - val_accuracy: 0.5276 - val_precision: 0.1538 - val_recall: 0.1558 - val_f1_score: 0.1548 - val_AUC: 0.3909
# Epoch 3/500
# 26/26 - 0s - loss: 2.1114 - accuracy: 0.5762 - precision: 0.2254 - recall: 0.5517 - f1_score: 0.3200 - AUC: 0.5770 - val_loss: 4.4133 - val_accuracy: 0.5601 - val_precision: 0.1918 - val_recall: 0.1818 - val_f1_score: 0.1867 - val_AUC: 0.4325
# Epoch 4/500
# 26/26 - 0s - loss: 1.9323 - accuracy: 0.5603 - precision: 0.2258 - recall: 0.6021 - f1_score: 0.3284 - AUC: 0.5921 - val_loss: 6.3211 - val_accuracy: 0.5276 - val_precision: 0.1351 - val_recall: 0.1299 - val_f1_score: 0.1325 - val_AUC: 0.4046
# Epoch 5/500
# 26/26 - 0s - loss: 1.6730 - accuracy: 0.5690 - precision: 0.2285 - recall: 0.5913 - f1_score: 0.3296 - AUC: 0.5937 - val_loss: 4.1607 - val_accuracy: 0.5577 - val_precision: 0.1982 - val_recall: 0.1948 - val_f1_score: 0.1965 - val_AUC: 0.4355
# Epoch 6/500
# 26/26 - 0s - loss: 1.4555 - accuracy: 0.5441 - precision: 0.2147 - recall: 0.5714 - f1_score: 0.3122 - AUC: 0.5811 - val_loss: 4.7912 - val_accuracy: 0.4880 - val_precision: 0.1924 - val_recall: 0.2641 - val_f1_score: 0.2226 - val_AUC: 0.4299
# Epoch 7/500
# 26/26 - 0s - loss: 1.2903 - accuracy: 0.5575 - precision: 0.2203 - recall: 0.5754 - f1_score: 0.3186 - AUC: 0.5805 - val_loss: 3.2999 - val_accuracy: 0.5084 - val_precision: 0.2819 - val_recall: 0.4978 - val_f1_score: 0.3599 - val_AUC: 0.4912
# Epoch 8/500
# 26/26 - 0s - loss: 1.1816 - accuracy: 0.5466 - precision: 0.2194 - recall: 0.5849 - f1_score: 0.3191 - AUC: 0.5762 - val_loss: 3.0392 - val_accuracy: 0.4675 - val_precision: 0.1845 - val_recall: 0.2684 - val_f1_score: 0.2187 - val_AUC: 0.4024
# Epoch 9/500
# 26/26 - 0s - loss: 1.0803 - accuracy: 0.5101 - precision: 0.2090 - recall: 0.6041 - f1_score: 0.3105 - AUC: 0.5705 - val_loss: 3.1188 - val_accuracy: 0.4988 - val_precision: 0.1125 - val_recall: 0.1169 - val_f1_score: 0.1146 - val_AUC: 0.3943
# Epoch 10/500
# 26/26 - 0s - loss: 0.9119 - accuracy: 0.5668 - precision: 0.2180 - recall: 0.5608 - f1_score: 0.3139 - AUC: 0.5930 - val_loss: 1.5751 - val_accuracy: 0.5950 - val_precision: 0.2500 - val_recall: 0.2294 - val_f1_score: 0.2393 - val_AUC: 0.5161
# Epoch 11/500
# 26/26 - 0s - loss: 0.8359 - accuracy: 0.5728 - precision: 0.2249 - recall: 0.5523 - f1_score: 0.3196 - AUC: 0.5896 - val_loss: 3.0603 - val_accuracy: 0.5024 - val_precision: 0.2095 - val_recall: 0.2857 - val_f1_score: 0.2418 - val_AUC: 0.4250
# Epoch 12/500
# 26/26 - 0s - loss: 0.7462 - accuracy: 0.6064 - precision: 0.2329 - recall: 0.5455 - f1_score: 0.3264 - AUC: 0.6144 - val_loss: 3.6503 - val_accuracy: 0.4639 - val_precision: 0.1902 - val_recall: 0.2857 - val_f1_score: 0.2284 - val_AUC: 0.3694
# Epoch 13/500
# 26/26 - 0s - loss: 0.7722 - accuracy: 0.5566 - precision: 0.2252 - recall: 0.5652 - f1_score: 0.3221 - AUC: 0.5847 - val_loss: 2.4248 - val_accuracy: 0.3606 - val_precision: 0.2681 - val_recall: 0.7532 - val_f1_score: 0.3955 - val_AUC: 0.4402
# Epoch 14/500
# 26/26 - 0s - loss: 0.6450 - accuracy: 0.5553 - precision: 0.2201 - recall: 0.5576 - f1_score: 0.3156 - AUC: 0.5853 - val_loss: 2.0247 - val_accuracy: 0.3942 - val_precision: 0.2816 - val_recall: 0.7619 - val_f1_score: 0.4112 - val_AUC: 0.4350
# Epoch 15/500
# 26/26 - 0s - loss: 0.6098 - accuracy: 0.5659 - precision: 0.2378 - recall: 0.6084 - f1_score: 0.3420 - AUC: 0.6146 - val_loss: 3.2001 - val_accuracy: 0.3137 - val_precision: 0.2671 - val_recall: 0.8442 - val_f1_score: 0.4058 - val_AUC: 0.3923
# Epoch 16/500
# 26/26 - 0s - loss: 0.5648 - accuracy: 0.5734 - precision: 0.2146 - recall: 0.5788 - f1_score: 0.3131 - AUC: 0.5997 - val_loss: 2.0234 - val_accuracy: 0.4279 - val_precision: 0.2612 - val_recall: 0.5801 - val_f1_score: 0.3602 - val_AUC: 0.4170
# Epoch 17/500
# 26/26 - 0s - loss: 0.4751 - accuracy: 0.5899 - precision: 0.2481 - recall: 0.6003 - f1_score: 0.3511 - AUC: 0.6335 - val_loss: 1.3118 - val_accuracy: 0.5264 - val_precision: 0.1877 - val_recall: 0.2121 - val_f1_score: 0.1992 - val_AUC: 0.4343
# Epoch 18/500
# 26/26 - 0s - loss: 0.5014 - accuracy: 0.5591 - precision: 0.2127 - recall: 0.5455 - f1_score: 0.3060 - AUC: 0.5810 - val_loss: 1.3219 - val_accuracy: 0.4844 - val_precision: 0.1439 - val_recall: 0.1732 - val_f1_score: 0.1572 - val_AUC: 0.3962
# Epoch 19/500
# 26/26 - 0s - loss: 0.4962 - accuracy: 0.5388 - precision: 0.2195 - recall: 0.5769 - f1_score: 0.3180 - AUC: 0.5837 - val_loss: 1.1907 - val_accuracy: 0.5204 - val_precision: 0.1585 - val_recall: 0.1688 - val_f1_score: 0.1635 - val_AUC: 0.4097
# Epoch 20/500
# 26/26 - 0s - loss: 0.4201 - accuracy: 0.5746 - precision: 0.2138 - recall: 0.5338 - f1_score: 0.3053 - AUC: 0.5894 - val_loss: 0.8641 - val_accuracy: 0.5541 - val_precision: 0.1847 - val_recall: 0.1775 - val_f1_score: 0.1810 - val_AUC: 0.4362
# Epoch 21/500
# 26/26 - 0s - loss: 0.3796 - accuracy: 0.5756 - precision: 0.2383 - recall: 0.6138 - f1_score: 0.3433 - AUC: 0.6229 - val_loss: 0.8829 - val_accuracy: 0.5108 - val_precision: 0.1812 - val_recall: 0.2165 - val_f1_score: 0.1972 - val_AUC: 0.4190
# Epoch 22/500
# 26/26 - 0s - loss: 0.3639 - accuracy: 0.5927 - precision: 0.2472 - recall: 0.6149 - f1_score: 0.3526 - AUC: 0.6407 - val_loss: 0.9240 - val_accuracy: 0.5697 - val_precision: 0.1006 - val_recall: 0.0693 - val_f1_score: 0.0821 - val_AUC: 0.3793
# Epoch 23/500
# 26/26 - 0s - loss: 0.3413 - accuracy: 0.5572 - precision: 0.2179 - recall: 0.5650 - f1_score: 0.3145 - AUC: 0.5980 - val_loss: 0.7954 - val_accuracy: 0.5577 - val_precision: 0.1523 - val_recall: 0.1299 - val_f1_score: 0.1402 - val_AUC: 0.3955
# Epoch 24/500
# 26/26 - 0s - loss: 0.3076 - accuracy: 0.5821 - precision: 0.2394 - recall: 0.6045 - f1_score: 0.3430 - AUC: 0.6347 - val_loss: 0.8945 - val_accuracy: 0.5481 - val_precision: 0.1282 - val_recall: 0.1082 - val_f1_score: 0.1174 - val_AUC: 0.3710
# Epoch 25/500
# 26/26 - 0s - loss: 0.3068 - accuracy: 0.5815 - precision: 0.2320 - recall: 0.5643 - f1_score: 0.3288 - AUC: 0.6109 - val_loss: 0.9480 - val_accuracy: 0.4663 - val_precision: 0.1703 - val_recall: 0.2381 - val_f1_score: 0.1986 - val_AUC: 0.3896
# Epoch 26/500
# 26/26 - 0s - loss: 0.2898 - accuracy: 0.5665 - precision: 0.2307 - recall: 0.5935 - f1_score: 0.3322 - AUC: 0.6246 - val_loss: 0.7409 - val_accuracy: 0.5986 - val_precision: 0.1399 - val_recall: 0.0866 - val_f1_score: 0.1070 - val_AUC: 0.4062
# Epoch 27/500
# 26/26 - 0s - loss: 0.2814 - accuracy: 0.5946 - precision: 0.2360 - recall: 0.5662 - f1_score: 0.3332 - AUC: 0.6229 - val_loss: 0.8232 - val_accuracy: 0.4844 - val_precision: 0.1722 - val_recall: 0.2251 - val_f1_score: 0.1951 - val_AUC: 0.4034
# Epoch 28/500
# 26/26 - 0s - loss: 0.2732 - accuracy: 0.5820 - precision: 0.2345 - recall: 0.5807 - f1_score: 0.3341 - AUC: 0.6154 - val_loss: 0.8556 - val_accuracy: 0.4748 - val_precision: 0.1399 - val_recall: 0.1732 - val_f1_score: 0.1547 - val_AUC: 0.3836
# Epoch 29/500
# 26/26 - 0s - loss: 0.2659 - accuracy: 0.5631 - precision: 0.2200 - recall: 0.5652 - f1_score: 0.3168 - AUC: 0.5999 - val_loss: 0.8077 - val_accuracy: 0.4976 - val_precision: 0.1304 - val_recall: 0.1429 - val_f1_score: 0.1364 - val_AUC: 0.3790
# Epoch 30/500
# 26/26 - 0s - loss: 0.2574 - accuracy: 0.5768 - precision: 0.2301 - recall: 0.5857 - f1_score: 0.3304 - AUC: 0.6126 - val_loss: 0.7436 - val_accuracy: 0.5300 - val_precision: 0.1040 - val_recall: 0.0909 - val_f1_score: 0.0970 - val_AUC: 0.3900
# Epoch 31/500
# 26/26 - 0s - loss: 0.2463 - accuracy: 0.6095 - precision: 0.2435 - recall: 0.5491 - f1_score: 0.3374 - AUC: 0.6278 - val_loss: 0.7898 - val_accuracy: 0.4627 - val_precision: 0.0940 - val_recall: 0.1082 - val_f1_score: 0.1006 - val_AUC: 0.3791
# Epoch 32/500
# 26/26 - 0s - loss: 0.2392 - accuracy: 0.5550 - precision: 0.2202 - recall: 0.5769 - f1_score: 0.3187 - AUC: 0.6085 - val_loss: 0.7024 - val_accuracy: 0.5793 - val_precision: 0.0952 - val_recall: 0.0606 - val_f1_score: 0.0741 - val_AUC: 0.3799
# Epoch 33/500
# 26/26 - 0s - loss: 0.2319 - accuracy: 0.6211 - precision: 0.2574 - recall: 0.5556 - f1_score: 0.3518 - AUC: 0.6299 - val_loss: 0.8477 - val_accuracy: 0.4651 - val_precision: 0.1232 - val_recall: 0.1515 - val_f1_score: 0.1359 - val_AUC: 0.3786
# Epoch 34/500
# 26/26 - 0s - loss: 0.2189 - accuracy: 0.6173 - precision: 0.2398 - recall: 0.5235 - f1_score: 0.3290 - AUC: 0.6284 - val_loss: 0.8999 - val_accuracy: 0.4471 - val_precision: 0.1622 - val_recall: 0.2381 - val_f1_score: 0.1930 - val_AUC: 0.3779
# Epoch 35/500
# 26/26 - 0s - loss: 0.2243 - accuracy: 0.6161 - precision: 0.2529 - recall: 0.5622 - f1_score: 0.3488 - AUC: 0.6338 - val_loss: 0.7549 - val_accuracy: 0.4868 - val_precision: 0.1048 - val_recall: 0.1126 - val_f1_score: 0.1086 - val_AUC: 0.3765
# Epoch 36/500
# 26/26 - 0s - loss: 0.2085 - accuracy: 0.6092 - precision: 0.2485 - recall: 0.5854 - f1_score: 0.3489 - AUC: 0.6450 - val_loss: 0.7245 - val_accuracy: 0.5132 - val_precision: 0.1150 - val_recall: 0.1126 - val_f1_score: 0.1138 - val_AUC: 0.3886
# Epoch 37/500
# 26/26 - 0s - loss: 0.2070 - accuracy: 0.6208 - precision: 0.2548 - recall: 0.5707 - f1_score: 0.3523 - AUC: 0.6518 - val_loss: 0.8699 - val_accuracy: 0.4507 - val_precision: 0.1355 - val_recall: 0.1818 - val_f1_score: 0.1553 - val_AUC: 0.3721
# Epoch 38/500
# 26/26 - 0s - loss: 0.2050 - accuracy: 0.6064 - precision: 0.2448 - recall: 0.5739 - f1_score: 0.3432 - AUC: 0.6403 - val_loss: 0.7922 - val_accuracy: 0.4712 - val_precision: 0.1596 - val_recall: 0.2121 - val_f1_score: 0.1822 - val_AUC: 0.3746
# Epoch 39/500
# 26/26 - 0s - loss: 0.2080 - accuracy: 0.6204 - precision: 0.2492 - recall: 0.5358 - f1_score: 0.3402 - AUC: 0.6292 - val_loss: 0.7809 - val_accuracy: 0.4844 - val_precision: 0.1360 - val_recall: 0.1602 - val_f1_score: 0.1471 - val_AUC: 0.3764
# Epoch 40/500
# 26/26 - 0s - loss: 0.2040 - accuracy: 0.6351 - precision: 0.2518 - recall: 0.5424 - f1_score: 0.3440 - AUC: 0.6441 - val_loss: 0.6985 - val_accuracy: 0.5228 - val_precision: 0.1360 - val_recall: 0.1342 - val_f1_score: 0.1351 - val_AUC: 0.3946
# Epoch 41/500
# 26/26 - 0s - loss: 0.2092 - accuracy: 0.6127 - precision: 0.2513 - recall: 0.5776 - f1_score: 0.3502 - AUC: 0.6388 - val_loss: 0.6751 - val_accuracy: 0.5877 - val_precision: 0.1706 - val_recall: 0.1255 - val_f1_score: 0.1446 - val_AUC: 0.4095
# Epoch 42/500
# 26/26 - 0s - loss: 0.2037 - accuracy: 0.6064 - precision: 0.2517 - recall: 0.5853 - f1_score: 0.3520 - AUC: 0.6413 - val_loss: 0.7548 - val_accuracy: 0.4844 - val_precision: 0.1562 - val_recall: 0.1948 - val_f1_score: 0.1734 - val_AUC: 0.3825
# Epoch 43/500
# 26/26 - 0s - loss: 0.2043 - accuracy: 0.6179 - precision: 0.2560 - recall: 0.5845 - f1_score: 0.3561 - AUC: 0.6484 - val_loss: 0.7632 - val_accuracy: 0.4507 - val_precision: 0.1596 - val_recall: 0.2294 - val_f1_score: 0.1883 - val_AUC: 0.3763
# Epoch 44/500
# 26/26 - 0s - loss: 0.2008 - accuracy: 0.6285 - precision: 0.2526 - recall: 0.5589 - f1_score: 0.3479 - AUC: 0.6442 - val_loss: 0.7467 - val_accuracy: 0.5048 - val_precision: 0.1181 - val_recall: 0.1212 - val_f1_score: 0.1197 - val_AUC: 0.3760
# Epoch 45/500
# 26/26 - 0s - loss: 0.1994 - accuracy: 0.6111 - precision: 0.2582 - recall: 0.6051 - f1_score: 0.3620 - AUC: 0.6545 - val_loss: 0.8050 - val_accuracy: 0.4651 - val_precision: 0.1526 - val_recall: 0.2035 - val_f1_score: 0.1744 - val_AUC: 0.3765
# Epoch 46/500
# 26/26 - 0s - loss: 0.1974 - accuracy: 0.6108 - precision: 0.2522 - recall: 0.5965 - f1_score: 0.3545 - AUC: 0.6498 - val_loss: 0.7569 - val_accuracy: 0.4603 - val_precision: 0.1615 - val_recall: 0.2251 - val_f1_score: 0.1881 - val_AUC: 0.3793
# Epoch 47/500
# 26/26 - 0s - loss: 0.1952 - accuracy: 0.6360 - precision: 0.2513 - recall: 0.5191 - f1_score: 0.3386 - AUC: 0.6490 - val_loss: 0.7376 - val_accuracy: 0.4784 - val_precision: 0.1199 - val_recall: 0.1385 - val_f1_score: 0.1285 - val_AUC: 0.3668
# Epoch 48/500
# 26/26 - 0s - loss: 0.1964 - accuracy: 0.6136 - precision: 0.2574 - recall: 0.5922 - f1_score: 0.3588 - AUC: 0.6560 - val_loss: 0.7692 - val_accuracy: 0.4543 - val_precision: 0.1438 - val_recall: 0.1948 - val_f1_score: 0.1654 - val_AUC: 0.3729
# Epoch 49/500
# 26/26 - 0s - loss: 0.1961 - accuracy: 0.6232 - precision: 0.2538 - recall: 0.5800 - f1_score: 0.3531 - AUC: 0.6522 - val_loss: 0.7530 - val_accuracy: 0.4591 - val_precision: 0.1712 - val_recall: 0.2468 - val_f1_score: 0.2021 - val_AUC: 0.3838
# Epoch 50/500
# 26/26 - 0s - loss: 0.1966 - accuracy: 0.6208 - precision: 0.2740 - recall: 0.6402 - f1_score: 0.3838 - AUC: 0.6640 - val_loss: 0.7949 - val_accuracy: 0.4399 - val_precision: 0.1883 - val_recall: 0.3074 - val_f1_score: 0.2336 - val_AUC: 0.3740
# Epoch 51/500
# 26/26 - 0s - loss: 0.1960 - accuracy: 0.6002 - precision: 0.2493 - recall: 0.6161 - f1_score: 0.3550 - AUC: 0.6478 - val_loss: 0.7560 - val_accuracy: 0.4423 - val_precision: 0.1415 - val_recall: 0.1991 - val_f1_score: 0.1655 - val_AUC: 0.3728
# Epoch 52/500
# 26/26 - 0s - loss: 0.1918 - accuracy: 0.6179 - precision: 0.2513 - recall: 0.5950 - f1_score: 0.3534 - AUC: 0.6556 - val_loss: 0.7719 - val_accuracy: 0.4459 - val_precision: 0.1770 - val_recall: 0.2727 - val_f1_score: 0.2147 - val_AUC: 0.3746
# Epoch 53/500
# 26/26 - 0s - loss: 0.1972 - accuracy: 0.5993 - precision: 0.2539 - recall: 0.6085 - f1_score: 0.3583 - AUC: 0.6556 - val_loss: 0.7649 - val_accuracy: 0.4519 - val_precision: 0.1538 - val_recall: 0.2165 - val_f1_score: 0.1799 - val_AUC: 0.3736
# Epoch 54/500
# 26/26 - 0s - loss: 0.1958 - accuracy: 0.6264 - precision: 0.2670 - recall: 0.6055 - f1_score: 0.3706 - AUC: 0.6573 - val_loss: 0.7544 - val_accuracy: 0.4639 - val_precision: 0.1475 - val_recall: 0.1948 - val_f1_score: 0.1679 - val_AUC: 0.3724
# Epoch 55/500
# 26/26 - 0s - loss: 0.1901 - accuracy: 0.6292 - precision: 0.2609 - recall: 0.5803 - f1_score: 0.3600 - AUC: 0.6679 - val_loss: 0.7905 - val_accuracy: 0.4531 - val_precision: 0.1585 - val_recall: 0.2251 - val_f1_score: 0.1860 - val_AUC: 0.3776
# Epoch 56/500
# 26/26 - 0s - loss: 0.1921 - accuracy: 0.6248 - precision: 0.2651 - recall: 0.6031 - f1_score: 0.3683 - AUC: 0.6737 - val_loss: 0.7370 - val_accuracy: 0.4736 - val_precision: 0.1492 - val_recall: 0.1905 - val_f1_score: 0.1673 - val_AUC: 0.3855
# Epoch 57/500
# 26/26 - 0s - loss: 0.1906 - accuracy: 0.6398 - precision: 0.2600 - recall: 0.5589 - f1_score: 0.3549 - AUC: 0.6690 - val_loss: 0.7494 - val_accuracy: 0.4808 - val_precision: 0.1423 - val_recall: 0.1732 - val_f1_score: 0.1562 - val_AUC: 0.3817
# Epoch 58/500
# 26/26 - 0s - loss: 0.1904 - accuracy: 0.6242 - precision: 0.2666 - recall: 0.6183 - f1_score: 0.3725 - AUC: 0.6747 - val_loss: 0.7818 - val_accuracy: 0.4459 - val_precision: 0.1657 - val_recall: 0.2468 - val_f1_score: 0.1983 - val_AUC: 0.3800
# Epoch 59/500
# 26/26 - 0s - loss: 0.1925 - accuracy: 0.6036 - precision: 0.2583 - recall: 0.6274 - f1_score: 0.3659 - AUC: 0.6674 - val_loss: 0.7324 - val_accuracy: 0.4519 - val_precision: 0.1662 - val_recall: 0.2424 - val_f1_score: 0.1972 - val_AUC: 0.3889
# Epoch 60/500
# 26/26 - 0s - loss: 0.1880 - accuracy: 0.6307 - precision: 0.2736 - recall: 0.6282 - f1_score: 0.3812 - AUC: 0.6873 - val_loss: 0.7532 - val_accuracy: 0.4483 - val_precision: 0.1724 - val_recall: 0.2597 - val_f1_score: 0.2073 - val_AUC: 0.3860
# Epoch 61/500
# 26/26 - 0s - loss: 0.1914 - accuracy: 0.6077 - precision: 0.2594 - recall: 0.6310 - f1_score: 0.3677 - AUC: 0.6719 - val_loss: 0.7269 - val_accuracy: 0.4519 - val_precision: 0.1517 - val_recall: 0.2121 - val_f1_score: 0.1769 - val_AUC: 0.3826
# Epoch 62/500
# 26/26 - 0s - loss: 0.1908 - accuracy: 0.6014 - precision: 0.2590 - recall: 0.6494 - f1_score: 0.3703 - AUC: 0.6716 - val_loss: 0.7429 - val_accuracy: 0.4555 - val_precision: 0.1735 - val_recall: 0.2554 - val_f1_score: 0.2067 - val_AUC: 0.3858
# Epoch 63/500
# 26/26 - 0s - loss: 0.1857 - accuracy: 0.6173 - precision: 0.2633 - recall: 0.6572 - f1_score: 0.3760 - AUC: 0.6857 - val_loss: 0.7372 - val_accuracy: 0.4579 - val_precision: 0.1584 - val_recall: 0.2208 - val_f1_score: 0.1844 - val_AUC: 0.3840
# Epoch 64/500
# 26/26 - 0s - loss: 0.1898 - accuracy: 0.6257 - precision: 0.2724 - recall: 0.6386 - f1_score: 0.3819 - AUC: 0.6829 - val_loss: 0.7206 - val_accuracy: 0.4712 - val_precision: 0.1745 - val_recall: 0.2424 - val_f1_score: 0.2029 - val_AUC: 0.3886
# Epoch 65/500
# 26/26 - 0s - loss: 0.1919 - accuracy: 0.5890 - precision: 0.2656 - recall: 0.6705 - f1_score: 0.3805 - AUC: 0.6815 - val_loss: 0.7629 - val_accuracy: 0.4423 - val_precision: 0.1681 - val_recall: 0.2554 - val_f1_score: 0.2027 - val_AUC: 0.3805
# Epoch 66/500
# 26/26 - 0s - loss: 0.1891 - accuracy: 0.6179 - precision: 0.2458 - recall: 0.5866 - f1_score: 0.3465 - AUC: 0.6639 - val_loss: 0.7133 - val_accuracy: 0.4531 - val_precision: 0.1500 - val_recall: 0.2078 - val_f1_score: 0.1742 - val_AUC: 0.3855
# Epoch 67/500
# 26/26 - 0s - loss: 0.1897 - accuracy: 0.6011 - precision: 0.2521 - recall: 0.6176 - f1_score: 0.3581 - AUC: 0.6704 - val_loss: 0.7419 - val_accuracy: 0.4627 - val_precision: 0.1805 - val_recall: 0.2641 - val_f1_score: 0.2144 - val_AUC: 0.3912
# Epoch 68/500
# 26/26 - 0s - loss: 0.1938 - accuracy: 0.5986 - precision: 0.2698 - recall: 0.6892 - f1_score: 0.3878 - AUC: 0.6794 - val_loss: 0.7576 - val_accuracy: 0.4471 - val_precision: 0.1602 - val_recall: 0.2338 - val_f1_score: 0.1901 - val_AUC: 0.3847
# Epoch 69/500
# 26/26 - 0s - loss: 0.1880 - accuracy: 0.6538 - precision: 0.2683 - recall: 0.5593 - f1_score: 0.3626 - AUC: 0.6769 - val_loss: 0.7194 - val_accuracy: 0.4892 - val_precision: 0.1269 - val_recall: 0.1429 - val_f1_score: 0.1344 - val_AUC: 0.3830
# Epoch 70/500
# 26/26 - 0s - loss: 0.1923 - accuracy: 0.6208 - precision: 0.2693 - recall: 0.6064 - f1_score: 0.3730 - AUC: 0.6706 - val_loss: 0.7269 - val_accuracy: 0.4615 - val_precision: 0.1419 - val_recall: 0.1861 - val_f1_score: 0.1610 - val_AUC: 0.3852
# Epoch 71/500
# 26/26 - 0s - loss: 0.1911 - accuracy: 0.6295 - precision: 0.2645 - recall: 0.5897 - f1_score: 0.3652 - AUC: 0.6689 - val_loss: 0.7427 - val_accuracy: 0.4567 - val_precision: 0.1621 - val_recall: 0.2294 - val_f1_score: 0.1900 - val_AUC: 0.3839
# Epoch 72/500
# 26/26 - 0s - loss: 0.1854 - accuracy: 0.6223 - precision: 0.2711 - recall: 0.6370 - f1_score: 0.3804 - AUC: 0.7014 - val_loss: 0.7505 - val_accuracy: 0.4567 - val_precision: 0.1558 - val_recall: 0.2165 - val_f1_score: 0.1812 - val_AUC: 0.3835
# Epoch 73/500
# 26/26 - 0s - loss: 0.1897 - accuracy: 0.6329 - precision: 0.2636 - recall: 0.6092 - f1_score: 0.3680 - AUC: 0.6695 - val_loss: 0.7479 - val_accuracy: 0.4651 - val_precision: 0.1409 - val_recall: 0.1818 - val_f1_score: 0.1588 - val_AUC: 0.3815
# Epoch 74/500
# 26/26 - 0s - loss: 0.1908 - accuracy: 0.6441 - precision: 0.2801 - recall: 0.6106 - f1_score: 0.3840 - AUC: 0.6825 - val_loss: 0.7729 - val_accuracy: 0.4507 - val_precision: 0.1696 - val_recall: 0.2511 - val_f1_score: 0.2024 - val_AUC: 0.3798
# Epoch 75/500
# 26/26 - 0s - loss: 0.1917 - accuracy: 0.5905 - precision: 0.2580 - recall: 0.6542 - f1_score: 0.3701 - AUC: 0.6758 - val_loss: 0.7767 - val_accuracy: 0.4411 - val_precision: 0.1969 - val_recall: 0.3290 - val_f1_score: 0.2464 - val_AUC: 0.3836
# Epoch 76/500
# 26/26 - 0s - loss: 0.1886 - accuracy: 0.6276 - precision: 0.2720 - recall: 0.6475 - f1_score: 0.3831 - AUC: 0.6836 - val_loss: 0.7845 - val_accuracy: 0.4495 - val_precision: 0.1571 - val_recall: 0.2251 - val_f1_score: 0.1851 - val_AUC: 0.3744
# Epoch 77/500
# 26/26 - 0s - loss: 0.1872 - accuracy: 0.6285 - precision: 0.2744 - recall: 0.6269 - f1_score: 0.3817 - AUC: 0.6916 - val_loss: 0.7352 - val_accuracy: 0.4363 - val_precision: 0.1713 - val_recall: 0.2684 - val_f1_score: 0.2091 - val_AUC: 0.3816
# Epoch 78/500
# 26/26 - 0s - loss: 0.1877 - accuracy: 0.5946 - precision: 0.2514 - recall: 0.6584 - f1_score: 0.3638 - AUC: 0.6826 - val_loss: 0.7476 - val_accuracy: 0.4195 - val_precision: 0.1942 - val_recall: 0.3463 - val_f1_score: 0.2488 - val_AUC: 0.3868
# Epoch 79/500
# 26/26 - 0s - loss: 0.1863 - accuracy: 0.5893 - precision: 0.2566 - recall: 0.6707 - f1_score: 0.3712 - AUC: 0.6917 - val_loss: 0.6902 - val_accuracy: 0.4724 - val_precision: 0.1556 - val_recall: 0.2035 - val_f1_score: 0.1764 - val_AUC: 0.3903
# Epoch 80/500
# 26/26 - 0s - loss: 0.1891 - accuracy: 0.6385 - precision: 0.2804 - recall: 0.6274 - f1_score: 0.3875 - AUC: 0.6886 - val_loss: 0.7506 - val_accuracy: 0.4327 - val_precision: 0.1787 - val_recall: 0.2900 - val_f1_score: 0.2211 - val_AUC: 0.3792
# Epoch 81/500
# 26/26 - 0s - loss: 0.1887 - accuracy: 0.6151 - precision: 0.2577 - recall: 0.6104 - f1_score: 0.3624 - AUC: 0.6769 - val_loss: 0.7076 - val_accuracy: 0.4603 - val_precision: 0.1461 - val_recall: 0.1948 - val_f1_score: 0.1670 - val_AUC: 0.3797
# Epoch 82/500
# 26/26 - 0s - loss: 0.1868 - accuracy: 0.6247 - precision: 0.2650 - recall: 0.6100 - f1_score: 0.3695 - AUC: 0.6848 - val_loss: 0.7362 - val_accuracy: 0.4591 - val_precision: 0.1502 - val_recall: 0.2035 - val_f1_score: 0.1728 - val_AUC: 0.3818
# Epoch 83/500
# 26/26 - 0s - loss: 0.1874 - accuracy: 0.6192 - precision: 0.2672 - recall: 0.6373 - f1_score: 0.3765 - AUC: 0.6840 - val_loss: 0.7203 - val_accuracy: 0.4663 - val_precision: 0.1597 - val_recall: 0.2165 - val_f1_score: 0.1838 - val_AUC: 0.3926
# Epoch 84/500
# 26/26 - 0s - loss: 0.1883 - accuracy: 0.6183 - precision: 0.2655 - recall: 0.6254 - f1_score: 0.3728 - AUC: 0.6850 - val_loss: 0.7255 - val_accuracy: 0.4519 - val_precision: 0.1681 - val_recall: 0.2468 - val_f1_score: 0.2000 - val_AUC: 0.3910
# Epoch 85/500
# 26/26 - 0s - loss: 0.1857 - accuracy: 0.6307 - precision: 0.2808 - recall: 0.6661 - f1_score: 0.3951 - AUC: 0.7017 - val_loss: 0.7536 - val_accuracy: 0.4591 - val_precision: 0.1692 - val_recall: 0.2424 - val_f1_score: 0.1993 - val_AUC: 0.3806
# Epoch 86/500
# 26/26 - 0s - loss: 0.1869 - accuracy: 0.6376 - precision: 0.2710 - recall: 0.6091 - f1_score: 0.3751 - AUC: 0.6781 - val_loss: 0.7278 - val_accuracy: 0.4579 - val_precision: 0.1541 - val_recall: 0.2121 - val_f1_score: 0.1785 - val_AUC: 0.3850
# Epoch 87/500
# 26/26 - 0s - loss: 0.1866 - accuracy: 0.6211 - precision: 0.2698 - recall: 0.6731 - f1_score: 0.3852 - AUC: 0.6889 - val_loss: 0.7471 - val_accuracy: 0.4543 - val_precision: 0.1460 - val_recall: 0.1991 - val_f1_score: 0.1685 - val_AUC: 0.3782
# Epoch 88/500
# 26/26 - 0s - loss: 0.1898 - accuracy: 0.6338 - precision: 0.2751 - recall: 0.5940 - f1_score: 0.3760 - AUC: 0.6812 - val_loss: 0.7398 - val_accuracy: 0.4507 - val_precision: 0.1715 - val_recall: 0.2554 - val_f1_score: 0.2052 - val_AUC: 0.3932
# Epoch 89/500
# 26/26 - 0s - loss: 0.1836 - accuracy: 0.6254 - precision: 0.2692 - recall: 0.6596 - f1_score: 0.3823 - AUC: 0.7006 - val_loss: 0.7377 - val_accuracy: 0.4459 - val_precision: 0.1714 - val_recall: 0.2597 - val_f1_score: 0.2065 - val_AUC: 0.3875
# Epoch 90/500
# 26/26 - 0s - loss: 0.1881 - accuracy: 0.6089 - precision: 0.2615 - recall: 0.6340 - f1_score: 0.3703 - AUC: 0.6826 - val_loss: 0.7071 - val_accuracy: 0.4615 - val_precision: 0.1489 - val_recall: 0.1991 - val_f1_score: 0.1704 - val_AUC: 0.3889
# Epoch 91/500
# 26/26 - 0s - loss: 0.1839 - accuracy: 0.6663 - precision: 0.2988 - recall: 0.6171 - f1_score: 0.4027 - AUC: 0.7095 - val_loss: 0.7581 - val_accuracy: 0.4399 - val_precision: 0.1450 - val_recall: 0.2078 - val_f1_score: 0.1708 - val_AUC: 0.3749
# Epoch 92/500
# 26/26 - 0s - loss: 0.1889 - accuracy: 0.6098 - precision: 0.2677 - recall: 0.6486 - f1_score: 0.3790 - AUC: 0.6845 - val_loss: 0.7144 - val_accuracy: 0.4399 - val_precision: 0.1781 - val_recall: 0.2814 - val_f1_score: 0.2181 - val_AUC: 0.3935
# Epoch 93/500
# 26/26 - 0s - loss: 0.1848 - accuracy: 0.6304 - precision: 0.2719 - recall: 0.6399 - f1_score: 0.3816 - AUC: 0.6947 - val_loss: 0.7273 - val_accuracy: 0.4411 - val_precision: 0.1518 - val_recall: 0.2208 - val_f1_score: 0.1799 - val_AUC: 0.3922
# Epoch 94/500
# 26/26 - 0s - loss: 0.1835 - accuracy: 0.6295 - precision: 0.2759 - recall: 0.6684 - f1_score: 0.3906 - AUC: 0.6992 - val_loss: 0.7318 - val_accuracy: 0.4543 - val_precision: 0.1672 - val_recall: 0.2424 - val_f1_score: 0.1979 - val_AUC: 0.3917
# Epoch 95/500
# 26/26 - 0s - loss: 0.1852 - accuracy: 0.6295 - precision: 0.2710 - recall: 0.6341 - f1_score: 0.3798 - AUC: 0.6930 - val_loss: 0.7303 - val_accuracy: 0.4435 - val_precision: 0.1813 - val_recall: 0.2857 - val_f1_score: 0.2218 - val_AUC: 0.3955
# Epoch 96/500
# 26/26 - 0s - loss: 0.1907 - accuracy: 0.6049 - precision: 0.2795 - recall: 0.6903 - f1_score: 0.3979 - AUC: 0.6918 - val_loss: 0.7671 - val_accuracy: 0.4375 - val_precision: 0.1906 - val_recall: 0.3160 - val_f1_score: 0.2378 - val_AUC: 0.3934
# Epoch 97/500
# 26/26 - 0s - loss: 0.1858 - accuracy: 0.6525 - precision: 0.2832 - recall: 0.6178 - f1_score: 0.3884 - AUC: 0.6952 - val_loss: 0.7425 - val_accuracy: 0.4267 - val_precision: 0.1486 - val_recall: 0.2251 - val_f1_score: 0.1790 - val_AUC: 0.3888
# Epoch 98/500
# 26/26 - 0s - loss: 0.1879 - accuracy: 0.6395 - precision: 0.2708 - recall: 0.6021 - f1_score: 0.3736 - AUC: 0.6789 - val_loss: 0.7184 - val_accuracy: 0.4531 - val_precision: 0.1433 - val_recall: 0.1948 - val_f1_score: 0.1651 - val_AUC: 0.3925
# Epoch 99/500
# 26/26 - 0s - loss: 0.1793 - accuracy: 0.6379 - precision: 0.2863 - recall: 0.6864 - f1_score: 0.4041 - AUC: 0.7251 - val_loss: 0.7543 - val_accuracy: 0.4459 - val_precision: 0.1714 - val_recall: 0.2597 - val_f1_score: 0.2065 - val_AUC: 0.3903
# Epoch 100/500
# 26/26 - 0s - loss: 0.1853 - accuracy: 0.6360 - precision: 0.2809 - recall: 0.6365 - f1_score: 0.3898 - AUC: 0.6984 - val_loss: 0.7648 - val_accuracy: 0.4363 - val_precision: 0.1638 - val_recall: 0.2511 - val_f1_score: 0.1983 - val_AUC: 0.3892
# Epoch 101/500
# 26/26 - 0s - loss: 0.1869 - accuracy: 0.6323 - precision: 0.2702 - recall: 0.6163 - f1_score: 0.3757 - AUC: 0.6905 - val_loss: 0.7227 - val_accuracy: 0.4844 - val_precision: 0.1489 - val_recall: 0.1818 - val_f1_score: 0.1637 - val_AUC: 0.3926
# Epoch 102/500
# 26/26 - 0s - loss: 0.1878 - accuracy: 0.6242 - precision: 0.2652 - recall: 0.6114 - f1_score: 0.3699 - AUC: 0.6802 - val_loss: 0.7035 - val_accuracy: 0.4868 - val_precision: 0.1288 - val_recall: 0.1472 - val_f1_score: 0.1374 - val_AUC: 0.3926
# Epoch 103/500
# 26/26 - 0s - loss: 0.1861 - accuracy: 0.6447 - precision: 0.2765 - recall: 0.6165 - f1_score: 0.3818 - AUC: 0.6911 - val_loss: 0.7147 - val_accuracy: 0.4555 - val_precision: 0.1349 - val_recall: 0.1775 - val_f1_score: 0.1533 - val_AUC: 0.3964
# Epoch 104/500
# 26/26 - 0s - loss: 0.1823 - accuracy: 0.6479 - precision: 0.2931 - recall: 0.6667 - f1_score: 0.4071 - AUC: 0.7151 - val_loss: 0.7613 - val_accuracy: 0.4483 - val_precision: 0.1868 - val_recall: 0.2944 - val_f1_score: 0.2286 - val_AUC: 0.3978
# Epoch 105/500
# 26/26 - 0s - loss: 0.1842 - accuracy: 0.6164 - precision: 0.2720 - recall: 0.6759 - f1_score: 0.3879 - AUC: 0.6993 - val_loss: 0.7617 - val_accuracy: 0.4471 - val_precision: 0.1681 - val_recall: 0.2511 - val_f1_score: 0.2014 - val_AUC: 0.3947
# Epoch 106/500
# 26/26 - 0s - loss: 0.1875 - accuracy: 0.6120 - precision: 0.2750 - recall: 0.6848 - f1_score: 0.3924 - AUC: 0.6937 - val_loss: 0.7567 - val_accuracy: 0.4495 - val_precision: 0.1571 - val_recall: 0.2251 - val_f1_score: 0.1851 - val_AUC: 0.3907
# Epoch 107/500
# 26/26 - 0s - loss: 0.1872 - accuracy: 0.6619 - precision: 0.2857 - recall: 0.5848 - f1_score: 0.3839 - AUC: 0.6958 - val_loss: 0.7516 - val_accuracy: 0.4615 - val_precision: 0.1620 - val_recall: 0.2251 - val_f1_score: 0.1884 - val_AUC: 0.3975
# Epoch 108/500
# 26/26 - 0s - loss: 0.1851 - accuracy: 0.6569 - precision: 0.2895 - recall: 0.6267 - f1_score: 0.3961 - AUC: 0.7019 - val_loss: 0.7096 - val_accuracy: 0.5012 - val_precision: 0.1691 - val_recall: 0.2035 - val_f1_score: 0.1847 - val_AUC: 0.4120
# Epoch 109/500
# 26/26 - 0s - loss: 0.1870 - accuracy: 0.6809 - precision: 0.2982 - recall: 0.5710 - f1_score: 0.3918 - AUC: 0.6917 - val_loss: 0.7211 - val_accuracy: 0.5000 - val_precision: 0.1754 - val_recall: 0.2165 - val_f1_score: 0.1938 - val_AUC: 0.4088
# Epoch 110/500
# 26/26 - 0s - loss: 0.1864 - accuracy: 0.6136 - precision: 0.2700 - recall: 0.6592 - f1_score: 0.3831 - AUC: 0.6949 - val_loss: 0.7157 - val_accuracy: 0.4892 - val_precision: 0.1381 - val_recall: 0.1602 - val_f1_score: 0.1483 - val_AUC: 0.3977
# Epoch 111/500
# 26/26 - 0s - loss: 0.1862 - accuracy: 0.6360 - precision: 0.2730 - recall: 0.6181 - f1_score: 0.3787 - AUC: 0.6962 - val_loss: 0.7182 - val_accuracy: 0.4688 - val_precision: 0.1586 - val_recall: 0.2121 - val_f1_score: 0.1815 - val_AUC: 0.4100
# Epoch 112/500
# 26/26 - 0s - loss: 0.1850 - accuracy: 0.6722 - precision: 0.2887 - recall: 0.5734 - f1_score: 0.3841 - AUC: 0.6934 - val_loss: 0.7191 - val_accuracy: 0.4579 - val_precision: 0.1667 - val_recall: 0.2381 - val_f1_score: 0.1961 - val_AUC: 0.3984
# Epoch 113/500
# 26/26 - 0s - loss: 0.1829 - accuracy: 0.6264 - precision: 0.2696 - recall: 0.6348 - f1_score: 0.3784 - AUC: 0.6994 - val_loss: 0.7109 - val_accuracy: 0.4772 - val_precision: 0.1688 - val_recall: 0.2251 - val_f1_score: 0.1929 - val_AUC: 0.4085
# Epoch 114/500
# 26/26 - 0s - loss: 0.1865 - accuracy: 0.5980 - precision: 0.2619 - recall: 0.6713 - f1_score: 0.3768 - AUC: 0.6935 - val_loss: 0.7232 - val_accuracy: 0.4856 - val_precision: 0.1568 - val_recall: 0.1948 - val_f1_score: 0.1737 - val_AUC: 0.3872
# Epoch 115/500
# 26/26 - 0s - loss: 0.1844 - accuracy: 0.6622 - precision: 0.2922 - recall: 0.6065 - f1_score: 0.3944 - AUC: 0.7058 - val_loss: 0.7439 - val_accuracy: 0.4555 - val_precision: 0.1442 - val_recall: 0.1948 - val_f1_score: 0.1657 - val_AUC: 0.3796
# Epoch 116/500
# 26/26 - 0s - loss: 0.1907 - accuracy: 0.6123 - precision: 0.2708 - recall: 0.6258 - f1_score: 0.3780 - AUC: 0.6881 - val_loss: 0.7234 - val_accuracy: 0.4688 - val_precision: 0.1693 - val_recall: 0.2338 - val_f1_score: 0.1964 - val_AUC: 0.3874
# Epoch 117/500
# 26/26 - 0s - loss: 0.1778 - accuracy: 0.6619 - precision: 0.2742 - recall: 0.6018 - f1_score: 0.3768 - AUC: 0.7033 - val_loss: 0.7309 - val_accuracy: 0.4724 - val_precision: 0.1556 - val_recall: 0.2035 - val_f1_score: 0.1764 - val_AUC: 0.3830
# Epoch 118/500
# 26/26 - 0s - loss: 0.1848 - accuracy: 0.6557 - precision: 0.2877 - recall: 0.6045 - f1_score: 0.3898 - AUC: 0.6986 - val_loss: 0.7364 - val_accuracy: 0.4772 - val_precision: 0.1600 - val_recall: 0.2078 - val_f1_score: 0.1808 - val_AUC: 0.3949
# Epoch 119/500
# 26/26 - 0s - loss: 0.1793 - accuracy: 0.6497 - precision: 0.2867 - recall: 0.6486 - f1_score: 0.3976 - AUC: 0.7164 - val_loss: 0.7525 - val_accuracy: 0.4928 - val_precision: 0.1718 - val_recall: 0.2165 - val_f1_score: 0.1916 - val_AUC: 0.4081
# Epoch 120/500
# 26/26 - 0s - loss: 0.1853 - accuracy: 0.6566 - precision: 0.3007 - recall: 0.6476 - f1_score: 0.4107 - AUC: 0.7083 - val_loss: 0.7854 - val_accuracy: 0.4531 - val_precision: 0.1706 - val_recall: 0.2511 - val_f1_score: 0.2032 - val_AUC: 0.3956
# Epoch 121/500
# 26/26 - 0s - loss: 0.1830 - accuracy: 0.6357 - precision: 0.2775 - recall: 0.6289 - f1_score: 0.3851 - AUC: 0.7042 - val_loss: 0.7429 - val_accuracy: 0.4736 - val_precision: 0.1561 - val_recall: 0.2035 - val_f1_score: 0.1767 - val_AUC: 0.3913
# Epoch 122/500
# 26/26 - 0s - loss: 0.1816 - accuracy: 0.6697 - precision: 0.2997 - recall: 0.6285 - f1_score: 0.4058 - AUC: 0.7097 - val_loss: 0.7588 - val_accuracy: 0.4796 - val_precision: 0.1493 - val_recall: 0.1861 - val_f1_score: 0.1657 - val_AUC: 0.3954
# Epoch 123/500
# 26/26 - 0s - loss: 0.1829 - accuracy: 0.6597 - precision: 0.2919 - recall: 0.6058 - f1_score: 0.3940 - AUC: 0.7083 - val_loss: 0.7634 - val_accuracy: 0.4856 - val_precision: 0.1706 - val_recall: 0.2208 - val_f1_score: 0.1925 - val_AUC: 0.4040
# Epoch 124/500
# 26/26 - 0s - loss: 0.1826 - accuracy: 0.6516 - precision: 0.2741 - recall: 0.5957 - f1_score: 0.3754 - AUC: 0.6962 - val_loss: 0.6796 - val_accuracy: 0.5637 - val_precision: 0.1944 - val_recall: 0.1818 - val_f1_score: 0.1879 - val_AUC: 0.4476
# Epoch 125/500
# 26/26 - 0s - loss: 0.1874 - accuracy: 0.6410 - precision: 0.2798 - recall: 0.6116 - f1_score: 0.3840 - AUC: 0.6884 - val_loss: 0.7828 - val_accuracy: 0.4603 - val_precision: 0.1717 - val_recall: 0.2468 - val_f1_score: 0.2025 - val_AUC: 0.3955
# Epoch 126/500
# 26/26 - 0s - loss: 0.1835 - accuracy: 0.6647 - precision: 0.2920 - recall: 0.6094 - f1_score: 0.3948 - AUC: 0.7013 - val_loss: 0.7478 - val_accuracy: 0.4700 - val_precision: 0.1546 - val_recall: 0.2035 - val_f1_score: 0.1757 - val_AUC: 0.3934
# Epoch 127/500
# 26/26 - 0s - loss: 0.1757 - accuracy: 0.6666 - precision: 0.3032 - recall: 0.6784 - f1_score: 0.4191 - AUC: 0.7371 - val_loss: 0.7895 - val_accuracy: 0.4543 - val_precision: 0.1526 - val_recall: 0.2121 - val_f1_score: 0.1775 - val_AUC: 0.3915
# Epoch 128/500
# 26/26 - 0s - loss: 0.1891 - accuracy: 0.6472 - precision: 0.2901 - recall: 0.6171 - f1_score: 0.3947 - AUC: 0.6929 - val_loss: 0.7265 - val_accuracy: 0.5012 - val_precision: 0.1541 - val_recall: 0.1775 - val_f1_score: 0.1650 - val_AUC: 0.3951
# Epoch 129/500
# 26/26 - 0s - loss: 0.1820 - accuracy: 0.6744 - precision: 0.2860 - recall: 0.5719 - f1_score: 0.3813 - AUC: 0.6955 - val_loss: 0.7187 - val_accuracy: 0.5084 - val_precision: 0.1603 - val_recall: 0.1818 - val_f1_score: 0.1704 - val_AUC: 0.3941
# Epoch 130/500
# 26/26 - 0s - loss: 0.1821 - accuracy: 0.6606 - precision: 0.2931 - recall: 0.5946 - f1_score: 0.3926 - AUC: 0.7107 - val_loss: 0.7481 - val_accuracy: 0.4760 - val_precision: 0.1704 - val_recall: 0.2294 - val_f1_score: 0.1956 - val_AUC: 0.3980
# Epoch 131/500
# 26/26 - 0s - loss: 0.1825 - accuracy: 0.6641 - precision: 0.3002 - recall: 0.6381 - f1_score: 0.4083 - AUC: 0.7146 - val_loss: 0.7181 - val_accuracy: 0.5108 - val_precision: 0.1508 - val_recall: 0.1645 - val_f1_score: 0.1573 - val_AUC: 0.3966
# Epoch 132/500
# 26/26 - 0s - loss: 0.1815 - accuracy: 0.6849 - precision: 0.2980 - recall: 0.6014 - f1_score: 0.3986 - AUC: 0.7025 - val_loss: 0.7403 - val_accuracy: 0.4976 - val_precision: 0.1894 - val_recall: 0.2468 - val_f1_score: 0.2143 - val_AUC: 0.4132
# Epoch 133/500
# 26/26 - 0s - loss: 0.1823 - accuracy: 0.6522 - precision: 0.3049 - recall: 0.6623 - f1_score: 0.4175 - AUC: 0.7239 - val_loss: 0.7810 - val_accuracy: 0.4772 - val_precision: 0.1772 - val_recall: 0.2424 - val_f1_score: 0.2048 - val_AUC: 0.3991
# Epoch 134/500
# 26/26 - 0s - loss: 0.1834 - accuracy: 0.6591 - precision: 0.2825 - recall: 0.6060 - f1_score: 0.3854 - AUC: 0.6962 - val_loss: 0.7503 - val_accuracy: 0.5036 - val_precision: 0.1630 - val_recall: 0.1905 - val_f1_score: 0.1756 - val_AUC: 0.3973
# Epoch 135/500
# 26/26 - 0s - loss: 0.1831 - accuracy: 0.6703 - precision: 0.2952 - recall: 0.5893 - f1_score: 0.3933 - AUC: 0.7067 - val_loss: 0.7731 - val_accuracy: 0.4663 - val_precision: 0.1895 - val_recall: 0.2814 - val_f1_score: 0.2265 - val_AUC: 0.4039
# Epoch 136/500
# 26/26 - 0s - loss: 0.1874 - accuracy: 0.6412 - precision: 0.2770 - recall: 0.6150 - f1_score: 0.3820 - AUC: 0.6877 - val_loss: 0.7558 - val_accuracy: 0.4651 - val_precision: 0.1614 - val_recall: 0.2208 - val_f1_score: 0.1865 - val_AUC: 0.3921
# Epoch 137/500
# 26/26 - 0s - loss: 0.1806 - accuracy: 0.6803 - precision: 0.3026 - recall: 0.5990 - f1_score: 0.4021 - AUC: 0.7143 - val_loss: 0.7577 - val_accuracy: 0.4832 - val_precision: 0.1780 - val_recall: 0.2381 - val_f1_score: 0.2037 - val_AUC: 0.3987
# Epoch 138/500
# 26/26 - 0s - loss: 0.1820 - accuracy: 0.6647 - precision: 0.2999 - recall: 0.6291 - f1_score: 0.4062 - AUC: 0.7139 - val_loss: 0.8031 - val_accuracy: 0.4651 - val_precision: 0.1677 - val_recall: 0.2338 - val_f1_score: 0.1953 - val_AUC: 0.3950
# Epoch 139/500
# 26/26 - 0s - loss: 0.1830 - accuracy: 0.6821 - precision: 0.3065 - recall: 0.5962 - f1_score: 0.4049 - AUC: 0.7079 - val_loss: 0.7263 - val_accuracy: 0.5048 - val_precision: 0.1779 - val_recall: 0.2165 - val_f1_score: 0.1953 - val_AUC: 0.4066
# Epoch 140/500
# 26/26 - 0s - loss: 0.1785 - accuracy: 0.6687 - precision: 0.2981 - recall: 0.6386 - f1_score: 0.4065 - AUC: 0.7251 - val_loss: 0.7581 - val_accuracy: 0.4844 - val_precision: 0.1678 - val_recall: 0.2165 - val_f1_score: 0.1890 - val_AUC: 0.4011
# Epoch 141/500
# 26/26 - 0s - loss: 0.1809 - accuracy: 0.6865 - precision: 0.3143 - recall: 0.6113 - f1_score: 0.4151 - AUC: 0.7127 - val_loss: 0.7652 - val_accuracy: 0.4832 - val_precision: 0.1738 - val_recall: 0.2294 - val_f1_score: 0.1978 - val_AUC: 0.4042
# Epoch 142/500
# 26/26 - 0s - loss: 0.1822 - accuracy: 0.6980 - precision: 0.3081 - recall: 0.5550 - f1_score: 0.3963 - AUC: 0.7020 - val_loss: 0.7818 - val_accuracy: 0.4700 - val_precision: 0.1656 - val_recall: 0.2251 - val_f1_score: 0.1908 - val_AUC: 0.3979
# Epoch 143/500
# 26/26 - 0s - loss: 0.1813 - accuracy: 0.6494 - precision: 0.2887 - recall: 0.6510 - f1_score: 0.4000 - AUC: 0.7163 - val_loss: 0.7383 - val_accuracy: 0.5000 - val_precision: 0.1821 - val_recall: 0.2294 - val_f1_score: 0.2031 - val_AUC: 0.4075
# Epoch 144/500
# 26/26 - 0s - loss: 0.1802 - accuracy: 0.6803 - precision: 0.3130 - recall: 0.6459 - f1_score: 0.4216 - AUC: 0.7253 - val_loss: 0.8378 - val_accuracy: 0.4748 - val_precision: 0.1567 - val_recall: 0.2035 - val_f1_score: 0.1770 - val_AUC: 0.3859
# Epoch 145/500
# 26/26 - 0s - loss: 0.1844 - accuracy: 0.6581 - precision: 0.2997 - recall: 0.6173 - f1_score: 0.4035 - AUC: 0.7064 - val_loss: 0.7812 - val_accuracy: 0.4868 - val_precision: 0.1733 - val_recall: 0.2251 - val_f1_score: 0.1959 - val_AUC: 0.4005
# Epoch 146/500
# 26/26 - 0s - loss: 0.1787 - accuracy: 0.6809 - precision: 0.3066 - recall: 0.6316 - f1_score: 0.4128 - AUC: 0.7203 - val_loss: 0.7809 - val_accuracy: 0.5060 - val_precision: 0.1809 - val_recall: 0.2208 - val_f1_score: 0.1988 - val_AUC: 0.4087
# Epoch 147/500
# 26/26 - 0s - loss: 0.1831 - accuracy: 0.6893 - precision: 0.3045 - recall: 0.5667 - f1_score: 0.3961 - AUC: 0.7030 - val_loss: 0.7942 - val_accuracy: 0.5132 - val_precision: 0.1575 - val_recall: 0.1732 - val_f1_score: 0.1649 - val_AUC: 0.3919
# Epoch 148/500
# 26/26 - 0s - loss: 0.1777 - accuracy: 0.6934 - precision: 0.3038 - recall: 0.5790 - f1_score: 0.3985 - AUC: 0.7160 - val_loss: 0.7538 - val_accuracy: 0.5361 - val_precision: 0.1912 - val_recall: 0.2078 - val_f1_score: 0.1992 - val_AUC: 0.4090
# Epoch 149/500
# 26/26 - 0s - loss: 0.1796 - accuracy: 0.6890 - precision: 0.3074 - recall: 0.5704 - f1_score: 0.3995 - AUC: 0.7155 - val_loss: 0.7381 - val_accuracy: 0.5409 - val_precision: 0.1841 - val_recall: 0.1905 - val_f1_score: 0.1872 - val_AUC: 0.3917
# Epoch 150/500
# 26/26 - 0s - loss: 0.1867 - accuracy: 0.6594 - precision: 0.2971 - recall: 0.6080 - f1_score: 0.3991 - AUC: 0.6972 - val_loss: 0.7680 - val_accuracy: 0.5180 - val_precision: 0.1828 - val_recall: 0.2121 - val_f1_score: 0.1964 - val_AUC: 0.3994
# Epoch 151/500
# 26/26 - 0s - loss: 0.1742 - accuracy: 0.6983 - precision: 0.3115 - recall: 0.6173 - f1_score: 0.4140 - AUC: 0.7332 - val_loss: 0.8011 - val_accuracy: 0.5216 - val_precision: 0.1564 - val_recall: 0.1645 - val_f1_score: 0.1603 - val_AUC: 0.3953
# Epoch 152/500
# 26/26 - 0s - loss: 0.1871 - accuracy: 0.6959 - precision: 0.3246 - recall: 0.5748 - f1_score: 0.4149 - AUC: 0.7011 - val_loss: 0.7425 - val_accuracy: 0.5312 - val_precision: 0.1646 - val_recall: 0.1688 - val_f1_score: 0.1667 - val_AUC: 0.4112
# Epoch 153/500
# 26/26 - 0s - loss: 0.1790 - accuracy: 0.6871 - precision: 0.2978 - recall: 0.5839 - f1_score: 0.3945 - AUC: 0.7124 - val_loss: 0.8723 - val_accuracy: 0.4808 - val_precision: 0.1789 - val_recall: 0.2424 - val_f1_score: 0.2059 - val_AUC: 0.4012
# Epoch 154/500
# 26/26 - 0s - loss: 0.1802 - accuracy: 0.6974 - precision: 0.3157 - recall: 0.5776 - f1_score: 0.4083 - AUC: 0.7092 - val_loss: 0.7563 - val_accuracy: 0.5192 - val_precision: 0.1859 - val_recall: 0.2165 - val_f1_score: 0.2000 - val_AUC: 0.4120
# Epoch 155/500
# 26/26 - 0s - loss: 0.1780 - accuracy: 0.6678 - precision: 0.3106 - recall: 0.6543 - f1_score: 0.4213 - AUC: 0.7342 - val_loss: 0.7423 - val_accuracy: 0.5373 - val_precision: 0.2016 - val_recall: 0.2251 - val_f1_score: 0.2127 - val_AUC: 0.4260
# Epoch 156/500
# 26/26 - 0s - loss: 0.1833 - accuracy: 0.6731 - precision: 0.2983 - recall: 0.6049 - f1_score: 0.3995 - AUC: 0.7071 - val_loss: 0.7281 - val_accuracy: 0.5505 - val_precision: 0.1878 - val_recall: 0.1861 - val_f1_score: 0.1870 - val_AUC: 0.4161
# Epoch 157/500
# 26/26 - 0s - loss: 0.1825 - accuracy: 0.6797 - precision: 0.3048 - recall: 0.5887 - f1_score: 0.4016 - AUC: 0.7035 - val_loss: 0.7878 - val_accuracy: 0.5240 - val_precision: 0.1839 - val_recall: 0.2078 - val_f1_score: 0.1951 - val_AUC: 0.3997
# Epoch 158/500
# 26/26 - 0s - loss: 0.1780 - accuracy: 0.6902 - precision: 0.2981 - recall: 0.5935 - f1_score: 0.3968 - AUC: 0.7104 - val_loss: 0.7128 - val_accuracy: 0.5625 - val_precision: 0.1658 - val_recall: 0.1429 - val_f1_score: 0.1535 - val_AUC: 0.4050
# Epoch 159/500
# 26/26 - 0s - loss: 0.1810 - accuracy: 0.7012 - precision: 0.3280 - recall: 0.5912 - f1_score: 0.4219 - AUC: 0.7175 - val_loss: 0.7349 - val_accuracy: 0.5457 - val_precision: 0.1704 - val_recall: 0.1645 - val_f1_score: 0.1674 - val_AUC: 0.4074
# Epoch 160/500
# 26/26 - 0s - loss: 0.1790 - accuracy: 0.7012 - precision: 0.3272 - recall: 0.6079 - f1_score: 0.4254 - AUC: 0.7267 - val_loss: 0.7447 - val_accuracy: 0.5469 - val_precision: 0.1651 - val_recall: 0.1558 - val_f1_score: 0.1604 - val_AUC: 0.4084
# Epoch 161/500
# 26/26 - 0s - loss: 0.1799 - accuracy: 0.7096 - precision: 0.3245 - recall: 0.5767 - f1_score: 0.4153 - AUC: 0.7170 - val_loss: 0.7413 - val_accuracy: 0.5409 - val_precision: 0.1867 - val_recall: 0.1948 - val_f1_score: 0.1907 - val_AUC: 0.4096
# Epoch 162/500
# 26/26 - 0s - loss: 0.1764 - accuracy: 0.6825 - precision: 0.3139 - recall: 0.6284 - f1_score: 0.4187 - AUC: 0.7338 - val_loss: 0.7981 - val_accuracy: 0.5108 - val_precision: 0.1835 - val_recall: 0.2208 - val_f1_score: 0.2004 - val_AUC: 0.4030
# Epoch 163/500
# 26/26 - 0s - loss: 0.1781 - accuracy: 0.6659 - precision: 0.2991 - recall: 0.6350 - f1_score: 0.4066 - AUC: 0.7227 - val_loss: 0.7622 - val_accuracy: 0.5264 - val_precision: 0.1646 - val_recall: 0.1732 - val_f1_score: 0.1688 - val_AUC: 0.3942
# Epoch 164/500
# 26/26 - 0s - loss: 0.1775 - accuracy: 0.6815 - precision: 0.3152 - recall: 0.6472 - f1_score: 0.4239 - AUC: 0.7322 - val_loss: 0.7647 - val_accuracy: 0.5300 - val_precision: 0.1923 - val_recall: 0.2165 - val_f1_score: 0.2037 - val_AUC: 0.4044
# Epoch 165/500
# 26/26 - 0s - loss: 0.1790 - accuracy: 0.7442 - precision: 0.3522 - recall: 0.5069 - f1_score: 0.4157 - AUC: 0.7188 - val_loss: 0.7815 - val_accuracy: 0.5276 - val_precision: 0.1811 - val_recall: 0.1991 - val_f1_score: 0.1897 - val_AUC: 0.4007
# Epoch 166/500
# 26/26 - 0s - loss: 0.1821 - accuracy: 0.6918 - precision: 0.3171 - recall: 0.6010 - f1_score: 0.4151 - AUC: 0.7162 - val_loss: 0.7456 - val_accuracy: 0.5433 - val_precision: 0.1883 - val_recall: 0.1948 - val_f1_score: 0.1915 - val_AUC: 0.4222
# Epoch 167/500
# 26/26 - 0s - loss: 0.1778 - accuracy: 0.7024 - precision: 0.3165 - recall: 0.5623 - f1_score: 0.4050 - AUC: 0.7209 - val_loss: 0.8115 - val_accuracy: 0.5060 - val_precision: 0.1853 - val_recall: 0.2294 - val_f1_score: 0.2050 - val_AUC: 0.4093
# Epoch 168/500
# 26/26 - 0s - loss: 0.1821 - accuracy: 0.6809 - precision: 0.3110 - recall: 0.6199 - f1_score: 0.4142 - AUC: 0.7140 - val_loss: 0.7331 - val_accuracy: 0.5409 - val_precision: 0.1644 - val_recall: 0.1602 - val_f1_score: 0.1623 - val_AUC: 0.4057
# Epoch 169/500
# 26/26 - 0s - loss: 0.1788 - accuracy: 0.6862 - precision: 0.3185 - recall: 0.6353 - f1_score: 0.4242 - AUC: 0.7297 - val_loss: 0.7741 - val_accuracy: 0.4940 - val_precision: 0.1701 - val_recall: 0.2121 - val_f1_score: 0.1888 - val_AUC: 0.3964
# Epoch 170/500
# 26/26 - 0s - loss: 0.1767 - accuracy: 0.6678 - precision: 0.2845 - recall: 0.6171 - f1_score: 0.3895 - AUC: 0.7172 - val_loss: 0.7804 - val_accuracy: 0.5240 - val_precision: 0.1660 - val_recall: 0.1775 - val_f1_score: 0.1715 - val_AUC: 0.3949
# Epoch 171/500
# 26/26 - 0s - loss: 0.1805 - accuracy: 0.7211 - precision: 0.3573 - recall: 0.5878 - f1_score: 0.4444 - AUC: 0.7296 - val_loss: 0.8085 - val_accuracy: 0.5216 - val_precision: 0.1986 - val_recall: 0.2381 - val_f1_score: 0.2165 - val_AUC: 0.4146
# Epoch 172/500
# 26/26 - 0s - loss: 0.1780 - accuracy: 0.6946 - precision: 0.3047 - recall: 0.5925 - f1_score: 0.4024 - AUC: 0.7174 - val_loss: 0.7652 - val_accuracy: 0.5733 - val_precision: 0.2232 - val_recall: 0.2165 - val_f1_score: 0.2198 - val_AUC: 0.4445
# Epoch 173/500
# 26/26 - 0s - loss: 0.1758 - accuracy: 0.7061 - precision: 0.3336 - recall: 0.6137 - f1_score: 0.4323 - AUC: 0.7361 - val_loss: 0.7718 - val_accuracy: 0.5433 - val_precision: 0.1598 - val_recall: 0.1515 - val_f1_score: 0.1556 - val_AUC: 0.3982
# Epoch 174/500
# 26/26 - 0s - loss: 0.1834 - accuracy: 0.6853 - precision: 0.3174 - recall: 0.6186 - f1_score: 0.4195 - AUC: 0.7163 - val_loss: 0.7736 - val_accuracy: 0.5252 - val_precision: 0.1940 - val_recall: 0.2251 - val_f1_score: 0.2084 - val_AUC: 0.4161
# Epoch 175/500
# 26/26 - 0s - loss: 0.1809 - accuracy: 0.7111 - precision: 0.3031 - recall: 0.5301 - f1_score: 0.3857 - AUC: 0.6975 - val_loss: 0.7240 - val_accuracy: 0.5625 - val_precision: 0.1907 - val_recall: 0.1775 - val_f1_score: 0.1839 - val_AUC: 0.4164
# Epoch 176/500
# 26/26 - 0s - loss: 0.1767 - accuracy: 0.6887 - precision: 0.3200 - recall: 0.6291 - f1_score: 0.4242 - AUC: 0.7313 - val_loss: 0.7445 - val_accuracy: 0.5180 - val_precision: 0.1368 - val_recall: 0.1385 - val_f1_score: 0.1376 - val_AUC: 0.3871
# Epoch 177/500
# 26/26 - 0s - loss: 0.1758 - accuracy: 0.7130 - precision: 0.3343 - recall: 0.5822 - f1_score: 0.4247 - AUC: 0.7289 - val_loss: 0.7983 - val_accuracy: 0.5300 - val_precision: 0.1899 - val_recall: 0.2121 - val_f1_score: 0.2004 - val_AUC: 0.4085
# Epoch 178/500
# 26/26 - 0s - loss: 0.1819 - accuracy: 0.6734 - precision: 0.2997 - recall: 0.6034 - f1_score: 0.4005 - AUC: 0.7058 - val_loss: 0.7705 - val_accuracy: 0.5349 - val_precision: 0.2068 - val_recall: 0.2381 - val_f1_score: 0.2213 - val_AUC: 0.4136
# Epoch 179/500
# 26/26 - 0s - loss: 0.1767 - accuracy: 0.7049 - precision: 0.3281 - recall: 0.6090 - f1_score: 0.4264 - AUC: 0.7313 - val_loss: 0.8421 - val_accuracy: 0.5180 - val_precision: 0.1805 - val_recall: 0.2078 - val_f1_score: 0.1932 - val_AUC: 0.3996
# Epoch 180/500
# 26/26 - 0s - loss: 0.1752 - accuracy: 0.7174 - precision: 0.3398 - recall: 0.6066 - f1_score: 0.4356 - AUC: 0.7388 - val_loss: 0.7547 - val_accuracy: 0.5565 - val_precision: 0.1835 - val_recall: 0.1732 - val_f1_score: 0.1782 - val_AUC: 0.4141
# Epoch 181/500
# 26/26 - 0s - loss: 0.1842 - accuracy: 0.6943 - precision: 0.3164 - recall: 0.5685 - f1_score: 0.4065 - AUC: 0.6994 - val_loss: 0.8054 - val_accuracy: 0.5312 - val_precision: 0.1858 - val_recall: 0.2035 - val_f1_score: 0.1942 - val_AUC: 0.4079
# Epoch 182/500
# 26/26 - 0s - loss: 0.1781 - accuracy: 0.7146 - precision: 0.3290 - recall: 0.5704 - f1_score: 0.4173 - AUC: 0.7218 - val_loss: 0.7570 - val_accuracy: 0.5541 - val_precision: 0.1667 - val_recall: 0.1515 - val_f1_score: 0.1587 - val_AUC: 0.4033
# Epoch 183/500
# 26/26 - 0s - loss: 0.1783 - accuracy: 0.7180 - precision: 0.3347 - recall: 0.5699 - f1_score: 0.4217 - AUC: 0.7176 - val_loss: 0.8043 - val_accuracy: 0.5288 - val_precision: 0.1868 - val_recall: 0.2078 - val_f1_score: 0.1967 - val_AUC: 0.4048
# Epoch 184/500
# 26/26 - 0s - loss: 0.1717 - accuracy: 0.7065 - precision: 0.3290 - recall: 0.6111 - f1_score: 0.4277 - AUC: 0.7482 - val_loss: 0.7877 - val_accuracy: 0.5120 - val_precision: 0.1429 - val_recall: 0.1515 - val_f1_score: 0.1471 - val_AUC: 0.3895
# Epoch 185/500
# 26/26 - 0s - loss: 0.1776 - accuracy: 0.6899 - precision: 0.3102 - recall: 0.5845 - f1_score: 0.4053 - AUC: 0.7240 - val_loss: 0.7765 - val_accuracy: 0.5337 - val_precision: 0.1770 - val_recall: 0.1861 - val_f1_score: 0.1814 - val_AUC: 0.3941
# Epoch 186/500
# 26/26 - 0s - loss: 0.1819 - accuracy: 0.7111 - precision: 0.3293 - recall: 0.5482 - f1_score: 0.4114 - AUC: 0.7076 - val_loss: 0.7947 - val_accuracy: 0.5517 - val_precision: 0.2017 - val_recall: 0.2078 - val_f1_score: 0.2047 - val_AUC: 0.4149
# Epoch 187/500
# 26/26 - 0s - loss: 0.1766 - accuracy: 0.7261 - precision: 0.3426 - recall: 0.5812 - f1_score: 0.4311 - AUC: 0.7278 - val_loss: 0.7728 - val_accuracy: 0.5649 - val_precision: 0.1773 - val_recall: 0.1558 - val_f1_score: 0.1659 - val_AUC: 0.4020
# Epoch 188/500
# ...
# Epoch 439/500
# 26/26 - 0s - loss: 0.1647 - accuracy: 0.7644 - precision: 0.4011 - recall: 0.6021 - f1_score: 0.4815 - AUC: 0.7730 - val_loss: 0.8751 - val_accuracy: 0.5469 - val_precision: 0.1880 - val_recall: 0.1905 - val_f1_score: 0.1892 - val_AUC: 0.4223
# Epoch 440/500
# 26/26 - 0s - loss: 0.1664 - accuracy: 0.7572 - precision: 0.3781 - recall: 0.5612 - f1_score: 0.4518 - AUC: 0.7588 - val_loss: 0.7998 - val_accuracy: 0.5829 - val_precision: 0.1813 - val_recall: 0.1429 - val_f1_score: 0.1598 - val_AUC: 0.4239
# Epoch 441/500
# 26/26 - 0s - loss: 0.1680 - accuracy: 0.7442 - precision: 0.3770 - recall: 0.6000 - f1_score: 0.4630 - AUC: 0.7665 - val_loss: 0.8155 - val_accuracy: 0.5781 - val_precision: 0.1842 - val_recall: 0.1515 - val_f1_score: 0.1663 - val_AUC: 0.4389
# Epoch 442/500
# 26/26 - 0s - loss: 0.1643 - accuracy: 0.7906 - precision: 0.4429 - recall: 0.5544 - f1_score: 0.4924 - AUC: 0.7763 - val_loss: 0.9658 - val_accuracy: 0.5637 - val_precision: 0.1944 - val_recall: 0.1818 - val_f1_score: 0.1879 - val_AUC: 0.4268
# Epoch 443/500
# 26/26 - 0s - loss: 0.1683 - accuracy: 0.7435 - precision: 0.3731 - recall: 0.5983 - f1_score: 0.4596 - AUC: 0.7594 - val_loss: 0.7943 - val_accuracy: 0.5529 - val_precision: 0.1690 - val_recall: 0.1558 - val_f1_score: 0.1622 - val_AUC: 0.4301
# Epoch 444/500
# 26/26 - 0s - loss: 0.1613 - accuracy: 0.7666 - precision: 0.3888 - recall: 0.5819 - f1_score: 0.4661 - AUC: 0.7732 - val_loss: 0.8956 - val_accuracy: 0.5349 - val_precision: 0.1695 - val_recall: 0.1732 - val_f1_score: 0.1713 - val_AUC: 0.4240
# Epoch 445/500
# 26/26 - 0s - loss: 0.1647 - accuracy: 0.7585 - precision: 0.3926 - recall: 0.5976 - f1_score: 0.4739 - AUC: 0.7751 - val_loss: 0.8682 - val_accuracy: 0.5733 - val_precision: 0.2130 - val_recall: 0.1991 - val_f1_score: 0.2058 - val_AUC: 0.4313
# Epoch 446/500
# 26/26 - 0s - loss: 0.1653 - accuracy: 0.7728 - precision: 0.4029 - recall: 0.5744 - f1_score: 0.4736 - AUC: 0.7652 - val_loss: 0.9123 - val_accuracy: 0.5637 - val_precision: 0.1887 - val_recall: 0.1732 - val_f1_score: 0.1806 - val_AUC: 0.4291
# Epoch 447/500
# 26/26 - 0s - loss: 0.1614 - accuracy: 0.7710 - precision: 0.4130 - recall: 0.6085 - f1_score: 0.4921 - AUC: 0.7790 - val_loss: 0.9049 - val_accuracy: 0.5517 - val_precision: 0.1713 - val_recall: 0.1602 - val_f1_score: 0.1655 - val_AUC: 0.4208
# Epoch 448/500
# 26/26 - 0s - loss: 0.1661 - accuracy: 0.7600 - precision: 0.3850 - recall: 0.5714 - f1_score: 0.4600 - AUC: 0.7624 - val_loss: 0.8481 - val_accuracy: 0.5709 - val_precision: 0.1753 - val_recall: 0.1472 - val_f1_score: 0.1600 - val_AUC: 0.4218
# Epoch 449/500
# 26/26 - 0s - loss: 0.1640 - accuracy: 0.7781 - precision: 0.4200 - recall: 0.5753 - f1_score: 0.4855 - AUC: 0.7735 - val_loss: 0.8145 - val_accuracy: 0.5577 - val_precision: 0.1784 - val_recall: 0.1645 - val_f1_score: 0.1712 - val_AUC: 0.4267
# Epoch 450/500
# 26/26 - 0s - loss: 0.1603 - accuracy: 0.7619 - precision: 0.3927 - recall: 0.6017 - f1_score: 0.4753 - AUC: 0.7770 - val_loss: 0.8488 - val_accuracy: 0.5733 - val_precision: 0.1900 - val_recall: 0.1645 - val_f1_score: 0.1763 - val_AUC: 0.4238
# Epoch 451/500
# 26/26 - 0s - loss: 0.1645 - accuracy: 0.7706 - precision: 0.4116 - recall: 0.5911 - f1_score: 0.4853 - AUC: 0.7770 - val_loss: 0.8843 - val_accuracy: 0.5469 - val_precision: 0.1798 - val_recall: 0.1775 - val_f1_score: 0.1786 - val_AUC: 0.4142
# Epoch 452/500
# 26/26 - 0s - loss: 0.1612 - accuracy: 0.7669 - precision: 0.3961 - recall: 0.6085 - f1_score: 0.4798 - AUC: 0.7790 - val_loss: 0.8740 - val_accuracy: 0.5613 - val_precision: 0.2035 - val_recall: 0.1991 - val_f1_score: 0.2013 - val_AUC: 0.4225
# Epoch 453/500
# 26/26 - 0s - loss: 0.1649 - accuracy: 0.7694 - precision: 0.4066 - recall: 0.6153 - f1_score: 0.4897 - AUC: 0.7783 - val_loss: 0.9131 - val_accuracy: 0.5517 - val_precision: 0.2066 - val_recall: 0.2165 - val_f1_score: 0.2114 - val_AUC: 0.4230
# Epoch 454/500
# 26/26 - 0s - loss: 0.1635 - accuracy: 0.7731 - precision: 0.4116 - recall: 0.6038 - f1_score: 0.4895 - AUC: 0.7789 - val_loss: 0.8044 - val_accuracy: 0.5637 - val_precision: 0.1765 - val_recall: 0.1558 - val_f1_score: 0.1655 - val_AUC: 0.4257
# Epoch 455/500
# 26/26 - 0s - loss: 0.1657 - accuracy: 0.7498 - precision: 0.3816 - recall: 0.6117 - f1_score: 0.4700 - AUC: 0.7651 - val_loss: 0.8136 - val_accuracy: 0.5601 - val_precision: 0.1770 - val_recall: 0.1602 - val_f1_score: 0.1682 - val_AUC: 0.4321
# Epoch 456/500
# 26/26 - 0s - loss: 0.1659 - accuracy: 0.7504 - precision: 0.3869 - recall: 0.6235 - f1_score: 0.4775 - AUC: 0.7754 - val_loss: 0.8011 - val_accuracy: 0.5721 - val_precision: 0.1891 - val_recall: 0.1645 - val_f1_score: 0.1759 - val_AUC: 0.4114
# Epoch 457/500
# 26/26 - 0s - loss: 0.1640 - accuracy: 0.7535 - precision: 0.3892 - recall: 0.5983 - f1_score: 0.4716 - AUC: 0.7752 - val_loss: 0.8654 - val_accuracy: 0.5445 - val_precision: 0.1509 - val_recall: 0.1385 - val_f1_score: 0.1445 - val_AUC: 0.4136
# Epoch 458/500
# 26/26 - 0s - loss: 0.1616 - accuracy: 0.7722 - precision: 0.3978 - recall: 0.5900 - f1_score: 0.4752 - AUC: 0.7664 - val_loss: 0.9019 - val_accuracy: 0.5481 - val_precision: 0.1834 - val_recall: 0.1818 - val_f1_score: 0.1826 - val_AUC: 0.4213
# Epoch 459/500
# 26/26 - 0s - loss: 0.1647 - accuracy: 0.7616 - precision: 0.3935 - recall: 0.5852 - f1_score: 0.4706 - AUC: 0.7705 - val_loss: 0.8773 - val_accuracy: 0.5517 - val_precision: 0.1773 - val_recall: 0.1688 - val_f1_score: 0.1729 - val_AUC: 0.4335
# Epoch 460/500
# 26/26 - 0s - loss: 0.1631 - accuracy: 0.7464 - precision: 0.3768 - recall: 0.6217 - f1_score: 0.4692 - AUC: 0.7736 - val_loss: 0.8126 - val_accuracy: 0.5709 - val_precision: 0.1613 - val_recall: 0.1299 - val_f1_score: 0.1439 - val_AUC: 0.4304
# Epoch 461/500
# 26/26 - 0s - loss: 0.1660 - accuracy: 0.7653 - precision: 0.3870 - recall: 0.5699 - f1_score: 0.4610 - AUC: 0.7645 - val_loss: 0.8102 - val_accuracy: 0.5661 - val_precision: 0.1684 - val_recall: 0.1429 - val_f1_score: 0.1546 - val_AUC: 0.4254
# Epoch 462/500
# 26/26 - 0s - loss: 0.1667 - accuracy: 0.7457 - precision: 0.3835 - recall: 0.6074 - f1_score: 0.4701 - AUC: 0.7720 - val_loss: 0.8620 - val_accuracy: 0.5661 - val_precision: 0.1905 - val_recall: 0.1732 - val_f1_score: 0.1814 - val_AUC: 0.4333
# Epoch 463/500
# 26/26 - 0s - loss: 0.1612 - accuracy: 0.7769 - precision: 0.4121 - recall: 0.5954 - f1_score: 0.4871 - AUC: 0.7785 - val_loss: 0.8615 - val_accuracy: 0.5481 - val_precision: 0.1778 - val_recall: 0.1732 - val_f1_score: 0.1754 - val_AUC: 0.4216
# Epoch 464/500
# 26/26 - 0s - loss: 0.1695 - accuracy: 0.7445 - precision: 0.3861 - recall: 0.6060 - f1_score: 0.4716 - AUC: 0.7620 - val_loss: 0.8584 - val_accuracy: 0.5469 - val_precision: 0.1589 - val_recall: 0.1472 - val_f1_score: 0.1528 - val_AUC: 0.4122
# Epoch 465/500
# 26/26 - 0s - loss: 0.1580 - accuracy: 0.7797 - precision: 0.4105 - recall: 0.5971 - f1_score: 0.4866 - AUC: 0.7902 - val_loss: 0.8822 - val_accuracy: 0.5457 - val_precision: 0.1613 - val_recall: 0.1515 - val_f1_score: 0.1562 - val_AUC: 0.4049
# Epoch 466/500
# 26/26 - 0s - loss: 0.1643 - accuracy: 0.7678 - precision: 0.4057 - recall: 0.6121 - f1_score: 0.4880 - AUC: 0.7741 - val_loss: 0.8836 - val_accuracy: 0.5565 - val_precision: 0.1920 - val_recall: 0.1861 - val_f1_score: 0.1890 - val_AUC: 0.4174
# Epoch 467/500
# 26/26 - 0s - loss: 0.1621 - accuracy: 0.7875 - precision: 0.4356 - recall: 0.5746 - f1_score: 0.4956 - AUC: 0.7814 - val_loss: 0.9041 - val_accuracy: 0.5649 - val_precision: 0.1805 - val_recall: 0.1602 - val_f1_score: 0.1697 - val_AUC: 0.4123
# Epoch 468/500
# 26/26 - 0s - loss: 0.1645 - accuracy: 0.7588 - precision: 0.3875 - recall: 0.5759 - f1_score: 0.4632 - AUC: 0.7651 - val_loss: 0.8679 - val_accuracy: 0.5541 - val_precision: 0.1818 - val_recall: 0.1732 - val_f1_score: 0.1774 - val_AUC: 0.4286
# Epoch 469/500
# 26/26 - 0s - loss: 0.1597 - accuracy: 0.7763 - precision: 0.4130 - recall: 0.5958 - f1_score: 0.4879 - AUC: 0.7837 - val_loss: 0.9365 - val_accuracy: 0.5613 - val_precision: 0.1898 - val_recall: 0.1775 - val_f1_score: 0.1834 - val_AUC: 0.4272
# Epoch 470/500
# 26/26 - 0s - loss: 0.1707 - accuracy: 0.7616 - precision: 0.4093 - recall: 0.5780 - f1_score: 0.4792 - AUC: 0.7631 - val_loss: 0.8692 - val_accuracy: 0.5337 - val_precision: 0.1715 - val_recall: 0.1775 - val_f1_score: 0.1745 - val_AUC: 0.3948
# Epoch 471/500
# 26/26 - 0s - loss: 0.1574 - accuracy: 0.7772 - precision: 0.3866 - recall: 0.5566 - f1_score: 0.4563 - AUC: 0.7764 - val_loss: 0.8816 - val_accuracy: 0.5649 - val_precision: 0.1741 - val_recall: 0.1515 - val_f1_score: 0.1620 - val_AUC: 0.4201
# Epoch 472/500
# 26/26 - 0s - loss: 0.1682 - accuracy: 0.7563 - precision: 0.3950 - recall: 0.5829 - f1_score: 0.4709 - AUC: 0.7660 - val_loss: 0.8676 - val_accuracy: 0.5505 - val_precision: 0.1850 - val_recall: 0.1818 - val_f1_score: 0.1834 - val_AUC: 0.4057
# Epoch 473/500
# 26/26 - 0s - loss: 0.1579 - accuracy: 0.7744 - precision: 0.4014 - recall: 0.5964 - f1_score: 0.4799 - AUC: 0.7846 - val_loss: 0.8788 - val_accuracy: 0.5553 - val_precision: 0.1737 - val_recall: 0.1602 - val_f1_score: 0.1667 - val_AUC: 0.4174
# Epoch 474/500
# 26/26 - 0s - loss: 0.1605 - accuracy: 0.7738 - precision: 0.4113 - recall: 0.6042 - f1_score: 0.4895 - AUC: 0.7795 - val_loss: 0.8263 - val_accuracy: 0.5541 - val_precision: 0.1602 - val_recall: 0.1429 - val_f1_score: 0.1510 - val_AUC: 0.4208
# Epoch 475/500
# 26/26 - 1s - loss: 0.1656 - accuracy: 0.7604 - precision: 0.3842 - recall: 0.5672 - f1_score: 0.4581 - AUC: 0.7568 - val_loss: 0.8316 - val_accuracy: 0.5661 - val_precision: 0.1845 - val_recall: 0.1645 - val_f1_score: 0.1739 - val_AUC: 0.4313
# Epoch 476/500
# 26/26 - 0s - loss: 0.1627 - accuracy: 0.7800 - precision: 0.4309 - recall: 0.5875 - f1_score: 0.4972 - AUC: 0.7836 - val_loss: 0.8017 - val_accuracy: 0.5697 - val_precision: 0.1492 - val_recall: 0.1169 - val_f1_score: 0.1311 - val_AUC: 0.4255
# Epoch 477/500
# 26/26 - 0s - loss: 0.1626 - accuracy: 0.7719 - precision: 0.4180 - recall: 0.6030 - f1_score: 0.4938 - AUC: 0.7801 - val_loss: 0.8550 - val_accuracy: 0.5589 - val_precision: 0.1634 - val_recall: 0.1429 - val_f1_score: 0.1524 - val_AUC: 0.4228
# Epoch 478/500
# 26/26 - 0s - loss: 0.1619 - accuracy: 0.7700 - precision: 0.3873 - recall: 0.5750 - f1_score: 0.4629 - AUC: 0.7641 - val_loss: 0.7980 - val_accuracy: 0.5553 - val_precision: 0.1508 - val_recall: 0.1299 - val_f1_score: 0.1395 - val_AUC: 0.4342
# Epoch 479/500
# 26/26 - 0s - loss: 0.1601 - accuracy: 0.7657 - precision: 0.3878 - recall: 0.5717 - f1_score: 0.4621 - AUC: 0.7718 - val_loss: 0.8475 - val_accuracy: 0.5685 - val_precision: 0.1701 - val_recall: 0.1429 - val_f1_score: 0.1553 - val_AUC: 0.4255
# Epoch 480/500
# 26/26 - 0s - loss: 0.1670 - accuracy: 0.7691 - precision: 0.4276 - recall: 0.6166 - f1_score: 0.5050 - AUC: 0.7773 - val_loss: 0.8267 - val_accuracy: 0.5577 - val_precision: 0.1928 - val_recall: 0.1861 - val_f1_score: 0.1894 - val_AUC: 0.4368
# Epoch 481/500
# 26/26 - 0s - loss: 0.1633 - accuracy: 0.7728 - precision: 0.3968 - recall: 0.5850 - f1_score: 0.4729 - AUC: 0.7674 - val_loss: 0.8430 - val_accuracy: 0.5625 - val_precision: 0.1878 - val_recall: 0.1732 - val_f1_score: 0.1802 - val_AUC: 0.4240
# Epoch 482/500
# 26/26 - 0s - loss: 0.1621 - accuracy: 0.7647 - precision: 0.4033 - recall: 0.5831 - f1_score: 0.4768 - AUC: 0.7845 - val_loss: 0.9048 - val_accuracy: 0.5517 - val_precision: 0.1802 - val_recall: 0.1732 - val_f1_score: 0.1766 - val_AUC: 0.4114
# Epoch 483/500
# 26/26 - 0s - loss: 0.1642 - accuracy: 0.7622 - precision: 0.3912 - recall: 0.5833 - f1_score: 0.4683 - AUC: 0.7675 - val_loss: 0.8594 - val_accuracy: 0.5613 - val_precision: 0.1927 - val_recall: 0.1818 - val_f1_score: 0.1871 - val_AUC: 0.4297
# Epoch 484/500
# 26/26 - 0s - loss: 0.1602 - accuracy: 0.7694 - precision: 0.4128 - recall: 0.6167 - f1_score: 0.4945 - AUC: 0.7831 - val_loss: 0.8429 - val_accuracy: 0.5481 - val_precision: 0.1628 - val_recall: 0.1515 - val_f1_score: 0.1570 - val_AUC: 0.4116
# Epoch 485/500
# 26/26 - 0s - loss: 0.1617 - accuracy: 0.7619 - precision: 0.3920 - recall: 0.5920 - f1_score: 0.4716 - AUC: 0.7697 - val_loss: 0.8371 - val_accuracy: 0.5433 - val_precision: 0.1502 - val_recall: 0.1385 - val_f1_score: 0.1441 - val_AUC: 0.4072
# Epoch 486/500
# 26/26 - 0s - loss: 0.1629 - accuracy: 0.7594 - precision: 0.3890 - recall: 0.5838 - f1_score: 0.4669 - AUC: 0.7692 - val_loss: 0.8724 - val_accuracy: 0.5337 - val_precision: 0.1715 - val_recall: 0.1775 - val_f1_score: 0.1745 - val_AUC: 0.4219
# Epoch 487/500
# 26/26 - 0s - loss: 0.1609 - accuracy: 0.7728 - precision: 0.4116 - recall: 0.6007 - f1_score: 0.4885 - AUC: 0.7784 - val_loss: 0.9057 - val_accuracy: 0.5673 - val_precision: 0.2000 - val_recall: 0.1861 - val_f1_score: 0.1928 - val_AUC: 0.4306
# Epoch 488/500
# 26/26 - 0s - loss: 0.1639 - accuracy: 0.7638 - precision: 0.3956 - recall: 0.5855 - f1_score: 0.4721 - AUC: 0.7746 - val_loss: 0.8436 - val_accuracy: 0.5601 - val_precision: 0.1860 - val_recall: 0.1732 - val_f1_score: 0.1794 - val_AUC: 0.4217
# Epoch 489/500
# 26/26 - 0s - loss: 0.1624 - accuracy: 0.7660 - precision: 0.4022 - recall: 0.6205 - f1_score: 0.4881 - AUC: 0.7856 - val_loss: 0.8689 - val_accuracy: 0.5409 - val_precision: 0.1644 - val_recall: 0.1602 - val_f1_score: 0.1623 - val_AUC: 0.3992
# Epoch 490/500
# 26/26 - 0s - loss: 0.1620 - accuracy: 0.7731 - precision: 0.4172 - recall: 0.6109 - f1_score: 0.4958 - AUC: 0.7763 - val_loss: 0.8631 - val_accuracy: 0.5577 - val_precision: 0.1722 - val_recall: 0.1558 - val_f1_score: 0.1636 - val_AUC: 0.4234
# Epoch 491/500
# 26/26 - 0s - loss: 0.1603 - accuracy: 0.7660 - precision: 0.3962 - recall: 0.6237 - f1_score: 0.4846 - AUC: 0.7839 - val_loss: 0.8311 - val_accuracy: 0.5565 - val_precision: 0.1714 - val_recall: 0.1558 - val_f1_score: 0.1633 - val_AUC: 0.4242
# Epoch 492/500
# 26/26 - 0s - loss: 0.1684 - accuracy: 0.7591 - precision: 0.4011 - recall: 0.5980 - f1_score: 0.4802 - AUC: 0.7599 - val_loss: 0.8757 - val_accuracy: 0.5661 - val_precision: 0.1934 - val_recall: 0.1775 - val_f1_score: 0.1851 - val_AUC: 0.4055
# Epoch 493/500
# 26/26 - 0s - loss: 0.1602 - accuracy: 0.7806 - precision: 0.4148 - recall: 0.5936 - f1_score: 0.4884 - AUC: 0.7800 - val_loss: 0.8805 - val_accuracy: 0.5589 - val_precision: 0.1822 - val_recall: 0.1688 - val_f1_score: 0.1753 - val_AUC: 0.4102
# Epoch 494/500
# 26/26 - 0s - loss: 0.1596 - accuracy: 0.7781 - precision: 0.4167 - recall: 0.5903 - f1_score: 0.4885 - AUC: 0.7807 - val_loss: 0.8182 - val_accuracy: 0.5637 - val_precision: 0.1562 - val_recall: 0.1299 - val_f1_score: 0.1418 - val_AUC: 0.4046
# Epoch 495/500
# 26/26 - 0s - loss: 0.1640 - accuracy: 0.7454 - precision: 0.3796 - recall: 0.6212 - f1_score: 0.4712 - AUC: 0.7731 - val_loss: 0.8067 - val_accuracy: 0.5613 - val_precision: 0.1436 - val_recall: 0.1169 - val_f1_score: 0.1289 - val_AUC: 0.4099
# Epoch 496/500
# 26/26 - 0s - loss: 0.1647 - accuracy: 0.7850 - precision: 0.4320 - recall: 0.5450 - f1_score: 0.4820 - AUC: 0.7687 - val_loss: 0.8790 - val_accuracy: 0.5601 - val_precision: 0.1889 - val_recall: 0.1775 - val_f1_score: 0.1830 - val_AUC: 0.4228
# Epoch 497/500
# 26/26 - 0s - loss: 0.1605 - accuracy: 0.7734 - precision: 0.3995 - recall: 0.5836 - f1_score: 0.4743 - AUC: 0.7749 - val_loss: 0.8144 - val_accuracy: 0.5613 - val_precision: 0.1436 - val_recall: 0.1169 - val_f1_score: 0.1289 - val_AUC: 0.4097
# Epoch 498/500
# 26/26 - 0s - loss: 0.1621 - accuracy: 0.7763 - precision: 0.4195 - recall: 0.6145 - f1_score: 0.4986 - AUC: 0.7811 - val_loss: 0.8359 - val_accuracy: 0.5733 - val_precision: 0.1931 - val_recall: 0.1688 - val_f1_score: 0.1801 - val_AUC: 0.4265
# Epoch 499/500
# 26/26 - 0s - loss: 0.1616 - accuracy: 0.7822 - precision: 0.4245 - recall: 0.6007 - f1_score: 0.4975 - AUC: 0.7743 - val_loss: 0.8582 - val_accuracy: 0.5601 - val_precision: 0.1707 - val_recall: 0.1515 - val_f1_score: 0.1606 - val_AUC: 0.4117
# Epoch 500/500
# 26/26 - 0s - loss: 0.1631 - accuracy: 0.7797 - precision: 0.4173 - recall: 0.5579 - f1_score: 0.4775 - AUC: 0.7729 - val_loss: 0.8401 - val_accuracy: 0.5661 - val_precision: 0.1750 - val_recall: 0.1515 - val_f1_score: 0.1624 - val_AUC: 0.4088

# %%
# Primera iteración con el AUC de validación más alto
best_iter=np.where(np.max(history_1.history['val_AUC'])==history_1.history['val_AUC'])[0][0]
print(best_iter)
# Out:
# 9

# %%
# AUC más alto
history_1.history['val_AUC'][best_iter]
# Out:
# 0.5161239504814148

# %%
# Definiendo la función para desplegar la curva ROC
def plot_roc(name, labels, predictions, name_fig):
    fp, tp, _ = roc_curve(labels, predictions)
    auc1 = auc(fp, tp)
    lw=2

    plt.plot(100*fp, 100*tp, linewidth=2, lw=lw, color='darkorange', label='ROC curve (area = %0.2f)' % auc1)
    plt.plot([0, 100], [0, 100], color='navy', lw=lw, linestyle='--',label='Random')
    plt.xlabel('Falsos positivos [%]')
    plt.ylabel('Verdaderos positivos [%]')
    plt.xlim([-5,105])
    plt.ylim([-5,105])
    plt.grid(True)
    ax = plt.gca()
    ax.set_aspect('equal')
    plt.title(name)
    plt.legend(loc="lower right")
    plt.savefig('ROC_'+name_fig+'.png')

# %%
# Definiendo función para visualizar curvas de entrenamiento
def display_training_curves(training, validation, title, subplot):   ####2
    if subplot%10==1: # set up the subplots on the first call
        plt.subplots(figsize=(10,10), facecolor='#F0F0F0')
        plt.tight_layout()
    ax = plt.subplot(subplot)
    ax.set_facecolor('#F8F8F8')
    ax.plot(training)
    ax.plot(validation)
    ax.set_title('model '+ title)
    ax.set_ylabel(title)
    #ax.set_ylim(0.28,1.05)
    ax.set_xlabel('Iteración')
    ax.legend(['Entrenamiento', 'Validación.'])
    ax.scatter(best_iter, validation[best_iter], c='#ff7f0e', s=500)
    bbox = dict(boxstyle="round", fc="0.9")
    ax.annotate("Iteración con AUC más alto", (best_iter, validation[best_iter]), bbox=bbox)
    plt.savefig(str(title)+'.png')

# %%
# Desplegando curvas (loss & accuracy)
display_training_curves(history_1.history['loss'], history_1.history['val_loss'], 'Loss', 211)
display_training_curves(history_1.history['accuracy'], history_1.history['val_accuracy'], 'Accuracy', 212)

# %%
# Desplegando curvas (precision & recall)
display_training_curves(history_1.history['precision'], history_1.history['val_precision'], 'Precision', 211)
display_training_curves(history_1.history['recall'], history_1.history['val_recall'], 'Recall', 212)

# %%
# Desplegando curvas (f1_score & AUC)
display_training_curves(history_1.history['f1_score'], history_1.history['val_f1_score'], 'F1-Score', 211)
display_training_curves(history_1.history['AUC'], history_1.history['val_AUC'], 'AUC', 212)

# %%
# Cargamos el modelo con la mejor métrica de F1-Score en validación
rnet.load_weights("rnet_weights.h5")

# %%
# Calculando las predicciones para Red Neuronal
Y_train_pred = (rnet.predict(X_train_pca) > 0.5).astype("int32")
Y_train_proba = rnet.predict(X_train_pca) # Arreglo de probabilidades
Y_test_pred = (rnet.predict(X_test_pca) > 0.5).astype("int32")
Y_test_proba = rnet.predict(X_test_pca) # Arreglo de probabilidades

# %% [markdown]
# Lamentablemente Tensorflow subestima la métrica F1-Score y Sobrestima la métrica AUC. Para este trabajo se reportarán los resultados con base en la biblioteca de Scikit-Learn y se utilizará las métricas de TensorFlow sólo como auxiliar para hallar el valor más alto ponderado durante las iteracion o entrenamiento.
#
# Por tanto es posible que algunas gráficas del entrenamiento difieran con los resultados finales de estas dos métricas.
#
# A continuación de realiza una demostración de lo anteriromente descrito.

# %%
# Desplegando métrica del rendimiento
print("RED NEURONAL TensorFlow Metrics")
print()
print("MÉTRICAS EN ENTRENAMIENTO")
metric = tf.keras.metrics.BinaryAccuracy()
metric.update_state(Y_train, Y_train_pred)
print("Accuracy: %0.2f%%"%(100*metric.result().numpy()))
metric = tf.keras.metrics.Precision()
metric.update_state(Y_train, Y_train_pred)
print("Precision: %0.2f%%"%(100*metric.result().numpy()))
metric = tf.keras.metrics.Recall()
metric.update_state(Y_train, Y_train_pred)
print("Recall: %0.2f%%"%(100*metric.result().numpy()))
metric = tfa.metrics.F1Score(num_classes=2, average="micro", threshold=0.5)
metric.update_state(Y_train, Y_train_pred)
print("F1-Score: %0.2f%%"%(100*metric.result().numpy()))
metric = tf.keras.metrics.AUC()
metric.update_state(Y_train, Y_train_proba)
print("AUC: %0.2f%%"%(100*metric.result().numpy()))
print()
print("MÉTRICAS EN VALIDACIÓN")
metric = tf.keras.metrics.BinaryAccuracy()
metric.update_state(Y_test, Y_test_pred)
print("Accuracy: %0.2f%%"%(100*metric.result().numpy()))
metric = tf.keras.metrics.Precision()
metric.update_state(Y_test, Y_test_pred)
print("Precision: %0.2f%%"%(100*metric.result().numpy()))
metric = tf.keras.metrics.Recall()
metric.update_state(Y_test, Y_test_pred)
print("Recall: %0.2f%%"%(100*metric.result().numpy()))
metric = tfa.metrics.F1Score(num_classes=2, average="micro", threshold=0.5)
metric.update_state(Y_test, Y_test_pred)
print("F1-Score: %0.2f%%"%(100*metric.result().numpy()))
metric = tf.keras.metrics.AUC()
metric.update_state(Y_test, Y_test_proba)
print("AUC: %0.2f%%"%(100*metric.result().numpy()))
print()
print()
print("RED NEURONAL SciKit-Learn Metrics")
print()
print("MÉTRICAS EN ENTRENAMIENTO")
print("Accuracy: %0.2f%%"%(100*accuracy_score(Y_train, Y_train_pred)))
print("Precision: %0.2f%%"%(100*precision_score(Y_train, Y_train_pred)))
print("Recall: %0.2f%%"%(100*recall_score(Y_train, Y_train_pred)))
print("F1-Score: %0.2f%%"%(100*f1_score(Y_train, Y_train_pred)))
fp, tp, _ = roc_curve(Y_train, Y_train_proba)
print("AUC: %0.2f%%"%(100*auc(fp, tp)))
print()
print("MÉTRICAS EN VALIDACIÓN")
print("Accuracy: %0.2f%%"%(100*accuracy_score(Y_test, Y_test_pred)))
print("Precision: %0.2f%%"%(100*precision_score(Y_test, Y_test_pred)))
print("Recall: %0.2f%%"%(100*recall_score(Y_test, Y_test_pred)))
print("F1-Score: %0.2f%%"%(100*f1_score(Y_test, Y_test_pred)))
fp, tp, _ = roc_curve(Y_test, Y_test_proba)
print("AUC: %0.2f%%"%(100*auc(fp, tp)))
print()
# Out:
# RED NEURONAL TensorFlow Metrics
#
# MÉTRICAS EN ENTRENAMIENTO
# Accuracy: 72.70%
# Precision: 33.00%
# Recall: 49.83%
# F1-Score: 21.71%
# AUC: 69.42%
#
# MÉTRICAS EN VALIDACIÓN
# Accuracy: 59.50%
# Precision: 25.00%
# Recall: 22.94%
# F1-Score: 26.57%
# AUC: 51.61%
#
#
# RED NEURONAL SciKit-Learn Metrics
#
# MÉTRICAS EN ENTRENAMIENTO
# Accuracy: 72.70%
# Precision: 33.00%
# Recall: 49.83%
# F1-Score: 39.71%
# AUC: 69.64%
#
# MÉTRICAS EN VALIDACIÓN
# Accuracy: 59.50%
# Precision: 25.00%
# Recall: 22.94%
# F1-Score: 23.93%
# AUC: 51.63%

# %%
# Curva ROC de entrenamiento
plot_roc('ROC Red Neuronal Entrenamiento', Y_train, Y_train_proba, name_fig='RNET')
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:7: MatplotlibDeprecationWarning: Saw kwargs ['lw', 'linewidth'] which are all aliases for 'linewidth'.  Kept value from 'linewidth'.  Passing multiple aliases for the same property will raise a TypeError in 3.3.
#   import sys

# %%
# Curva de Roc de Validación
plot_roc('ROC Red Neuronal Validacion', Y_test, Y_test_proba, name_fig='RNET')
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:7: MatplotlibDeprecationWarning: Saw kwargs ['lw', 'linewidth'] which are all aliases for 'linewidth'.  Kept value from 'linewidth'.  Passing multiple aliases for the same property will raise a TypeError in 3.3.
#   import sys

# %%
rnet.save('PCA_rnet_FULL.h5')
